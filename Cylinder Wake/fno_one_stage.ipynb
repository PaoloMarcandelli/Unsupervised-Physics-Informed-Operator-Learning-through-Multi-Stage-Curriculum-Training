# %%
import numpy as np
import scipy.io
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sub = 1
offset = 0
T_in = 1
T = 10

# --- carica ---  #
data   = scipy.io.loadmat('cylinder_wake.mat')
X_star = data['X_star']           # (N,2)
U_star = data['U_star']           # (N,2,T)
P_star = data['p_star']           # (N,T)
t_star = data['t'].squeeze()      # (T,)

# --- griglia regolare (completa) ---
dec =12
x_unique = np.unique(np.round(X_star[:,0], dec))   # 100 valori
y_unique = np.unique(np.round(X_star[:,1], dec))   # 50 valori
Sx_full, Sy_full = len(x_unique), len(y_unique)
time = t_star.shape[0]

# mapping (x,y) -> (i,j) sulla griglia COMPLETA
x_to_i = {x:i for i,x in enumerate(x_unique)}
y_to_j = {y:j for j,y in enumerate(y_unique)}
ij = np.empty((X_star.shape[0],2), dtype=int)
for k,(x,y) in enumerate(np.round(X_star, dec)):
    ij[k] = (x_to_i[x], y_to_j[y])

# --- riempi griglie complete ---
U_grid = np.empty((Sx_full, Sy_full, time, 2), dtype=U_star.dtype)  # ...,(u,v)
P_grid = np.empty((Sx_full, Sy_full, time),     dtype=P_star.dtype)

for k in range(X_star.shape[0]):
    i,j = ij[k]
    U_grid[i,j,:,0] = U_star[k,0,:]   # u
    U_grid[i,j,:,1] = U_star[k,1,:]   # v
    P_grid[i,j,:]   = P_star[k,:]

# ====== QUI scegli metà dominio in x (50 colonne) ======
half = Sx_full // 2

# Metà SINISTRA:    ix = slice(0, half)
# Metà DESTRA:      ix = slice(half, Sx_full)
# Metà CENTRATA:    c = Sx_full//2; w = half; ix = slice(c - w//2, c + w//2)
ix = slice(0, half)

# Integra anche l'eventuale subsampling
iy = slice(0, Sy_full)               # tieni tutte le 50 in y
ix = slice(ix.start, ix.stop, sub)   # es. sub=1 → tutte; sub=2 → una ogni 2
iy = slice(iy.start, iy.stop, sub)

# --- in torch, con B=1: u,v,p hanno shape (1, Sx', Sy', T) ---
u = torch.from_numpy(U_grid[ix, iy, :, 0]).unsqueeze(0).contiguous()   # (1, 50, 50, T) se sub=1
v = torch.from_numpy(U_grid[ix, iy, :, 1]).unsqueeze(0).contiguous()
p = torch.from_numpy(P_grid[ix, iy, :]).unsqueeze(0).contiguous()

# --- coord grid coerenti (usando meshgrid) ---
x_half = x_unique[ix]
y_half = y_unique[iy]
Xv, Yv = np.meshgrid(x_half, y_half, indexing='ij')  # (Sx',Sy')
X = torch.from_numpy(Xv)[None, ..., None]  # (1,Sx',Sy',1)
Y = torch.from_numpy(Yv)[None, ..., None]  # (1,Sx',Sy',1)

# --- split in/stimolo e target ---
u_in = u[..., offset:offset+T_in]                         # (1,Sx',Sy',T_in)
v_in = v[..., offset:offset+T_in]
p_in = p[..., offset:offset+T_in]

u_t = u[..., offset+T_in:offset+T_in+T]                   # (1,Sx',Sy',T)
v_t = v[..., offset+T_in:offset+T_in+T]
p_t = p[..., offset+T_in:offset+T_in+T]

# pack finale (B=1): concateni (x,y) ai canali temporali
train_in = torch.cat([X.to(device), Y.to(device), 
                      u_in.to(device), v_in.to(device), p_in.to(device)], dim=-1)  # (1,Sx',Sy', 2+3*T_in)

target = torch.stack([u_t, v_t, p_t], dim=-1)  # (1,Sx',Sy', T, 3)
train_t = target.reshape(target.shape[0], target.shape[1], target.shape[2], -1).contiguous().to(device)

print("Shapes ->", "train_in:", tuple(train_in.shape), "train_t:", tuple(train_t.shape),
      "| sub =", sub, "| half-x =", (ix.start, ix.stop, ix.step))

train_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(train_in, train_t),
    batch_size=1, shuffle=False
)
# Out:
# Shapes -> train_in: (1, 50, 50, 5) train_t: (1, 50, 50, 30) | sub = 1 | half-x = (0, 50, 1)

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
from utilities3 import *

import operator
from functools import reduce
from functools import partial
import os

from timeit import default_timer
import scipy.io
import pandas as pd
from get_params import get_params

import math


torch.manual_seed(0)
np.random.seed(0)

################################################################
# fourier layer
################################################################

def compl_mul2d_rfft(a, b):
    # a: (batch, in_ch, m1, m2, 2)
    # b: (in_ch, out_ch, m1, m2, 2)
    op = partial(torch.einsum, "bctq,dctq->bdtq")
    real = op(a[...,0], b[...,0]) - op(a[...,1], b[...,1])
    imag = op(a[...,1], b[...,0]) + op(a[...,0], b[...,1])
    return torch.stack([real, imag], dim=-1)


class SpectralConv2d_fast(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1
        self.modes2 = modes2
        self.scale = (1/(in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))

    def forward(self, x):
        batchsize, _, nx, ny = *x.shape, 
        # Compute Fourier coefficients (real input -> rfft2)
        x_ft_complex = torch.fft.rfft2(x, norm='ortho')
        # Convert to real-imag tensor
        x_ft = torch.stack([x_ft_complex.real, x_ft_complex.imag], dim=-1)
        # Allocate output in Fourier space
        out_ft = torch.zeros(batchsize, self.out_channels, nx, ny//2+1, 2, device=x.device)
        # Multiply modes
        out_ft[:, :, :self.modes1, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)
        # Convert back to complex
        out_ft_complex = torch.complex(out_ft[...,0], out_ft[...,1])
        # Return to physical space
        x = torch.fft.irfft2(out_ft_complex, s=(nx, ny), norm='ortho')
        return x

class SimpleBlock2d(nn.Module):
    def __init__(self, modes1, modes2, width):
        super(SimpleBlock2d, self).__init__()

        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.fc0 = nn.Linear(5, self.width)

        self.conv0 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)
        self.bn0 = torch.nn.BatchNorm2d(self.width)
        self.bn1 = torch.nn.BatchNorm2d(self.width)
        self.bn2 = torch.nn.BatchNorm2d(self.width)
        self.bn3 = torch.nn.BatchNorm2d(self.width)


        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 3)

    def forward(self, x):
        batchsize = x.shape[0]
        size_x, size_y = x.shape[1], x.shape[2]

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)

        x1 = self.conv0(x)
        x2 = self.w0(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn0(x1 + x2)
        x = F.relu(x)
        x1 = self.conv1(x)
        x2 = self.w1(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn1(x1 + x2)
        x = F.relu(x)
        x1 = self.conv2(x)
        x2 = self.w2(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn2(x1 + x2)
        x = F.relu(x)
        x1 = self.conv3(x)
        x2 = self.w3(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn3(x1 + x2)


        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

class Net2d(nn.Module):
    def __init__(self, modes, width):
        super(Net2d, self).__init__()

        self.conv1 = SimpleBlock2d(modes, modes, width)


    def forward(self, x):
        x = self.conv1(x)
        return x


    def count_params(self):
        c = 0
        for p in self.parameters():
            c += reduce(operator.mul, list(p.size()))

        return c

import torch
import math

# ------------------------------------------------------------
# 1) Fourier continuation (even-reflection) 2D
#    Estende con riflessione pari (C^0 e con pendenze ~0 agli estremi).
#    È robusta per derivazione spettrale su domini non periodici.
# ------------------------------------------------------------
def fc_pad2d_even(x, m: int, dimx: int=-2, dimy: int=-1):
    """
    x: (..., Sx, Sy)
    m: spessore continuation per lato
    return: x_ext (..., Sx+2m, Sy+2m)
    """
    assert m > 0
    # pad lungo x (righe)
    x_left  = torch.flip(x[..., 1:m+1, :], dims=(dimx,))   # riflessione interna (evita duplicare bordo)
    x_right = torch.flip(x[..., -m-1:-1, :], dims=(dimx,))
    x_px = torch.cat([x_left, x, x_right], dim=dimx)
    # pad lungo y (colonne)
    y_top    = torch.flip(x_px[..., :, 1:m+1], dims=(dimy,))
    y_bottom = torch.flip(x_px[..., :, -m-1:-1], dims=(dimy,))
    x_ext = torch.cat([y_top, x_px, y_bottom], dim=dimy)
    return x_ext

def center_crop2d(x_ext, m: int, dimx: int=-2, dimy: int=-1):
    """
    x_ext: (..., Sx+2m, Sy+2m)
    return: (..., Sx, Sy)
    """
    slx = [slice(None)] * x_ext.ndim
    sly = [slice(None)] * x_ext.ndim
    Sx_ext = x_ext.shape[dimx]
    Sy_ext = x_ext.shape[dimy]
    Sx = Sx_ext - 2*m
    Sy = Sy_ext - 2*m
    slx[dimx] = slice(m, m+Sx)
    sly[dimy] = slice(m, m+Sy)
    return x_ext[tuple(slx)][tuple(sly)]

# ------------------------------------------------------------
# 2) Wavenumbers e operatori spettrali su griglia estesa
# ------------------------------------------------------------
def _build_kxy(Sx, Sy, device):
    """
    Ritorna kx, ky (float) di shape (Sx, Sy) per FFT periodica su griglia Sx,Sy.
    """
    kx = torch.fft.fftfreq(Sx, d=1.0, device=device)  # [0,1/Sx,...,-1/Sx]
    ky = torch.fft.fftfreq(Sy, d=1.0, device=device)
    kx = kx.view(Sx, 1).expand(Sx, Sy)
    ky = ky.view(1, Sy).expand(Sx, Sy)
    # fattori 2π
    kx = (2.0*math.pi) * kx
    ky = (2.0*math.pi) * ky
    return kx, ky

def _dealias_23(mask_shape, device):
    """
    Maschera 2/3 classica per antialiasing (sfera rettangolare).
    """
    Sx, Sy = mask_shape
    cx = Sx//2
    cy = Sy//2
    kx = torch.fft.fftfreq(Sx, d=1.0, device=device).abs()
    ky = torch.fft.fftfreq(Sy, d=1.0, device=device).abs()
    # cutoff = 1/3 in frequenza normale (⇒ 2/3 dei modes tenuti)
    cutoff_x = (1.0/3.0)
    cutoff_y = (1.0/3.0)
    mx = (kx <= cutoff_x).view(Sx, 1).expand(Sx, Sy)
    my = (ky <= cutoff_y).view(1, Sy).expand(Sx, Sy)
    return (mx & my)

def _spectral_derivatives_on_extended(f_ext, dealias=True):
    """
    f_ext: (B, SxE, SyE) campo scalare su griglia ESTESA (già periodica per costruzione)
    Ritorna: fx_ext, fy_ext, lap_ext (stesse shape)
    """
    B, SxE, SyE = f_ext.shape
    device = f_ext.device

    kx, ky = _build_kxy(SxE, SyE, device)               # (SxE, SyE)
    k2 = kx**2 + ky**2
    k2[0,0] = 1.0  # evita div/0 quando serve

    F = torch.fft.fftn(f_ext, dim=(-2, -1))             # (B, SxE, SyE)
    if dealias:
        mask = _dealias_23((SxE, SyE), device)          # bool
        F = F * mask                                   # broadcasting su B

    Fx = (1j * kx) * F
    Fy = (1j * ky) * F
    Flap = -(k2) * F

    fx_ext  = torch.fft.ifftn(Fx,   dim=(-2, -1)).real
    fy_ext  = torch.fft.ifftn(Fy,   dim=(-2, -1)).real
    lap_ext = torch.fft.ifftn(Flap, dim=(-2, -1)).real
    return fx_ext, fy_ext, lap_ext

# ------------------------------------------------------------
# 3) Operatori differenziali per (u,v,p) con FC automatica
# ------------------------------------------------------------
def spectral_ops_vp_fc(u, v, p, m: int=12, dealias: bool=True):
    """
    Calcola operatori differenziali per Navier-Stokes in forma (u,v,p)
    usando Fourier continuation (even-reflection) e derivate spettrali.

    Input:
      u,v,p: (B, Sx, Sy)  tensors
      m: spessore banda FC (celle per lato)
      dealias: applica o meno maschera 2/3 in Fourier

    Output: dict con
      ux, uy, vx, vy,         # derivate prime
      lap_u, lap_v,           # Laplaciani
      div_u,                  # divergenza
      px, py,                 # gradiente pressione
      convx, convy,           # (u·∇)u componenti
      interior_mask           # (1,Sx,Sy) True nell'interno (esclude banda FC)
    """
    assert u.shape == v.shape == p.shape
    B, Sx, Sy = u.shape
    device = u.device

    # 3.1 FC padding per ciascun canale
    u_ext = fc_pad2d_even(u, m)   # (B, Sx+2m, Sy+2m)
    v_ext = fc_pad2d_even(v, m)
    p_ext = fc_pad2d_even(p, m)

    # 3.2 Derivate spettrali su esteso
    ux_ext, uy_ext, lap_u_ext = _spectral_derivatives_on_extended(u_ext, dealias=dealias)
    vx_ext, vy_ext, lap_v_ext = _spectral_derivatives_on_extended(v_ext, dealias=dealias)
    px_ext, py_ext, _         = _spectral_derivatives_on_extended(p_ext, dealias=dealias)

    # 3.3 Crop centrale (tornare alla griglia originale)
    ux   = center_crop2d(ux_ext,   m)
    uy   = center_crop2d(uy_ext,   m)
    vx   = center_crop2d(vx_ext,   m)
    vy   = center_crop2d(vy_ext,   m)
    lap_u= center_crop2d(lap_u_ext,m)
    lap_v= center_crop2d(lap_v_ext,m)
    px   = center_crop2d(px_ext,   m)
    py   = center_crop2d(py_ext,   m)

    # 3.4 Divergenza e convettivo (sulla griglia originale)
    div_u = ux + vy
    convx = u * ux + v * uy
    convy = u * vx + v * vy

    # 3.5 Maschera interno (True solo lontano dai bordi fisici)
    interior_mask = torch.zeros(1, Sx, Sy, dtype=torch.bool, device=device)
    interior_mask[:, m:Sx-m, m:Sy-m] = True

    return {
        'ux': ux, 'uy': uy, 'vx': vx, 'vy': vy,
        'lap_u': lap_u, 'lap_v': lap_v,
        'div_u': div_u,
        'px': px, 'py': py,
        'convx': convx, 'convy': convy,
        'interior_mask': interior_mask
    }

# %%
################################################################
# training and evaluation
################################################################
# Parametri\ 

ntrain      = 1

modes       = 24
width       = 64


batch_size  = 1
epochs      = 100

learning_rate   = 2e-3
scheduler_step  = 20
scheduler_gamma = 0.5


step        = 1

rf          = 8
orders_v    = [2,2]
n_samples   = 4
model = Net2d(modes, width).cuda()
# model = torch.load('model/ns_fourier_V100_N1000_ep100_m8_w10')

print(model.count_params())
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=scheduler_gamma)


myloss = LpLoss(size_average=False)

test_full = []

path = f'FNO_One_Stage_ep{epochs}_m{modes}_w{width}_T{T}'

path_model     = os.path.join('model',  path)
path_image     = os.path.join('image',  path)
path_loss_dir  = os.path.join('loss',   path)
os.makedirs(path_image, exist_ok=True)
os.makedirs(path_loss_dir, exist_ok=True)
os.makedirs(os.path.dirname(path_model), exist_ok=True)
# ============================
# Training loop robusto a T lunghi
# ============================

import numpy as np
import torch

# ---- impostazioni autoregressione / stabilità ----
predict_delta   = False     # True: modello predice Δ; False: predice stato assoluto
use_detach      = True     # stacca il gradiente quando reinserisci la predizione in finestra
time_weighting  = True     # pesa di più gli step temporali lontani
noise_std       = 0.0      # es. 0.01 se lavori con canali normalizzati (std~1). 0.0 = off
grad_clip       = 1.0      # clipping del gradiente (None o 0.0 per disattivare)

# ---- scheduled sampling con "pavimento" ----
tf_max = 1.0
tf_min = 0.10                   # non scendere mai sotto il 10% di teacher forcing
warm   = int(0.6 * 200)      # epoche su cui far decrescere p GT -> tf_min

def get_tf_ratio(ep):
    # Cosine decay da 1.0 a tf_min durante il warmup
    x = min(1.0, ep / max(1, warm))
    # 0 -> 1: cos decresce da 1 a -1
    return float(tf_min + 0.5*(tf_max - tf_min)*(1.0 + torch.cos(torch.tensor(np.pi*x)).item()))

def make_boundary_mask(Sx, Sy, thickness=1, device='cuda'):
    bm = torch.zeros(1, Sx, Sy, 1, device=device)
    t = int(thickness)
    bm[:, :t, :, :]  = 1;  bm[:, -t:, :, :] = 1
    bm[:, :, :t, :]  = 1;  bm[:, :, -t:, :] = 1
    return bm  # shape (1,Sx,Sy,1)

C = 3  # (u,v,p) per passo
# Out:
# 37774979

# %%
nu = 0.01
dt = 0.1

lambda_res = 1.0      # peso della residual loss (tuning a piacere)
beta_div   = 1.0      # peso del vincolo di incomprimibilità
m_fc       = 2       # spessore banda Fourier continuation

C = 3
# Pesi per fase (modifica liberamente)
PHASES = [
    {
        'name': 'P1_border_only',
        'epochs':200,
        'lambda_bd': 1.0,
        'lambda_res': 1.0,
        'record': False

    }
    # {
    #     'name': 'P2_res_warm',
    #     'epochs': 200,
    #     'lambda_bd': 1.0,
    #     'lambda_res': 0.5,
    #     'record': True
    # }
]

for iph, phase in enumerate(PHASES, 1):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=0.5)

    lambda_bd  = phase['lambda_bd']
    lambda_res = phase['lambda_res']

    print(f"\n===== Phase {iph}/{len(PHASES)}: {phase['name']}  (epochs={phase['epochs']}) =====")
    print(f"lambdas → bd:{lambda_bd}  res:{lambda_res}")

    boundary_loss, full_loss, res_loss = [], [], []

    # usa le epoche della fase
    for ep in range(phase['epochs']):
        model.train()
        t_start = default_timer()

        # accumulatori epoca
        train_l2_step = 0.0           # loss totale per step (tutte le componenti)
        train_l2_full = 0.0           # L2 full-sequence (monitoring)
        train_bd_step = 0.0           # supervisione bordo (u,v)
        train_p_step  = 0.0           # supervisione pressione full
        train_res_step = 0.0          # residual loss

        tf_ratio = get_tf_ratio(ep)

        for xx, yy in train_loader:
            xx = xx.to(device, dtype=torch.float32)  # (B,Sx,Sy, 2 + 3*T_in)
            yy = yy.to(device, dtype=torch.float32)  # (B,Sx,Sy, 3*T)

            B, Sx, Sy = xx.shape[0], xx.shape[1], xx.shape[2]
            bd_mask = make_boundary_mask(Sx, Sy, thickness=1, device=xx.device)  # (1,Sx,Sy,1)

            loss = 0.0
            preds = []

            # accumulatori per QUESTO batch (sommati sui T step)
            sum_bd_batch = 0.0
            sum_p_batch  = 0.0
            sum_res_batch = 0.0

            for t in range(T):
                # target (u_{t+1}, v_{t+1}, p_{t+1})
                y  = yy[..., C*t : C*(t+1)]                          # (B,Sx,Sy,3)

                # predizione
                if predict_delta:
                    base = xx[..., -C:]                              # (u_t,v_t,p_t)
                    delta = model(xx)                                # (Δu,Δv,Δp)
                    im = base + delta                                # (u_{t+1}, v_{t+1}, p_{t+1})
                else:
                    im = model(xx)

                preds.append(im)

                # ====== RESIDUAL NS (valutata su stato t) ======
                state_t = xx[..., -C:]                        # (u_t, v_t, p_t)
                u_t = state_t[..., 0]
                v_t = state_t[..., 1]
                p_t = state_t[..., 2]

                # derivate spaziali con FC+FFT
                ops = spectral_ops_vp_fc(u_t, v_t, p_t, m=m_fc, dealias=True)

                # derivate temporali (forward diff)
                dudt = (im[..., 0] - u_t) / dt
                dvdt = (im[..., 1] - v_t) / dt

                # residui (senza forcing)
                rx   = dudt + ops['convx'] + ops['px'] - nu * ops['lap_u']
                ry   = dvdt + ops['convy'] + ops['py'] - nu * ops['lap_v']
                rinc = ops['div_u']

                # loss residua mascherata (solo interno, esclusa banda FC)
                interior_mask = ops['interior_mask'].float().expand(B, -1, -1)  # (B,Sx,Sy)

                def masked_mse(field, mask):
                    num = ((field**2) * mask).sum()
                    den = mask.sum().clamp_min(1.0)
                    return num / den

                loss_res_t = masked_mse(rx, interior_mask) \
                           + masked_mse(ry, interior_mask) \
                           + beta_div * masked_mse(rinc, interior_mask)

                # ====== SUPERVISIONE DATI ======
                # u,v SOLO al bordo
                im_vel_bd = im[..., :2] * bd_mask              # (B,Sx,Sy,2)
                y_vel_bd  = y[...,  :2] * bd_mask
                loss_bd_t = myloss(im_vel_bd.reshape(B, -1), y_vel_bd.reshape(B, -1))

                # p su TUTTO il dominio
                im_p = im[..., 2]                               # (B,Sx,Sy)
                y_p  = y[...,  2]
                loss_p_t = myloss(im_p.reshape(B, -1), y_p.reshape(B, -1))

                # somma alla loss totale con i pesi di fase
                loss = loss + lambda_res * loss_res_t + lambda_bd * (loss_bd_t + loss_p_t)

                # ====== scheduled sampling / feed finestra ======
                if torch.rand(1, device=device) < tf_ratio:
                    feed = y
                else:
                    feed = im.detach() if use_detach else im

                if noise_std and noise_std > 0.0:
                    feed = feed + noise_std*torch.randn_like(feed)

                xy   = xx[..., :2]
                hist = xx[..., 2:]
                hist = torch.cat([hist[..., C:], feed], dim=-1)   # sposta la finestra e aggiunge feed
                xx   = torch.cat([xy, hist], dim=-1)

                # ---- accumula per-step (batch) ----
                sum_bd_batch  += loss_bd_t.item()
                sum_p_batch   += loss_p_t.item()
                sum_res_batch += loss_res_t.item()

            # ---- metriche full-sequence ----
            pred_seq = torch.cat(preds, dim=-1)                        # (B,Sx,Sy, 3*T)
            train_l2_full += myloss(pred_seq.reshape(B, -1), yy.reshape(B, -1)).item()

            # ---- accumula su epoca ----
            train_l2_step += loss.item()
            train_bd_step += sum_bd_batch
            train_p_step  += sum_p_batch
            train_res_step += sum_res_batch

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            if grad_clip and grad_clip > 0.0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            optimizer.step()

        scheduler.step()
        elapsed = default_timer() - t_start
        denom_steps = T * len(train_loader)

        print(f"[Phase {iph}:{phase['name']}] Ep {ep+1:3d}/{phase['epochs']} │ "
              f"Time: {elapsed:6.2f}s │ "
              f"Train step BD(u,v): {train_bd_step/denom_steps:8.4e} │ "
              f"Train step P(full): {train_p_step/denom_steps:8.4e} │ "
              f"Train step RES: {train_res_step/denom_steps:8.4e} │ "
              f"Train step TOTAL: {train_l2_step/denom_steps:8.4e} │ "
              f"Train full L2: {train_l2_full/len(train_loader):8.4e} │ ")

        # salva serie per plotting
        boundary_loss.append(train_bd_step/denom_steps)                     # solo (u,v) bordo
        full_loss.append(train_l2_full/len(train_loader))
        if phase['record']:
            res_loss.append(train_res_step/denom_steps)

    idx = list(range(1, phase['epochs']+1))
    data = {
        'loss_boundary':   boundary_loss,
        'loss_full': full_loss,
    }
    if phase['record']:
        data['loss_res'] = res_loss
    df = pd.DataFrame(data, index=idx)
    df.index.name = 'epoch_in_phase'
    csv_path = os.path.join(path_loss_dir, f"loss_{phase['name']}.csv")
    df.to_csv(csv_path)
    print(f"→ Saved loss history for phase '{phase['name']}' in {csv_path}")
# Out:
# ===== Phase 1/1: P1_border_only  (epochs=200) =====
# lambdas → bd:1.0  res:1.0
# [Phase 1:P1_border_only] Ep   1/200 │ Time:   0.56s │ Train step BD(u,v): 1.0225e+00 │ Train step P(full): 1.3251e+00 │ Train step RES: 1.0065e+02 │ Train step TOTAL: 1.0300e+02 │ Train full L2: 1.0763e+00 │
# [Phase 1:P1_border_only] Ep   2/200 │ Time:   0.20s │ Train step BD(u,v): 1.0363e+00 │ Train step P(full): 1.3755e+00 │ Train step RES: 7.6178e+01 │ Train step TOTAL: 7.8590e+01 │ Train full L2: 9.7125e-01 │
# [Phase 1:P1_border_only] Ep   3/200 │ Time:   0.22s │ Train step BD(u,v): 1.0475e+00 │ Train step P(full): 1.4711e+00 │ Train step RES: 5.8979e+01 │ Train step TOTAL: 6.1497e+01 │ Train full L2: 8.9373e-01 │
# [Phase 1:P1_border_only] Ep   4/200 │ Time:   0.23s │ Train step BD(u,v): 1.0587e+00 │ Train step P(full): 1.5379e+00 │ Train step RES: 4.7168e+01 │ Train step TOTAL: 4.9765e+01 │ Train full L2: 8.3754e-01 │
# [Phase 1:P1_border_only] Ep   5/200 │ Time:   0.23s │ Train step BD(u,v): 1.0681e+00 │ Train step P(full): 1.5646e+00 │ Train step RES: 3.8746e+01 │ Train step TOTAL: 4.1379e+01 │ Train full L2: 7.9461e-01 │
# [Phase 1:P1_border_only] Ep   6/200 │ Time:   0.22s │ Train step BD(u,v): 1.0768e+00 │ Train step P(full): 1.5642e+00 │ Train step RES: 3.2307e+01 │ Train step TOTAL: 3.4948e+01 │ Train full L2: 7.5963e-01 │
# [Phase 1:P1_border_only] Ep   7/200 │ Time:   0.22s │ Train step BD(u,v): 1.0860e+00 │ Train step P(full): 1.5513e+00 │ Train step RES: 2.6996e+01 │ Train step TOTAL: 2.9633e+01 │ Train full L2: 7.2969e-01 │
# [Phase 1:P1_border_only] Ep   8/200 │ Time:   0.22s │ Train step BD(u,v): 1.0960e+00 │ Train step P(full): 1.5333e+00 │ Train step RES: 2.2437e+01 │ Train step TOTAL: 2.5066e+01 │ Train full L2: 7.0327e-01 │
# [Phase 1:P1_border_only] Ep   9/200 │ Time:   0.23s │ Train step BD(u,v): 1.1060e+00 │ Train step P(full): 1.5133e+00 │ Train step RES: 1.8508e+01 │ Train step TOTAL: 2.1127e+01 │ Train full L2: 6.7999e-01 │
# [Phase 1:P1_border_only] Ep  10/200 │ Time:   0.24s │ Train step BD(u,v): 1.1159e+00 │ Train step P(full): 1.4935e+00 │ Train step RES: 1.5136e+01 │ Train step TOTAL: 1.7746e+01 │ Train full L2: 6.6010e-01 │
# [Phase 1:P1_border_only] Ep  11/200 │ Time:   0.22s │ Train step BD(u,v): 1.1267e+00 │ Train step P(full): 1.4731e+00 │ Train step RES: 1.2241e+01 │ Train step TOTAL: 1.4841e+01 │ Train full L2: 6.4337e-01 │
# [Phase 1:P1_border_only] Ep  12/200 │ Time:   0.22s │ Train step BD(u,v): 1.1378e+00 │ Train step P(full): 1.4488e+00 │ Train step RES: 9.7657e+00 │ Train step TOTAL: 1.2352e+01 │ Train full L2: 6.2934e-01 │
# [Phase 1:P1_border_only] Ep  13/200 │ Time:   0.22s │ Train step BD(u,v): 1.1478e+00 │ Train step P(full): 1.4210e+00 │ Train step RES: 7.6778e+00 │ Train step TOTAL: 1.0247e+01 │ Train full L2: 6.1762e-01 │
# [Phase 1:P1_border_only] Ep  14/200 │ Time:   0.22s │ Train step BD(u,v): 1.1561e+00 │ Train step P(full): 1.3892e+00 │ Train step RES: 5.9274e+00 │ Train step TOTAL: 8.4727e+00 │ Train full L2: 6.0781e-01 │
# [Phase 1:P1_border_only] Ep  15/200 │ Time:   0.23s │ Train step BD(u,v): 1.1617e+00 │ Train step P(full): 1.3536e+00 │ Train step RES: 4.4688e+00 │ Train step TOTAL: 6.9840e+00 │ Train full L2: 5.9934e-01 │
# [Phase 1:P1_border_only] Ep  16/200 │ Time:   0.23s │ Train step BD(u,v): 1.1629e+00 │ Train step P(full): 1.3105e+00 │ Train step RES: 3.2794e+00 │ Train step TOTAL: 5.7528e+00 │ Train full L2: 5.9138e-01 │
# [Phase 1:P1_border_only] Ep  17/200 │ Time:   0.22s │ Train step BD(u,v): 1.1539e+00 │ Train step P(full): 1.2626e+00 │ Train step RES: 2.5344e+00 │ Train step TOTAL: 4.9509e+00 │ Train full L2: 5.8515e-01 │
# [Phase 1:P1_border_only] Ep  18/200 │ Time:   0.22s │ Train step BD(u,v): 1.1453e+00 │ Train step P(full): 1.2001e+00 │ Train step RES: 1.6316e+00 │ Train step TOTAL: 3.9771e+00 │ Train full L2: 5.7448e-01 │
# [Phase 1:P1_border_only] Ep  19/200 │ Time:   0.22s │ Train step BD(u,v): 1.1170e+00 │ Train step P(full): 1.1383e+00 │ Train step RES: 1.6560e+00 │ Train step TOTAL: 3.9113e+00 │ Train full L2: 5.6554e-01 │
# [Phase 1:P1_border_only] Ep  20/200 │ Time:   0.22s │ Train step BD(u,v): 1.0920e+00 │ Train step P(full): 1.0647e+00 │ Train step RES: 1.1630e+00 │ Train step TOTAL: 3.3196e+00 │ Train full L2: 5.5375e-01 │
# [Phase 1:P1_border_only] Ep  21/200 │ Time:   0.22s │ Train step BD(u,v): 1.0643e+00 │ Train step P(full): 9.8547e-01 │ Train step RES: 6.4717e-01 │ Train step TOTAL: 2.6969e+00 │ Train full L2: 5.4465e-01 │
# [Phase 1:P1_border_only] Ep  22/200 │ Time:   0.22s │ Train step BD(u,v): 1.0419e+00 │ Train step P(full): 9.4197e-01 │ Train step RES: 5.3094e-01 │ Train step TOTAL: 2.5148e+00 │ Train full L2: 5.3768e-01 │
# [Phase 1:P1_border_only] Ep  23/200 │ Time:   0.22s │ Train step BD(u,v): 1.0152e+00 │ Train step P(full): 8.8899e-01 │ Train step RES: 4.9101e-01 │ Train step TOTAL: 2.3952e+00 │ Train full L2: 5.2845e-01 │
# [Phase 1:P1_border_only] Ep  24/200 │ Time:   0.22s │ Train step BD(u,v): 9.7638e-01 │ Train step P(full): 8.1736e-01 │ Train step RES: 3.4689e-01 │ Train step TOTAL: 2.1406e+00 │ Train full L2: 5.1772e-01 │
# [Phase 1:P1_border_only] Ep  25/200 │ Time:   0.23s │ Train step BD(u,v): 9.3603e-01 │ Train step P(full): 7.3261e-01 │ Train step RES: 3.9903e-01 │ Train step TOTAL: 2.0677e+00 │ Train full L2: 5.0419e-01 │
# [Phase 1:P1_border_only] Ep  26/200 │ Time:   0.22s │ Train step BD(u,v): 8.8414e-01 │ Train step P(full): 6.3408e-01 │ Train step RES: 2.8785e-01 │ Train step TOTAL: 1.8061e+00 │ Train full L2: 4.9030e-01 │
# [Phase 1:P1_border_only] Ep  27/200 │ Time:   0.22s │ Train step BD(u,v): 8.3448e-01 │ Train step P(full): 5.3743e-01 │ Train step RES: 2.6477e-01 │ Train step TOTAL: 1.6367e+00 │ Train full L2: 4.7582e-01 │
# [Phase 1:P1_border_only] Ep  28/200 │ Time:   0.22s │ Train step BD(u,v): 7.8487e-01 │ Train step P(full): 4.4798e-01 │ Train step RES: 2.4747e-01 │ Train step TOTAL: 1.4803e+00 │ Train full L2: 4.6184e-01 │
# [Phase 1:P1_border_only] Ep  29/200 │ Time:   0.22s │ Train step BD(u,v): 7.4113e-01 │ Train step P(full): 3.8313e-01 │ Train step RES: 2.6488e-01 │ Train step TOTAL: 1.3891e+00 │ Train full L2: 4.4980e-01 │
# [Phase 1:P1_border_only] Ep  30/200 │ Time:   0.22s │ Train step BD(u,v): 6.9596e-01 │ Train step P(full): 3.3163e-01 │ Train step RES: 2.6287e-01 │ Train step TOTAL: 1.2905e+00 │ Train full L2: 4.3805e-01 │
# [Phase 1:P1_border_only] Ep  31/200 │ Time:   0.22s │ Train step BD(u,v): 6.5295e-01 │ Train step P(full): 2.9568e-01 │ Train step RES: 2.3930e-01 │ Train step TOTAL: 1.1879e+00 │ Train full L2: 4.2774e-01 │
# [Phase 1:P1_border_only] Ep  32/200 │ Time:   0.22s │ Train step BD(u,v): 6.1062e-01 │ Train step P(full): 2.7214e-01 │ Train step RES: 2.1584e-01 │ Train step TOTAL: 1.0986e+00 │ Train full L2: 4.1837e-01 │
# [Phase 1:P1_border_only] Ep  33/200 │ Time:   0.22s │ Train step BD(u,v): 5.6971e-01 │ Train step P(full): 2.5365e-01 │ Train step RES: 1.9124e-01 │ Train step TOTAL: 1.0146e+00 │ Train full L2: 4.1002e-01 │
# [Phase 1:P1_border_only] Ep  34/200 │ Time:   0.22s │ Train step BD(u,v): 5.3028e-01 │ Train step P(full): 2.3542e-01 │ Train step RES: 1.7343e-01 │ Train step TOTAL: 9.3913e-01 │ Train full L2: 4.0225e-01 │
# [Phase 1:P1_border_only] Ep  35/200 │ Time:   0.22s │ Train step BD(u,v): 4.9583e-01 │ Train step P(full): 2.2660e-01 │ Train step RES: 1.7767e-01 │ Train step TOTAL: 9.0010e-01 │ Train full L2: 3.9630e-01 │
# [Phase 1:P1_border_only] Ep  36/200 │ Time:   0.22s │ Train step BD(u,v): 4.4916e-01 │ Train step P(full): 1.8062e-01 │ Train step RES: 1.2360e-01 │ Train step TOTAL: 7.5338e-01 │ Train full L2: 3.8742e-01 │
# [Phase 1:P1_border_only] Ep  37/200 │ Time:   0.22s │ Train step BD(u,v): 4.0911e-01 │ Train step P(full): 1.6372e-01 │ Train step RES: 1.0515e-01 │ Train step TOTAL: 6.7797e-01 │ Train full L2: 3.8077e-01 │
# [Phase 1:P1_border_only] Ep  38/200 │ Time:   0.22s │ Train step BD(u,v): 3.7021e-01 │ Train step P(full): 1.6563e-01 │ Train step RES: 1.0423e-01 │ Train step TOTAL: 6.4007e-01 │ Train full L2: 3.7514e-01 │
# [Phase 1:P1_border_only] Ep  39/200 │ Time:   0.22s │ Train step BD(u,v): 3.2916e-01 │ Train step P(full): 1.7000e-01 │ Train step RES: 9.7722e-02 │ Train step TOTAL: 5.9689e-01 │ Train full L2: 3.6968e-01 │
# [Phase 1:P1_border_only] Ep  40/200 │ Time:   0.23s │ Train step BD(u,v): 2.8813e-01 │ Train step P(full): 1.5729e-01 │ Train step RES: 1.0066e-01 │ Train step TOTAL: 5.4609e-01 │ Train full L2: 3.6378e-01 │
# [Phase 1:P1_border_only] Ep  41/200 │ Time:   0.22s │ Train step BD(u,v): 2.5013e-01 │ Train step P(full): 1.4581e-01 │ Train step RES: 1.0156e-01 │ Train step TOTAL: 4.9749e-01 │ Train full L2: 3.5944e-01 │
# [Phase 1:P1_border_only] Ep  42/200 │ Time:   0.22s │ Train step BD(u,v): 2.3061e-01 │ Train step P(full): 1.3029e-01 │ Train step RES: 8.2709e-02 │ Train step TOTAL: 4.4360e-01 │ Train full L2: 3.5569e-01 │
# [Phase 1:P1_border_only] Ep  43/200 │ Time:   0.23s │ Train step BD(u,v): 2.1373e-01 │ Train step P(full): 1.2382e-01 │ Train step RES: 7.4862e-02 │ Train step TOTAL: 4.1240e-01 │ Train full L2: 3.5373e-01 │
# [Phase 1:P1_border_only] Ep  44/200 │ Time:   0.23s │ Train step BD(u,v): 1.9766e-01 │ Train step P(full): 1.2713e-01 │ Train step RES: 7.4428e-02 │ Train step TOTAL: 3.9922e-01 │ Train full L2: 3.5274e-01 │
# [Phase 1:P1_border_only] Ep  45/200 │ Time:   0.22s │ Train step BD(u,v): 1.8046e-01 │ Train step P(full): 1.0934e-01 │ Train step RES: 6.1366e-02 │ Train step TOTAL: 3.5117e-01 │ Train full L2: 3.4989e-01 │
# [Phase 1:P1_border_only] Ep  46/200 │ Time:   0.22s │ Train step BD(u,v): 1.6484e-01 │ Train step P(full): 1.2200e-01 │ Train step RES: 7.0627e-02 │ Train step TOTAL: 3.5747e-01 │ Train full L2: 3.5041e-01 │
# [Phase 1:P1_border_only] Ep  47/200 │ Time:   0.22s │ Train step BD(u,v): 1.4869e-01 │ Train step P(full): 1.0630e-01 │ Train step RES: 5.7150e-02 │ Train step TOTAL: 3.1215e-01 │ Train full L2: 3.4806e-01 │
# [Phase 1:P1_border_only] Ep  48/200 │ Time:   0.22s │ Train step BD(u,v): 1.3412e-01 │ Train step P(full): 9.5262e-02 │ Train step RES: 5.4590e-02 │ Train step TOTAL: 2.8397e-01 │ Train full L2: 3.4519e-01 │
# [Phase 1:P1_border_only] Ep  49/200 │ Time:   0.22s │ Train step BD(u,v): 1.2523e-01 │ Train step P(full): 1.1249e-01 │ Train step RES: 6.5089e-02 │ Train step TOTAL: 3.0280e-01 │ Train full L2: 3.4875e-01 │
# [Phase 1:P1_border_only] Ep  50/200 │ Time:   0.22s │ Train step BD(u,v): 1.1340e-01 │ Train step P(full): 9.7111e-02 │ Train step RES: 5.7889e-02 │ Train step TOTAL: 2.6840e-01 │ Train full L2: 3.4492e-01 │
# [Phase 1:P1_border_only] Ep  51/200 │ Time:   0.22s │ Train step BD(u,v): 1.0838e-01 │ Train step P(full): 1.2293e-01 │ Train step RES: 4.9177e-02 │ Train step TOTAL: 2.8048e-01 │ Train full L2: 3.5131e-01 │
# [Phase 1:P1_border_only] Ep  52/200 │ Time:   0.22s │ Train step BD(u,v): 1.0223e-01 │ Train step P(full): 9.9922e-02 │ Train step RES: 6.2621e-02 │ Train step TOTAL: 2.6477e-01 │ Train full L2: 3.4502e-01 │
# [Phase 1:P1_border_only] Ep  53/200 │ Time:   0.22s │ Train step BD(u,v): 9.7009e-02 │ Train step P(full): 9.4596e-02 │ Train step RES: 6.1334e-02 │ Train step TOTAL: 2.5294e-01 │ Train full L2: 3.4192e-01 │
# [Phase 1:P1_border_only] Ep  54/200 │ Time:   0.22s │ Train step BD(u,v): 9.1258e-02 │ Train step P(full): 8.7779e-02 │ Train step RES: 5.3809e-02 │ Train step TOTAL: 2.3285e-01 │ Train full L2: 3.4115e-01 │
# [Phase 1:P1_border_only] Ep  55/200 │ Time:   0.21s │ Train step BD(u,v): 8.4226e-02 │ Train step P(full): 7.7013e-02 │ Train step RES: 5.1449e-02 │ Train step TOTAL: 2.1269e-01 │ Train full L2: 3.3594e-01 │
# [Phase 1:P1_border_only] Ep  56/200 │ Time:   0.22s │ Train step BD(u,v): 8.2126e-02 │ Train step P(full): 9.6231e-02 │ Train step RES: 4.7747e-02 │ Train step TOTAL: 2.2610e-01 │ Train full L2: 3.4136e-01 │
# [Phase 1:P1_border_only] Ep  57/200 │ Time:   0.22s │ Train step BD(u,v): 7.5196e-02 │ Train step P(full): 7.5672e-02 │ Train step RES: 5.0509e-02 │ Train step TOTAL: 2.0138e-01 │ Train full L2: 3.3449e-01 │
# [Phase 1:P1_border_only] Ep  58/200 │ Time:   0.22s │ Train step BD(u,v): 6.9961e-02 │ Train step P(full): 6.9223e-02 │ Train step RES: 4.3370e-02 │ Train step TOTAL: 1.8255e-01 │ Train full L2: 3.3029e-01 │
# [Phase 1:P1_border_only] Ep  59/200 │ Time:   0.21s │ Train step BD(u,v): 6.8594e-02 │ Train step P(full): 8.0511e-02 │ Train step RES: 4.5662e-02 │ Train step TOTAL: 1.9477e-01 │ Train full L2: 3.3400e-01 │
# [Phase 1:P1_border_only] Ep  60/200 │ Time:   0.22s │ Train step BD(u,v): 6.2151e-02 │ Train step P(full): 8.1321e-02 │ Train step RES: 4.1748e-02 │ Train step TOTAL: 1.8522e-01 │ Train full L2: 3.3427e-01 │
# [Phase 1:P1_border_only] Ep  61/200 │ Time:   0.22s │ Train step BD(u,v): 6.0315e-02 │ Train step P(full): 1.0828e-01 │ Train step RES: 4.0099e-02 │ Train step TOTAL: 2.0869e-01 │ Train full L2: 3.4282e-01 │
# [Phase 1:P1_border_only] Ep  62/200 │ Time:   0.22s │ Train step BD(u,v): 5.4155e-02 │ Train step P(full): 6.8693e-02 │ Train step RES: 3.9023e-02 │ Train step TOTAL: 1.6187e-01 │ Train full L2: 3.2756e-01 │
# [Phase 1:P1_border_only] Ep  63/200 │ Time:   0.23s │ Train step BD(u,v): 5.5592e-02 │ Train step P(full): 7.0999e-02 │ Train step RES: 4.0551e-02 │ Train step TOTAL: 1.6714e-01 │ Train full L2: 3.2806e-01 │
# [Phase 1:P1_border_only] Ep  64/200 │ Time:   0.23s │ Train step BD(u,v): 5.0305e-02 │ Train step P(full): 6.7199e-02 │ Train step RES: 3.4590e-02 │ Train step TOTAL: 1.5209e-01 │ Train full L2: 3.2458e-01 │
# [Phase 1:P1_border_only] Ep  65/200 │ Time:   0.22s │ Train step BD(u,v): 4.7282e-02 │ Train step P(full): 6.2979e-02 │ Train step RES: 3.3750e-02 │ Train step TOTAL: 1.4401e-01 │ Train full L2: 3.2413e-01 │
# [Phase 1:P1_border_only] Ep  66/200 │ Time:   0.23s │ Train step BD(u,v): 4.7985e-02 │ Train step P(full): 7.5558e-02 │ Train step RES: 3.4646e-02 │ Train step TOTAL: 1.5819e-01 │ Train full L2: 3.3055e-01 │
# [Phase 1:P1_border_only] Ep  67/200 │ Time:   0.23s │ Train step BD(u,v): 5.0398e-02 │ Train step P(full): 8.7771e-02 │ Train step RES: 3.8661e-02 │ Train step TOTAL: 1.7683e-01 │ Train full L2: 3.3569e-01 │
# [Phase 1:P1_border_only] Ep  68/200 │ Time:   0.22s │ Train step BD(u,v): 4.2731e-02 │ Train step P(full): 5.9568e-02 │ Train step RES: 3.4076e-02 │ Train step TOTAL: 1.3638e-01 │ Train full L2: 3.2300e-01 │
# [Phase 1:P1_border_only] Ep  69/200 │ Time:   0.23s │ Train step BD(u,v): 4.5661e-02 │ Train step P(full): 7.4719e-02 │ Train step RES: 3.8072e-02 │ Train step TOTAL: 1.5845e-01 │ Train full L2: 3.3258e-01 │
# [Phase 1:P1_border_only] Ep  70/200 │ Time:   0.22s │ Train step BD(u,v): 4.2760e-02 │ Train step P(full): 8.1276e-02 │ Train step RES: 3.3229e-02 │ Train step TOTAL: 1.5727e-01 │ Train full L2: 3.3248e-01 │
# [Phase 1:P1_border_only] Ep  71/200 │ Time:   0.23s │ Train step BD(u,v): 4.5495e-02 │ Train step P(full): 8.1597e-02 │ Train step RES: 3.7806e-02 │ Train step TOTAL: 1.6490e-01 │ Train full L2: 3.3529e-01 │
# [Phase 1:P1_border_only] Ep  72/200 │ Time:   0.22s │ Train step BD(u,v): 3.7325e-02 │ Train step P(full): 6.3912e-02 │ Train step RES: 3.1179e-02 │ Train step TOTAL: 1.3242e-01 │ Train full L2: 3.2649e-01 │
# [Phase 1:P1_border_only] Ep  73/200 │ Time:   0.23s │ Train step BD(u,v): 3.6550e-02 │ Train step P(full): 5.8496e-02 │ Train step RES: 3.3282e-02 │ Train step TOTAL: 1.2833e-01 │ Train full L2: 3.1791e-01 │
# [Phase 1:P1_border_only] Ep  74/200 │ Time:   0.22s │ Train step BD(u,v): 3.7275e-02 │ Train step P(full): 7.6041e-02 │ Train step RES: 3.4035e-02 │ Train step TOTAL: 1.4735e-01 │ Train full L2: 3.3547e-01 │
# [Phase 1:P1_border_only] Ep  75/200 │ Time:   0.22s │ Train step BD(u,v): 3.5021e-02 │ Train step P(full): 5.4553e-02 │ Train step RES: 3.2069e-02 │ Train step TOTAL: 1.2164e-01 │ Train full L2: 3.1966e-01 │
# [Phase 1:P1_border_only] Ep  76/200 │ Time:   0.23s │ Train step BD(u,v): 3.4400e-02 │ Train step P(full): 5.0762e-02 │ Train step RES: 3.0424e-02 │ Train step TOTAL: 1.1559e-01 │ Train full L2: 3.1734e-01 │
# [Phase 1:P1_border_only] Ep  77/200 │ Time:   0.22s │ Train step BD(u,v): 3.8595e-02 │ Train step P(full): 9.4064e-02 │ Train step RES: 3.4846e-02 │ Train step TOTAL: 1.6750e-01 │ Train full L2: 3.4494e-01 │
# [Phase 1:P1_border_only] Ep  78/200 │ Time:   0.22s │ Train step BD(u,v): 3.1758e-02 │ Train step P(full): 5.6882e-02 │ Train step RES: 3.2172e-02 │ Train step TOTAL: 1.2081e-01 │ Train full L2: 3.2298e-01 │
# [Phase 1:P1_border_only] Ep  79/200 │ Time:   0.22s │ Train step BD(u,v): 3.0326e-02 │ Train step P(full): 5.3945e-02 │ Train step RES: 3.1408e-02 │ Train step TOTAL: 1.1568e-01 │ Train full L2: 3.2174e-01 │
# [Phase 1:P1_border_only] Ep  80/200 │ Time:   0.24s │ Train step BD(u,v): 2.9689e-02 │ Train step P(full): 5.4029e-02 │ Train step RES: 2.8476e-02 │ Train step TOTAL: 1.1219e-01 │ Train full L2: 3.2193e-01 │
# [Phase 1:P1_border_only] Ep  81/200 │ Time:   0.22s │ Train step BD(u,v): 3.2757e-02 │ Train step P(full): 7.7610e-02 │ Train step RES: 3.1901e-02 │ Train step TOTAL: 1.4227e-01 │ Train full L2: 3.3904e-01 │
# [Phase 1:P1_border_only] Ep  82/200 │ Time:   0.23s │ Train step BD(u,v): 2.6748e-02 │ Train step P(full): 5.6624e-02 │ Train step RES: 2.5081e-02 │ Train step TOTAL: 1.0845e-01 │ Train full L2: 3.2245e-01 │
# [Phase 1:P1_border_only] Ep  83/200 │ Time:   0.23s │ Train step BD(u,v): 2.6941e-02 │ Train step P(full): 5.7308e-02 │ Train step RES: 2.8540e-02 │ Train step TOTAL: 1.1279e-01 │ Train full L2: 3.2548e-01 │
# [Phase 1:P1_border_only] Ep  84/200 │ Time:   0.23s │ Train step BD(u,v): 2.9005e-02 │ Train step P(full): 5.0954e-02 │ Train step RES: 3.1035e-02 │ Train step TOTAL: 1.1099e-01 │ Train full L2: 3.2579e-01 │
# [Phase 1:P1_border_only] Ep  85/200 │ Time:   0.23s │ Train step BD(u,v): 3.2400e-02 │ Train step P(full): 9.5398e-02 │ Train step RES: 3.2131e-02 │ Train step TOTAL: 1.5993e-01 │ Train full L2: 3.4720e-01 │
# [Phase 1:P1_border_only] Ep  86/200 │ Time:   0.23s │ Train step BD(u,v): 2.8036e-02 │ Train step P(full): 6.5433e-02 │ Train step RES: 3.0697e-02 │ Train step TOTAL: 1.2417e-01 │ Train full L2: 3.3628e-01 │
# [Phase 1:P1_border_only] Ep  87/200 │ Time:   0.23s │ Train step BD(u,v): 2.5556e-02 │ Train step P(full): 5.5988e-02 │ Train step RES: 2.8375e-02 │ Train step TOTAL: 1.0992e-01 │ Train full L2: 3.2651e-01 │
# [Phase 1:P1_border_only] Ep  88/200 │ Time:   0.24s │ Train step BD(u,v): 2.4389e-02 │ Train step P(full): 5.2591e-02 │ Train step RES: 2.6337e-02 │ Train step TOTAL: 1.0332e-01 │ Train full L2: 3.2316e-01 │
# [Phase 1:P1_border_only] Ep  89/200 │ Time:   0.23s │ Train step BD(u,v): 2.4178e-02 │ Train step P(full): 5.1264e-02 │ Train step RES: 2.6465e-02 │ Train step TOTAL: 1.0191e-01 │ Train full L2: 3.2309e-01 │
# [Phase 1:P1_border_only] Ep  90/200 │ Time:   0.23s │ Train step BD(u,v): 2.4731e-02 │ Train step P(full): 4.7844e-02 │ Train step RES: 3.0237e-02 │ Train step TOTAL: 1.0281e-01 │ Train full L2: 3.2297e-01 │
# [Phase 1:P1_border_only] Ep  91/200 │ Time:   0.22s │ Train step BD(u,v): 2.5465e-02 │ Train step P(full): 5.9970e-02 │ Train step RES: 2.9215e-02 │ Train step TOTAL: 1.1465e-01 │ Train full L2: 3.3284e-01 │
# [Phase 1:P1_border_only] Ep  92/200 │ Time:   0.22s │ Train step BD(u,v): 2.4682e-02 │ Train step P(full): 5.4407e-02 │ Train step RES: 3.0913e-02 │ Train step TOTAL: 1.1000e-01 │ Train full L2: 3.2626e-01 │
# [Phase 1:P1_border_only] Ep  93/200 │ Time:   0.22s │ Train step BD(u,v): 2.2911e-02 │ Train step P(full): 5.0106e-02 │ Train step RES: 2.8440e-02 │ Train step TOTAL: 1.0146e-01 │ Train full L2: 3.2477e-01 │
# [Phase 1:P1_border_only] Ep  94/200 │ Time:   0.22s │ Train step BD(u,v): 2.4351e-02 │ Train step P(full): 6.5238e-02 │ Train step RES: 2.9107e-02 │ Train step TOTAL: 1.1870e-01 │ Train full L2: 3.3699e-01 │
# [Phase 1:P1_border_only] Ep  95/200 │ Time:   0.22s │ Train step BD(u,v): 2.2283e-02 │ Train step P(full): 4.2410e-02 │ Train step RES: 2.8219e-02 │ Train step TOTAL: 9.2912e-02 │ Train full L2: 3.1646e-01 │
# [Phase 1:P1_border_only] Ep  96/200 │ Time:   0.22s │ Train step BD(u,v): 2.2874e-02 │ Train step P(full): 4.4676e-02 │ Train step RES: 2.8852e-02 │ Train step TOTAL: 9.6402e-02 │ Train full L2: 3.1826e-01 │
# [Phase 1:P1_border_only] Ep  97/200 │ Time:   0.22s │ Train step BD(u,v): 2.4509e-02 │ Train step P(full): 5.9633e-02 │ Train step RES: 2.8858e-02 │ Train step TOTAL: 1.1300e-01 │ Train full L2: 3.3588e-01 │
# [Phase 1:P1_border_only] Ep  98/200 │ Time:   0.22s │ Train step BD(u,v): 2.2833e-02 │ Train step P(full): 4.4828e-02 │ Train step RES: 2.9178e-02 │ Train step TOTAL: 9.6839e-02 │ Train full L2: 3.2432e-01 │
# [Phase 1:P1_border_only] Ep  99/200 │ Time:   0.23s │ Train step BD(u,v): 3.3015e-02 │ Train step P(full): 9.5305e-02 │ Train step RES: 3.3078e-02 │ Train step TOTAL: 1.6140e-01 │ Train full L2: 3.5288e-01 │
# [Phase 1:P1_border_only] Ep 100/200 │ Time:   0.22s │ Train step BD(u,v): 2.1345e-02 │ Train step P(full): 4.4477e-02 │ Train step RES: 2.8827e-02 │ Train step TOTAL: 9.4649e-02 │ Train full L2: 3.2335e-01 │
# [Phase 1:P1_border_only] Ep 101/200 │ Time:   0.22s │ Train step BD(u,v): 3.0979e-02 │ Train step P(full): 9.0682e-02 │ Train step RES: 2.9160e-02 │ Train step TOTAL: 1.5082e-01 │ Train full L2: 3.4637e-01 │
# [Phase 1:P1_border_only] Ep 102/200 │ Time:   0.23s │ Train step BD(u,v): 4.2798e-02 │ Train step P(full): 1.3436e-01 │ Train step RES: 3.2069e-02 │ Train step TOTAL: 2.0922e-01 │ Train full L2: 3.7510e-01 │
# [Phase 1:P1_border_only] Ep 103/200 │ Time:   0.22s │ Train step BD(u,v): 2.1847e-02 │ Train step P(full): 5.7685e-02 │ Train step RES: 2.7805e-02 │ Train step TOTAL: 1.0734e-01 │ Train full L2: 3.3659e-01 │
# [Phase 1:P1_border_only] Ep 104/200 │ Time:   0.22s │ Train step BD(u,v): 2.4195e-02 │ Train step P(full): 6.8094e-02 │ Train step RES: 2.7893e-02 │ Train step TOTAL: 1.2018e-01 │ Train full L2: 3.4029e-01 │
# [Phase 1:P1_border_only] Ep 105/200 │ Time:   0.22s │ Train step BD(u,v): 3.8450e-02 │ Train step P(full): 1.2186e-01 │ Train step RES: 3.1174e-02 │ Train step TOTAL: 1.9148e-01 │ Train full L2: 3.7301e-01 │
# [Phase 1:P1_border_only] Ep 106/200 │ Time:   0.22s │ Train step BD(u,v): 2.6517e-02 │ Train step P(full): 6.7445e-02 │ Train step RES: 3.1825e-02 │ Train step TOTAL: 1.2579e-01 │ Train full L2: 3.4147e-01 │
# [Phase 1:P1_border_only] Ep 107/200 │ Time:   0.22s │ Train step BD(u,v): 2.2341e-02 │ Train step P(full): 4.9190e-02 │ Train step RES: 2.9997e-02 │ Train step TOTAL: 1.0153e-01 │ Train full L2: 3.2870e-01 │
# [Phase 1:P1_border_only] Ep 108/200 │ Time:   0.22s │ Train step BD(u,v): 2.2177e-02 │ Train step P(full): 5.4776e-02 │ Train step RES: 2.8309e-02 │ Train step TOTAL: 1.0526e-01 │ Train full L2: 3.3635e-01 │
# [Phase 1:P1_border_only] Ep 109/200 │ Time:   0.22s │ Train step BD(u,v): 2.3744e-02 │ Train step P(full): 5.8625e-02 │ Train step RES: 3.0919e-02 │ Train step TOTAL: 1.1329e-01 │ Train full L2: 3.3634e-01 │
# [Phase 1:P1_border_only] Ep 110/200 │ Time:   0.22s │ Train step BD(u,v): 2.2598e-02 │ Train step P(full): 6.8298e-02 │ Train step RES: 2.8568e-02 │ Train step TOTAL: 1.1946e-01 │ Train full L2: 3.4220e-01 │
# [Phase 1:P1_border_only] Ep 111/200 │ Time:   0.23s │ Train step BD(u,v): 2.1257e-02 │ Train step P(full): 5.8981e-02 │ Train step RES: 2.9102e-02 │ Train step TOTAL: 1.0934e-01 │ Train full L2: 3.3253e-01 │
# [Phase 1:P1_border_only] Ep 112/200 │ Time:   0.22s │ Train step BD(u,v): 2.6035e-02 │ Train step P(full): 8.6434e-02 │ Train step RES: 2.9782e-02 │ Train step TOTAL: 1.4225e-01 │ Train full L2: 3.5126e-01 │
# [Phase 1:P1_border_only] Ep 113/200 │ Time:   0.22s │ Train step BD(u,v): 2.2287e-02 │ Train step P(full): 5.8814e-02 │ Train step RES: 2.8655e-02 │ Train step TOTAL: 1.0976e-01 │ Train full L2: 3.4149e-01 │
# [Phase 1:P1_border_only] Ep 114/200 │ Time:   0.22s │ Train step BD(u,v): 3.6390e-02 │ Train step P(full): 1.2410e-01 │ Train step RES: 3.1194e-02 │ Train step TOTAL: 1.9168e-01 │ Train full L2: 3.7945e-01 │
# [Phase 1:P1_border_only] Ep 115/200 │ Time:   0.22s │ Train step BD(u,v): 2.0352e-02 │ Train step P(full): 4.8716e-02 │ Train step RES: 2.8077e-02 │ Train step TOTAL: 9.7144e-02 │ Train full L2: 3.2533e-01 │
# [Phase 1:P1_border_only] Ep 116/200 │ Time:   0.22s │ Train step BD(u,v): 3.5170e-02 │ Train step P(full): 1.2004e-01 │ Train step RES: 2.9841e-02 │ Train step TOTAL: 1.8505e-01 │ Train full L2: 3.7807e-01 │
# [Phase 1:P1_border_only] Ep 117/200 │ Time:   0.22s │ Train step BD(u,v): 3.4298e-02 │ Train step P(full): 1.1750e-01 │ Train step RES: 2.9847e-02 │ Train step TOTAL: 1.8165e-01 │ Train full L2: 3.7738e-01 │
# [Phase 1:P1_border_only] Ep 118/200 │ Time:   0.22s │ Train step BD(u,v): 3.3249e-02 │ Train step P(full): 1.1420e-01 │ Train step RES: 2.9786e-02 │ Train step TOTAL: 1.7723e-01 │ Train full L2: 3.7678e-01 │
# [Phase 1:P1_border_only] Ep 119/200 │ Time:   0.22s │ Train step BD(u,v): 2.2183e-02 │ Train step P(full): 5.1565e-02 │ Train step RES: 3.0459e-02 │ Train step TOTAL: 1.0421e-01 │ Train full L2: 3.2966e-01 │
# [Phase 1:P1_border_only] Ep 120/200 │ Time:   0.22s │ Train step BD(u,v): 3.1580e-02 │ Train step P(full): 1.0884e-01 │ Train step RES: 2.9733e-02 │ Train step TOTAL: 1.7015e-01 │ Train full L2: 3.7643e-01 │
# [Phase 1:P1_border_only] Ep 121/200 │ Time:   0.22s │ Train step BD(u,v): 2.7862e-02 │ Train step P(full): 8.8535e-02 │ Train step RES: 3.2344e-02 │ Train step TOTAL: 1.4874e-01 │ Train full L2: 3.6364e-01 │
# [Phase 1:P1_border_only] Ep 122/200 │ Time:   0.22s │ Train step BD(u,v): 2.6052e-02 │ Train step P(full): 9.4321e-02 │ Train step RES: 2.9426e-02 │ Train step TOTAL: 1.4980e-01 │ Train full L2: 3.5869e-01 │
# [Phase 1:P1_border_only] Ep 123/200 │ Time:   0.22s │ Train step BD(u,v): 2.2613e-02 │ Train step P(full): 6.3734e-02 │ Train step RES: 3.2543e-02 │ Train step TOTAL: 1.1889e-01 │ Train full L2: 3.3050e-01 │
# [Phase 1:P1_border_only] Ep 124/200 │ Time:   0.22s │ Train step BD(u,v): 2.2846e-02 │ Train step P(full): 6.8943e-02 │ Train step RES: 3.0079e-02 │ Train step TOTAL: 1.2187e-01 │ Train full L2: 3.4261e-01 │
# [Phase 1:P1_border_only] Ep 125/200 │ Time:   0.22s │ Train step BD(u,v): 2.9195e-02 │ Train step P(full): 1.0326e-01 │ Train step RES: 3.0408e-02 │ Train step TOTAL: 1.6286e-01 │ Train full L2: 3.7650e-01 │
# [Phase 1:P1_border_only] Ep 126/200 │ Time:   0.22s │ Train step BD(u,v): 2.9021e-02 │ Train step P(full): 1.0249e-01 │ Train step RES: 3.0154e-02 │ Train step TOTAL: 1.6166e-01 │ Train full L2: 3.7645e-01 │
# [Phase 1:P1_border_only] Ep 127/200 │ Time:   0.22s │ Train step BD(u,v): 2.4396e-02 │ Train step P(full): 7.2340e-02 │ Train step RES: 3.2717e-02 │ Train step TOTAL: 1.2945e-01 │ Train full L2: 3.5427e-01 │
# [Phase 1:P1_border_only] Ep 128/200 │ Time:   0.22s │ Train step BD(u,v): 2.3356e-02 │ Train step P(full): 5.7269e-02 │ Train step RES: 3.3512e-02 │ Train step TOTAL: 1.1414e-01 │ Train full L2: 3.3314e-01 │
# [Phase 1:P1_border_only] Ep 129/200 │ Time:   0.22s │ Train step BD(u,v): 2.8667e-02 │ Train step P(full): 1.0222e-01 │ Train step RES: 3.0000e-02 │ Train step TOTAL: 1.6089e-01 │ Train full L2: 3.7783e-01 │
# [Phase 1:P1_border_only] Ep 130/200 │ Time:   0.23s │ Train step BD(u,v): 2.2866e-02 │ Train step P(full): 5.6712e-02 │ Train step RES: 3.3730e-02 │ Train step TOTAL: 1.1331e-01 │ Train full L2: 3.3456e-01 │
# [Phase 1:P1_border_only] Ep 131/200 │ Time:   0.22s │ Train step BD(u,v): 2.9099e-02 │ Train step P(full): 1.0320e-01 │ Train step RES: 3.0291e-02 │ Train step TOTAL: 1.6259e-01 │ Train full L2: 3.7921e-01 │
# [Phase 1:P1_border_only] Ep 132/200 │ Time:   0.22s │ Train step BD(u,v): 2.2868e-02 │ Train step P(full): 6.1029e-02 │ Train step RES: 3.3027e-02 │ Train step TOTAL: 1.1692e-01 │ Train full L2: 3.2802e-01 │
# [Phase 1:P1_border_only] Ep 133/200 │ Time:   0.22s │ Train step BD(u,v): 2.9431e-02 │ Train step P(full): 1.0286e-01 │ Train step RES: 2.9907e-02 │ Train step TOTAL: 1.6220e-01 │ Train full L2: 3.7983e-01 │
# [Phase 1:P1_border_only] Ep 134/200 │ Time:   0.22s │ Train step BD(u,v): 2.9283e-02 │ Train step P(full): 1.0236e-01 │ Train step RES: 2.9630e-02 │ Train step TOTAL: 1.6127e-01 │ Train full L2: 3.7994e-01 │
# [Phase 1:P1_border_only] Ep 135/200 │ Time:   0.22s │ Train step BD(u,v): 2.4298e-02 │ Train step P(full): 7.2304e-02 │ Train step RES: 3.3267e-02 │ Train step TOTAL: 1.2987e-01 │ Train full L2: 3.5655e-01 │
# [Phase 1:P1_border_only] Ep 136/200 │ Time:   0.24s │ Train step BD(u,v): 2.3449e-02 │ Train step P(full): 5.9100e-02 │ Train step RES: 3.4874e-02 │ Train step TOTAL: 1.1742e-01 │ Train full L2: 3.3431e-01 │
# [Phase 1:P1_border_only] Ep 137/200 │ Time:   0.22s │ Train step BD(u,v): 2.8316e-02 │ Train step P(full): 1.0034e-01 │ Train step RES: 2.9746e-02 │ Train step TOTAL: 1.5840e-01 │ Train full L2: 3.8011e-01 │
# [Phase 1:P1_border_only] Ep 138/200 │ Time:   0.22s │ Train step BD(u,v): 2.8005e-02 │ Train step P(full): 9.9867e-02 │ Train step RES: 2.9703e-02 │ Train step TOTAL: 1.5757e-01 │ Train full L2: 3.8017e-01 │
# [Phase 1:P1_border_only] Ep 139/200 │ Time:   0.22s │ Train step BD(u,v): 2.7600e-02 │ Train step P(full): 9.9113e-02 │ Train step RES: 2.9696e-02 │ Train step TOTAL: 1.5641e-01 │ Train full L2: 3.8020e-01 │
# [Phase 1:P1_border_only] Ep 140/200 │ Time:   0.24s │ Train step BD(u,v): 2.7223e-02 │ Train step P(full): 9.8133e-02 │ Train step RES: 2.9759e-02 │ Train step TOTAL: 1.5512e-01 │ Train full L2: 3.8019e-01 │
# [Phase 1:P1_border_only] Ep 141/200 │ Time:   0.22s │ Train step BD(u,v): 2.6728e-02 │ Train step P(full): 9.7132e-02 │ Train step RES: 2.9767e-02 │ Train step TOTAL: 1.5363e-01 │ Train full L2: 3.8020e-01 │
# [Phase 1:P1_border_only] Ep 142/200 │ Time:   0.23s │ Train step BD(u,v): 2.6491e-02 │ Train step P(full): 9.6518e-02 │ Train step RES: 2.9769e-02 │ Train step TOTAL: 1.5278e-01 │ Train full L2: 3.8022e-01 │
# [Phase 1:P1_border_only] Ep 143/200 │ Time:   0.23s │ Train step BD(u,v): 2.5911e-02 │ Train step P(full): 6.8267e-02 │ Train step RES: 4.0336e-02 │ Train step TOTAL: 1.3451e-01 │ Train full L2: 3.2805e-01 │
# [Phase 1:P1_border_only] Ep 144/200 │ Time:   0.22s │ Train step BD(u,v): 2.5675e-02 │ Train step P(full): 6.9900e-02 │ Train step RES: 3.6651e-02 │ Train step TOTAL: 1.3223e-01 │ Train full L2: 3.3152e-01 │
# [Phase 1:P1_border_only] Ep 145/200 │ Time:   0.22s │ Train step BD(u,v): 2.5117e-02 │ Train step P(full): 7.7817e-02 │ Train step RES: 3.3871e-02 │ Train step TOTAL: 1.3681e-01 │ Train full L2: 3.4562e-01 │
# [Phase 1:P1_border_only] Ep 146/200 │ Time:   0.23s │ Train step BD(u,v): 2.3046e-02 │ Train step P(full): 7.1215e-02 │ Train step RES: 3.4529e-02 │ Train step TOTAL: 1.2879e-01 │ Train full L2: 3.5734e-01 │
# [Phase 1:P1_border_only] Ep 147/200 │ Time:   0.22s │ Train step BD(u,v): 2.4148e-02 │ Train step P(full): 6.6148e-02 │ Train step RES: 3.7245e-02 │ Train step TOTAL: 1.2754e-01 │ Train full L2: 3.3449e-01 │
# [Phase 1:P1_border_only] Ep 148/200 │ Time:   0.22s │ Train step BD(u,v): 2.4993e-02 │ Train step P(full): 7.7463e-02 │ Train step RES: 3.4139e-02 │ Train step TOTAL: 1.3660e-01 │ Train full L2: 3.4604e-01 │
# [Phase 1:P1_border_only] Ep 149/200 │ Time:   0.22s │ Train step BD(u,v): 2.6452e-02 │ Train step P(full): 9.7167e-02 │ Train step RES: 3.0255e-02 │ Train step TOTAL: 1.5387e-01 │ Train full L2: 3.8195e-01 │
# [Phase 1:P1_border_only] Ep 150/200 │ Time:   0.22s │ Train step BD(u,v): 2.2203e-02 │ Train step P(full): 6.4883e-02 │ Train step RES: 3.3612e-02 │ Train step TOTAL: 1.2070e-01 │ Train full L2: 3.4973e-01 │
# [Phase 1:P1_border_only] Ep 151/200 │ Time:   0.22s │ Train step BD(u,v): 2.4007e-02 │ Train step P(full): 6.7617e-02 │ Train step RES: 3.3580e-02 │ Train step TOTAL: 1.2520e-01 │ Train full L2: 3.4185e-01 │
# [Phase 1:P1_border_only] Ep 152/200 │ Time:   0.23s │ Train step BD(u,v): 2.6891e-02 │ Train step P(full): 9.8191e-02 │ Train step RES: 2.9964e-02 │ Train step TOTAL: 1.5505e-01 │ Train full L2: 3.8260e-01 │
# [Phase 1:P1_border_only] Ep 153/200 │ Time:   0.22s │ Train step BD(u,v): 2.4440e-02 │ Train step P(full): 6.8371e-02 │ Train step RES: 3.7998e-02 │ Train step TOTAL: 1.3081e-01 │ Train full L2: 3.3822e-01 │
# [Phase 1:P1_border_only] Ep 154/200 │ Time:   0.22s │ Train step BD(u,v): 2.5608e-02 │ Train step P(full): 6.9354e-02 │ Train step RES: 3.8089e-02 │ Train step TOTAL: 1.3305e-01 │ Train full L2: 3.3202e-01 │
# [Phase 1:P1_border_only] Ep 155/200 │ Time:   0.23s │ Train step BD(u,v): 2.4366e-02 │ Train step P(full): 8.4953e-02 │ Train step RES: 3.5542e-02 │ Train step TOTAL: 1.4486e-01 │ Train full L2: 3.5469e-01 │
# [Phase 1:P1_border_only] Ep 156/200 │ Time:   0.22s │ Train step BD(u,v): 2.7406e-02 │ Train step P(full): 9.9749e-02 │ Train step RES: 2.9697e-02 │ Train step TOTAL: 1.5685e-01 │ Train full L2: 3.8284e-01 │
# [Phase 1:P1_border_only] Ep 157/200 │ Time:   0.22s │ Train step BD(u,v): 2.7382e-02 │ Train step P(full): 9.9898e-02 │ Train step RES: 2.9727e-02 │ Train step TOTAL: 1.5701e-01 │ Train full L2: 3.8276e-01 │
# [Phase 1:P1_border_only] Ep 158/200 │ Time:   0.22s │ Train step BD(u,v): 2.7305e-02 │ Train step P(full): 9.9749e-02 │ Train step RES: 2.9700e-02 │ Train step TOTAL: 1.5675e-01 │ Train full L2: 3.8262e-01 │
# [Phase 1:P1_border_only] Ep 159/200 │ Time:   0.22s │ Train step BD(u,v): 2.2088e-02 │ Train step P(full): 5.8669e-02 │ Train step RES: 3.6757e-02 │ Train step TOTAL: 1.1751e-01 │ Train full L2: 3.4066e-01 │
# [Phase 1:P1_border_only] Ep 160/200 │ Time:   0.22s │ Train step BD(u,v): 2.3378e-02 │ Train step P(full): 6.6273e-02 │ Train step RES: 3.9445e-02 │ Train step TOTAL: 1.2910e-01 │ Train full L2: 3.3738e-01 │
# [Phase 1:P1_border_only] Ep 161/200 │ Time:   0.22s │ Train step BD(u,v): 2.6858e-02 │ Train step P(full): 9.9226e-02 │ Train step RES: 2.9631e-02 │ Train step TOTAL: 1.5572e-01 │ Train full L2: 3.8235e-01 │
# [Phase 1:P1_border_only] Ep 162/200 │ Time:   0.22s │ Train step BD(u,v): 2.2895e-02 │ Train step P(full): 6.3156e-02 │ Train step RES: 3.3256e-02 │ Train step TOTAL: 1.1931e-01 │ Train full L2: 3.4184e-01 │
# [Phase 1:P1_border_only] Ep 163/200 │ Time:   0.22s │ Train step BD(u,v): 2.2884e-02 │ Train step P(full): 7.0523e-02 │ Train step RES: 3.4375e-02 │ Train step TOTAL: 1.2778e-01 │ Train full L2: 3.5839e-01 │
# [Phase 1:P1_border_only] Ep 164/200 │ Time:   0.22s │ Train step BD(u,v): 2.6757e-02 │ Train step P(full): 9.9194e-02 │ Train step RES: 2.9583e-02 │ Train step TOTAL: 1.5553e-01 │ Train full L2: 3.8235e-01 │
# [Phase 1:P1_border_only] Ep 165/200 │ Time:   0.22s │ Train step BD(u,v): 2.2235e-02 │ Train step P(full): 5.7097e-02 │ Train step RES: 3.3994e-02 │ Train step TOTAL: 1.1333e-01 │ Train full L2: 3.3624e-01 │
# [Phase 1:P1_border_only] Ep 166/200 │ Time:   0.22s │ Train step BD(u,v): 2.6680e-02 │ Train step P(full): 9.8998e-02 │ Train step RES: 2.9513e-02 │ Train step TOTAL: 1.5519e-01 │ Train full L2: 3.8233e-01 │
# [Phase 1:P1_border_only] Ep 167/200 │ Time:   0.22s │ Train step BD(u,v): 2.6623e-02 │ Train step P(full): 9.8845e-02 │ Train step RES: 2.9426e-02 │ Train step TOTAL: 1.5489e-01 │ Train full L2: 3.8233e-01 │
# [Phase 1:P1_border_only] Ep 168/200 │ Time:   0.23s │ Train step BD(u,v): 2.2883e-02 │ Train step P(full): 6.2740e-02 │ Train step RES: 3.3116e-02 │ Train step TOTAL: 1.1874e-01 │ Train full L2: 3.4173e-01 │
# [Phase 1:P1_border_only] Ep 169/200 │ Time:   0.22s │ Train step BD(u,v): 2.1428e-02 │ Train step P(full): 5.7611e-02 │ Train step RES: 3.2528e-02 │ Train step TOTAL: 1.1157e-01 │ Train full L2: 3.4408e-01 │
# [Phase 1:P1_border_only] Ep 170/200 │ Time:   0.23s │ Train step BD(u,v): 2.2070e-02 │ Train step P(full): 5.7701e-02 │ Train step RES: 3.2525e-02 │ Train step TOTAL: 1.1230e-01 │ Train full L2: 3.4112e-01 │
# [Phase 1:P1_border_only] Ep 171/200 │ Time:   0.22s │ Train step BD(u,v): 2.3546e-02 │ Train step P(full): 6.4647e-02 │ Train step RES: 3.7385e-02 │ Train step TOTAL: 1.2558e-01 │ Train full L2: 3.3798e-01 │
# [Phase 1:P1_border_only] Ep 172/200 │ Time:   0.22s │ Train step BD(u,v): 2.6696e-02 │ Train step P(full): 9.9304e-02 │ Train step RES: 2.9450e-02 │ Train step TOTAL: 1.5545e-01 │ Train full L2: 3.8258e-01 │
# [Phase 1:P1_border_only] Ep 173/200 │ Time:   0.22s │ Train step BD(u,v): 2.6759e-02 │ Train step P(full): 9.9443e-02 │ Train step RES: 2.9410e-02 │ Train step TOTAL: 1.5561e-01 │ Train full L2: 3.8262e-01 │
# [Phase 1:P1_border_only] Ep 174/200 │ Time:   0.22s │ Train step BD(u,v): 2.4526e-02 │ Train step P(full): 8.2292e-02 │ Train step RES: 3.2798e-02 │ Train step TOTAL: 1.3962e-01 │ Train full L2: 3.6880e-01 │
# [Phase 1:P1_border_only] Ep 175/200 │ Time:   0.22s │ Train step BD(u,v): 2.3705e-02 │ Train step P(full): 6.4175e-02 │ Train step RES: 3.4459e-02 │ Train step TOTAL: 1.2234e-01 │ Train full L2: 3.3229e-01 │
# [Phase 1:P1_border_only] Ep 176/200 │ Time:   0.23s │ Train step BD(u,v): 2.3727e-02 │ Train step P(full): 6.0747e-02 │ Train step RES: 3.8743e-02 │ Train step TOTAL: 1.2322e-01 │ Train full L2: 3.3328e-01 │
# [Phase 1:P1_border_only] Ep 177/200 │ Time:   0.22s │ Train step BD(u,v): 2.6657e-02 │ Train step P(full): 9.8909e-02 │ Train step RES: 2.9218e-02 │ Train step TOTAL: 1.5479e-01 │ Train full L2: 3.8238e-01 │
# [Phase 1:P1_border_only] Ep 178/200 │ Time:   0.22s │ Train step BD(u,v): 2.3179e-02 │ Train step P(full): 7.2069e-02 │ Train step RES: 3.3609e-02 │ Train step TOTAL: 1.2886e-01 │ Train full L2: 3.4624e-01 │
# [Phase 1:P1_border_only] Ep 179/200 │ Time:   0.22s │ Train step BD(u,v): 2.6573e-02 │ Train step P(full): 9.8612e-02 │ Train step RES: 2.9141e-02 │ Train step TOTAL: 1.5433e-01 │ Train full L2: 3.8217e-01 │
# [Phase 1:P1_border_only] Ep 180/200 │ Time:   0.22s │ Train step BD(u,v): 2.5327e-02 │ Train step P(full): 6.4599e-02 │ Train step RES: 4.4142e-02 │ Train step TOTAL: 1.3407e-01 │ Train full L2: 3.2147e-01 │
# [Phase 1:P1_border_only] Ep 181/200 │ Time:   0.24s │ Train step BD(u,v): 2.6453e-02 │ Train step P(full): 9.8313e-02 │ Train step RES: 2.9091e-02 │ Train step TOTAL: 1.5386e-01 │ Train full L2: 3.8200e-01 │
# [Phase 1:P1_border_only] Ep 182/200 │ Time:   0.22s │ Train step BD(u,v): 2.6410e-02 │ Train step P(full): 9.8234e-02 │ Train step RES: 2.9078e-02 │ Train step TOTAL: 1.5372e-01 │ Train full L2: 3.8195e-01 │
# [Phase 1:P1_border_only] Ep 183/200 │ Time:   0.22s │ Train step BD(u,v): 2.6351e-02 │ Train step P(full): 9.8054e-02 │ Train step RES: 2.9063e-02 │ Train step TOTAL: 1.5347e-01 │ Train full L2: 3.8189e-01 │
# [Phase 1:P1_border_only] Ep 184/200 │ Time:   0.22s │ Train step BD(u,v): 2.1333e-02 │ Train step P(full): 6.0864e-02 │ Train step RES: 3.3023e-02 │ Train step TOTAL: 1.1522e-01 │ Train full L2: 3.4975e-01 │
# [Phase 1:P1_border_only] Ep 185/200 │ Time:   0.22s │ Train step BD(u,v): 2.3535e-02 │ Train step P(full): 8.2547e-02 │ Train step RES: 3.4472e-02 │ Train step TOTAL: 1.4055e-01 │ Train full L2: 3.5370e-01 │
# [Phase 1:P1_border_only] Ep 186/200 │ Time:   0.22s │ Train step BD(u,v): 2.2399e-02 │ Train step P(full): 6.8851e-02 │ Train step RES: 3.3983e-02 │ Train step TOTAL: 1.2523e-01 │ Train full L2: 3.5805e-01 │
# [Phase 1:P1_border_only] Ep 187/200 │ Time:   0.23s │ Train step BD(u,v): 2.2336e-02 │ Train step P(full): 5.6868e-02 │ Train step RES: 3.6811e-02 │ Train step TOTAL: 1.1602e-01 │ Train full L2: 3.3465e-01 │
# [Phase 1:P1_border_only] Ep 188/200 │ Time:   0.23s │ Train step BD(u,v): 2.1107e-02 │ Train step P(full): 5.6316e-02 │ Train step RES: 3.2248e-02 │ Train step TOTAL: 1.0967e-01 │ Train full L2: 3.4386e-01 │
# [Phase 1:P1_border_only] Ep 189/200 │ Time:   0.23s │ Train step BD(u,v): 2.6159e-02 │ Train step P(full): 9.7645e-02 │ Train step RES: 2.9035e-02 │ Train step TOTAL: 1.5284e-01 │ Train full L2: 3.8184e-01 │
# [Phase 1:P1_border_only] Ep 190/200 │ Time:   0.22s │ Train step BD(u,v): 2.1278e-02 │ Train step P(full): 6.0657e-02 │ Train step RES: 3.2945e-02 │ Train step TOTAL: 1.1488e-01 │ Train full L2: 3.4972e-01 │
# [Phase 1:P1_border_only] Ep 191/200 │ Time:   0.22s │ Train step BD(u,v): 2.3718e-02 │ Train step P(full): 6.2495e-02 │ Train step RES: 3.5379e-02 │ Train step TOTAL: 1.2159e-01 │ Train full L2: 3.2708e-01 │
# [Phase 1:P1_border_only] Ep 192/200 │ Time:   0.23s │ Train step BD(u,v): 2.6192e-02 │ Train step P(full): 9.7879e-02 │ Train step RES: 2.9007e-02 │ Train step TOTAL: 1.5308e-01 │ Train full L2: 3.8198e-01 │
# [Phase 1:P1_border_only] Ep 193/200 │ Time:   0.22s │ Train step BD(u,v): 2.5448e-02 │ Train step P(full): 6.4984e-02 │ Train step RES: 4.5336e-02 │ Train step TOTAL: 1.3577e-01 │ Train full L2: 3.2136e-01 │
# [Phase 1:P1_border_only] Ep 194/200 │ Time:   0.22s │ Train step BD(u,v): 2.1708e-02 │ Train step P(full): 5.4790e-02 │ Train step RES: 3.3429e-02 │ Train step TOTAL: 1.0993e-01 │ Train full L2: 3.3605e-01 │
# [Phase 1:P1_border_only] Ep 195/200 │ Time:   0.22s │ Train step BD(u,v): 2.6275e-02 │ Train step P(full): 9.8396e-02 │ Train step RES: 2.9184e-02 │ Train step TOTAL: 1.5385e-01 │ Train full L2: 3.8220e-01 │
# [Phase 1:P1_border_only] Ep 196/200 │ Time:   0.22s │ Train step BD(u,v): 2.6280e-02 │ Train step P(full): 9.8346e-02 │ Train step RES: 2.9134e-02 │ Train step TOTAL: 1.5376e-01 │ Train full L2: 3.8222e-01 │
# [Phase 1:P1_border_only] Ep 197/200 │ Time:   0.22s │ Train step BD(u,v): 2.6235e-02 │ Train step P(full): 9.8316e-02 │ Train step RES: 2.9049e-02 │ Train step TOTAL: 1.5360e-01 │ Train full L2: 3.8220e-01 │
# [Phase 1:P1_border_only] Ep 198/200 │ Time:   0.23s │ Train step BD(u,v): 2.6231e-02 │ Train step P(full): 9.8212e-02 │ Train step RES: 2.9065e-02 │ Train step TOTAL: 1.5351e-01 │ Train full L2: 3.8215e-01 │
# [Phase 1:P1_border_only] Ep 199/200 │ Time:   0.23s │ Train step BD(u,v): 2.1623e-02 │ Train step P(full): 5.6000e-02 │ Train step RES: 3.2035e-02 │ Train step TOTAL: 1.0966e-01 │ Train full L2: 3.4092e-01 │
# [Phase 1:P1_border_only] Ep 200/200 │ Time:   0.24s │ Train step BD(u,v): 2.1637e-02 │ Train step P(full): 5.5997e-02 │ Train step RES: 3.2041e-02 │ Train step TOTAL: 1.0967e-01 │ Train full L2: 3.4091e-01 │
# → Saved loss history for phase 'P1_border_only' in loss/FNO_One_Stage_ep100_m24_w64_T10/loss_P1_border_only.csv

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# -----------------------------------------
# genera predizioni autoregressive dal modello
# -----------------------------------------
def predict_sequence(model, xx, yy, T, step=1, C=3):
    model.eval()
    preds = []
    with torch.no_grad():
        for t in range(0, T, step):
            y = yy[..., 3*t:3*(t+1)] 
           # ---- predizione ----
            if predict_delta:
                # base = ultimo stato nella finestra (u_t, v_t, p_t)
                base = xx[..., -C:]                                # (B,Sx,Sy,3)
                delta = model(xx)                                  # (B,Sx,Sy,3)
                im = base + delta                                  # pred stato t+1
            else:
                im = model(xx)                                     # pred stato t+1 diretto
            
            preds.append(im)
            
            # aggiorna input con autoregressione
            xy   = xx[..., :2]
            hist = xx[..., 2:]
            hist = torch.cat([hist[..., C:], y], dim=-1)
            xx   = torch.cat([xy, hist], dim=-1)
    pred_seq = torch.cat(preds, dim=-1)  # (B, Sx, Sy, 3*T)
    return pred_seq


# -----------------------------------------
# funzione per animare u,v,p
# -----------------------------------------
def animate_prediction(xx, yy, model, T, step=1, interval=200,
                       save_prefix="anim",  # solo basename del file (niente path)
                       cmap_field="jet", cmap_err="magma",
                       add_colorbars=True, times=None,
                       out_dir=".", save_last_png=True, filename_base=None):
    """
    out_dir: cartella dove salvare i file (es. path_image)
    save_last_png: se True salva anche l'ultimo frame come PNG
    filename_base: basename per i file; se None usa save_prefix
    """
    import os
    if filename_base is None:
        filename_base = save_prefix
    os.makedirs(out_dir, exist_ok=True)

    C = 3
    pred_seq = predict_sequence(model, xx.clone(), yy.clone(), T, step, C)  # (B,Sx,Sy,3*Tpred)
    B, Sx, Sy, _ = pred_seq.shape
    Tpred = pred_seq.shape[-1] // C

    # estrai pred e gt (B,Sx,Sy,T)
    u_pred = pred_seq[..., 0::C]; v_pred = pred_seq[..., 1::C]; p_pred = pred_seq[..., 2::C]
    u_true = yy      [..., 0::C]; v_true = yy      [..., 1::C]; p_true = yy      [..., 2::C]

    # to numpy (Sx,Sy,T)
    u_pred = u_pred.squeeze(0).detach().cpu().numpy()
    v_pred = v_pred.squeeze(0).detach().cpu().numpy()
    p_pred = p_pred.squeeze(0).detach().cpu().numpy()
    u_true = u_true.squeeze(0).detach().cpu().numpy()
    v_true = v_true.squeeze(0).detach().cpu().numpy()
    p_true = p_true.squeeze(0).detach().cpu().numpy()

    # errori (Sx,Sy,T)
    eu = np.abs(u_pred - u_true)
    ev = np.abs(v_pred - v_true)
    ep = np.abs(p_pred - p_true)

    # range colori stabile (dai GT)
    vmin_u, vmax_u = float(u_true.min()), float(u_true.max())
    vmin_v, vmax_v = float(v_true.min()), float(v_true.max())
    vmin_p, vmax_p = float(p_true.min()), float(p_true.max())

    # range errore robusto (99° percentile)
    emax_u = max(1e-12, float(np.percentile(eu, 99)))
    emax_v = max(1e-12, float(np.percentile(ev, 99)))
    emax_p = max(1e-12, float(np.percentile(ep, 99)))

    # figura animazione 3x3
    fig, axes = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
    titles_top = ['u pred', 'v pred', 'p pred']
    titles_mid = ['u GT',   'v GT',   'p GT'  ]
    titles_bot = ['|u err|','|v err|','|p err|']

    for i in range(3):
        axes[0,i].set_title(titles_top[i])
        axes[1,i].set_title(titles_mid[i])
        axes[2,i].set_title(titles_bot[i])
        for r in range(3):
            axes[r,i].set_xticks([]); axes[r,i].set_yticks([])

    k0 = 0
    im00 = axes[0,0].imshow(u_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im01 = axes[0,1].imshow(v_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im02 = axes[0,2].imshow(p_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im10 = axes[1,0].imshow(u_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im11 = axes[1,1].imshow(v_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im12 = axes[1,2].imshow(p_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im20 = axes[2,0].imshow(eu[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_u, animated=True)
    im21 = axes[2,1].imshow(ev[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_v, animated=True)
    im22 = axes[2,2].imshow(ep[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_p, animated=True)

    ims = [im00, im01, im02, im10, im11, im12, im20, im21, im22]
    cbs = []
    if add_colorbars:
        for ax, im in zip(axes[0], ims[0:3]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[1], ims[3:6]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[2], ims[6:9]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))

    # testo tempo/frame
    if times is not None and len(times) >= Tpred:
        time_text = fig.text(0.01, 0.98, f"t = {float(times[0]):.3f}", fontsize=12)
    else:
        time_text = fig.text(0.01, 0.98, f"frame 0 / {Tpred-1}", fontsize=12)

    def update(frame):
        im00.set_array(u_pred[...,frame].T); im01.set_array(v_pred[...,frame].T); im02.set_array(p_pred[...,frame].T)
        im10.set_array(u_true[...,frame].T); im11.set_array(v_true[...,frame].T); im12.set_array(p_true[...,frame].T)
        im20.set_array(eu[...,frame].T);     im21.set_array(ev[...,frame].T);     im22.set_array(ep[...,frame].T)
        if times is not None and len(times) >= Tpred:
            time_text.set_text(f"t = {float(times[frame]):.3f}")
        else:
            time_text.set_text(f"frame {frame} / {Tpred-1}")
        return ims + [time_text]

    ani = animation.FuncAnimation(fig, update, frames=Tpred, interval=interval, blit=False)

    # ---- salva GIF ----
    gif_path = os.path.join(out_dir, f"{filename_base}.gif")
    ani.save(gif_path, writer='pillow', fps=max(1, int(1000/interval)))

    # ---- salva PNG dell'ultimo frame (stessa griglia 3x3) ----
    png_path = None
    if save_last_png:
        frame = Tpred-1
        fig_last, axes_last = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
        titles_top = ['u pred', 'v pred', 'p pred']
        titles_mid = ['u GT',   'v GT',   'p GT'  ]
        titles_bot = ['|u err|','|v err|','|p err|']
        for i in range(3):
            axes_last[0,i].set_title(titles_top[i])
            axes_last[1,i].set_title(titles_mid[i])
            axes_last[2,i].set_title(titles_bot[i])
            for r in range(3):
                axes_last[r,i].set_xticks([]); axes_last[r,i].set_yticks([])

        axes_last[0,0].imshow(u_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[0,1].imshow(v_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[0,2].imshow(p_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[1,0].imshow(u_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[1,1].imshow(v_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[1,2].imshow(p_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[2,0].imshow(eu[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_u)
        axes_last[2,1].imshow(ev[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_v)
        axes_last[2,2].imshow(ep[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_p)

        if add_colorbars:
            for ax in axes_last[0]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[1]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[2]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)

        png_path = os.path.join(out_dir, f"{filename_base}_last.png")
        fig_last.savefig(png_path, dpi=160, bbox_inches="tight")
        plt.close(fig_last)

    plt.close(fig)
    return ani, gif_path, png_path



# batch di esempio
xx, yy = next(iter(train_loader))
xx = xx.to(device, dtype=torch.float32)
yy = yy.to(device, dtype=torch.float32)

# salva GIF + ultimo frame PNG nella cartella immagini dell'esperimento
ani, gif_path, png_path = animate_prediction(
    xx, yy, model,
    T=T, step=1, interval=200,
    save_prefix="supervised_fno",
    out_dir=path_image,          # <--- usa la cartella 'image/<path>'
    save_last_png=True,
)

print("GIF salvata in:", gif_path)
print("PNG ultimo frame in:", png_path)
# Out:
# GIF salvata in: image/FNO_One_Stage_ep100_m24_w64_T10/supervised_fno.gif
# PNG ultimo frame in: image/FNO_One_Stage_ep100_m24_w64_T10/supervised_fno_last.png
