# %%
import numpy as np
import scipy.io
import torch
import os

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')



sub = 1
offset = 0
T_in = 1
T = 10

# --- carica ---  #
data   = scipy.io.loadmat('cylinder_wake.mat')
X_star = data['X_star']           # (N,2)
U_star = data['U_star']           # (N,2,T)
P_star = data['p_star']           # (N,T)
t_star = data['t'].squeeze()      # (T,)

# --- griglia regolare (completa) ---
dec =12
x_unique = np.unique(np.round(X_star[:,0], dec))   # 100 valori
y_unique = np.unique(np.round(X_star[:,1], dec))   # 50 valori
Sx_full, Sy_full = len(x_unique), len(y_unique)
time = t_star.shape[0]

# mapping (x,y) -> (i,j) sulla griglia COMPLETA
x_to_i = {x:i for i,x in enumerate(x_unique)}
y_to_j = {y:j for j,y in enumerate(y_unique)}
ij = np.empty((X_star.shape[0],2), dtype=int)
for k,(x,y) in enumerate(np.round(X_star, dec)):
    ij[k] = (x_to_i[x], y_to_j[y])

# --- riempi griglie complete ---
U_grid = np.empty((Sx_full, Sy_full, time, 2), dtype=U_star.dtype)  # ...,(u,v)
P_grid = np.empty((Sx_full, Sy_full, time),     dtype=P_star.dtype)

for k in range(X_star.shape[0]):
    i,j = ij[k]
    U_grid[i,j,:,0] = U_star[k,0,:]   # u
    U_grid[i,j,:,1] = U_star[k,1,:]   # v
    P_grid[i,j,:]   = P_star[k,:]

# ====== QUI scegli metà dominio in x (50 colonne) ======
half = Sx_full // 2

# Metà SINISTRA:    ix = slice(0, half)
# Metà DESTRA:      ix = slice(half, Sx_full)
# Metà CENTRATA:    c = Sx_full//2; w = half; ix = slice(c - w//2, c + w//2)
ix = slice(0, half)

# Integra anche l'eventuale subsampling
iy = slice(0, Sy_full)               # tieni tutte le 50 in y
ix = slice(ix.start, ix.stop, sub)   # es. sub=1 → tutte; sub=2 → una ogni 2
iy = slice(iy.start, iy.stop, sub)

# --- in torch, con B=1: u,v,p hanno shape (1, Sx', Sy', T) ---
u = torch.from_numpy(U_grid[ix, iy, :, 0]).unsqueeze(0).contiguous()   # (1, 50, 50, T) se sub=1
v = torch.from_numpy(U_grid[ix, iy, :, 1]).unsqueeze(0).contiguous()
p = torch.from_numpy(P_grid[ix, iy, :]).unsqueeze(0).contiguous()

# --- coord grid coerenti (usando meshgrid) ---
x_half = x_unique[ix]
y_half = y_unique[iy]
Xv, Yv = np.meshgrid(x_half, y_half, indexing='ij')  # (Sx',Sy')
X = torch.from_numpy(Xv)[None, ..., None]  # (1,Sx',Sy',1)
Y = torch.from_numpy(Yv)[None, ..., None]  # (1,Sx',Sy',1)

# --- split in/stimolo e target ---
u_in = u[..., offset:offset+T_in]                         # (1,Sx',Sy',T_in)
v_in = v[..., offset:offset+T_in]
p_in = p[..., offset:offset+T_in]

u_t = u[..., offset+T_in:offset+T_in+T]                   # (1,Sx',Sy',T)
v_t = v[..., offset+T_in:offset+T_in+T]
p_t = p[..., offset+T_in:offset+T_in+T]

# pack finale (B=1): concateni (x,y) ai canali temporali
train_in = torch.cat([X.to(device), Y.to(device), 
                      u_in.to(device), v_in.to(device), p_in.to(device)], dim=-1)  # (1,Sx',Sy', 2+3*T_in)

target = torch.stack([u_t, v_t, p_t], dim=-1)  # (1,Sx',Sy', T, 3)
train_t = target.reshape(target.shape[0], target.shape[1], target.shape[2], -1).contiguous().to(device)

print("Shapes ->", "train_in:", tuple(train_in.shape), "train_t:", tuple(train_t.shape),
      "| sub =", sub, "| half-x =", (ix.start, ix.stop, ix.step))

train_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(train_in, train_t),
    batch_size=1, shuffle=False
)
# Out:
# Shapes -> train_in: (1, 50, 50, 5) train_t: (1, 50, 50, 30) | sub = 1 | half-x = (0, 50, 1)

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
from utilities3 import *

import operator
from functools import reduce
from functools import partial
import os

from timeit import default_timer
import scipy.io
import pandas as pd
from get_params import get_params

import math


torch.manual_seed(0)
np.random.seed(0)

################################################################
# fourier layer
################################################################

def compl_mul2d_rfft(a, b):
    # a: (batch, in_ch, m1, m2, 2)
    # b: (in_ch, out_ch, m1, m2, 2)
    op = partial(torch.einsum, "bctq,dctq->bdtq")
    real = op(a[...,0], b[...,0]) - op(a[...,1], b[...,1])
    imag = op(a[...,1], b[...,0]) + op(a[...,0], b[...,1])
    return torch.stack([real, imag], dim=-1)


class SpectralConv2d_fast(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1
        self.modes2 = modes2
        self.scale = (1/(in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))

    def forward(self, x):
        batchsize, _, nx, ny = *x.shape, 
        # Compute Fourier coefficients (real input -> rfft2)
        x_ft_complex = torch.fft.rfft2(x, norm='ortho')
        # Convert to real-imag tensor
        x_ft = torch.stack([x_ft_complex.real, x_ft_complex.imag], dim=-1)
        # Allocate output in Fourier space
        out_ft = torch.zeros(batchsize, self.out_channels, nx, ny//2+1, 2, device=x.device)
        # Multiply modes
        out_ft[:, :, :self.modes1, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)
        # Convert back to complex
        out_ft_complex = torch.complex(out_ft[...,0], out_ft[...,1])
        # Return to physical space
        x = torch.fft.irfft2(out_ft_complex, s=(nx, ny), norm='ortho')
        return x

class SimpleBlock2d(nn.Module):
    def __init__(self, modes1, modes2, width):
        super(SimpleBlock2d, self).__init__()

        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.fc0 = nn.Linear(5, self.width)

        self.conv0 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)
        self.bn0 = torch.nn.BatchNorm2d(self.width)
        self.bn1 = torch.nn.BatchNorm2d(self.width)
        self.bn2 = torch.nn.BatchNorm2d(self.width)
        self.bn3 = torch.nn.BatchNorm2d(self.width)


        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 18)

    def forward(self, x):
        batchsize = x.shape[0]
        size_x, size_y = x.shape[1], x.shape[2]

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)

        x1 = self.conv0(x)
        x2 = self.w0(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn0(x1 + x2)
        x = F.relu(x)
        x1 = self.conv1(x)
        x2 = self.w1(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn1(x1 + x2)
        x = F.relu(x)
        x1 = self.conv2(x)
        x2 = self.w2(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn2(x1 + x2)
        x = F.relu(x)
        x1 = self.conv3(x)
        x2 = self.w3(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn3(x1 + x2)


        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)

        # ora sposto i 9 canali in testa per fare il pad spaziale
        x = x.permute(0, 3, 1, 2)        # (B, 9, H, W)

        return x

class Net2d(nn.Module):
    def __init__(self, modes, width):
        super(Net2d, self).__init__()

        self.conv1 = SimpleBlock2d(modes, modes, width)


    def forward(self, x):
        x = self.conv1(x)
        return x


    def count_params(self):
        c = 0
        for p in self.parameters():
            c += reduce(operator.mul, list(p.size()))

        return c

# %%
################################################################
# training and evaluation
################################################################
# Parametri\ 

ntrain      = 1

modes       = 24
width       = 64


batch_size  = 1
epochs      = 100

learning_rate   = 2e-3
scheduler_step  = 20
scheduler_gamma = 0.5


step        = 1

rf          = 8
orders_v    = [2,2]
n_samples   = 4
model = Net2d(modes, width).cuda()
# model = torch.load('model/ns_fourier_V100_N1000_ep100_m8_w10')

print(model.count_params())

myloss = LpLoss(size_average=False)

test_full = []

path = f'Spline_Multi_Stage_Adam_ep{epochs}_m{modes}_w{width}_T{T}'

path_model     = os.path.join('model',  path)
path_image     = os.path.join('image',  path)
path_loss_dir  = os.path.join('loss',   path)
os.makedirs(path_image, exist_ok=True)
os.makedirs(path_loss_dir, exist_ok=True)
os.makedirs(os.path.dirname(path_model), exist_ok=True)
# ============================
# Training loop robusto a T lunghi
# ============================

import numpy as np
import torch

# ---- impostazioni autoregressione / stabilità ----
predict_delta   = False     # True: modello predice Δ; False: predice stato assoluto
use_detach      = True     # stacca il gradiente quando reinserisci la predizione in finestra
time_weighting  = True     # pesa di più gli step temporali lontani
noise_std       = 0.0      # es. 0.01 se lavori con canali normalizzati (std~1). 0.0 = off
grad_clip       = 1.0      # clipping del gradiente (None o 0.0 per disattivare)

import numpy as np  # <--- aggiungi se non l'hai già
# Out:
# 37776914

# %%
def make_boundary_mask(Sx, Sy, thickness=1, device='cuda'):
    bm = torch.zeros(1, Sx, Sy, 1, device=device)
    t = int(thickness)
    bm[:, :t, :, :]  = 1   # top
    bm[:, -t:, :, :] = 1   # bottom
    bm[:, :, :t, :]  = 1   # left
    bm[:, :, -t:, :] = 1   # right
    return bm  # shape: (1,Sx,Sy,1)

def lp_on_mask(myloss, x, y, mask_bool):
    """
    x,y: (B,Sx,Sy,C)
    mask_bool: (Sx*Sy,) booleano
    Esegue LpLoss SOLO sui pixel selezionati, concatenando i C canali.
    """
    B, Sx, Sy, C = x.shape
    X = x.reshape(B, Sx*Sy, C)[:, mask_bool, :].reshape(B, -1)
    Y = y.reshape(B, Sx*Sy, C)[:, mask_bool, :].reshape(B, -1)
    return myloss(X, Y)

def fd_grad(u, hx, hy):
    # u: (B,Sx,Sy)
    du_dx = torch.zeros_like(u); du_dy = torch.zeros_like(u)
    du_dx[:, 1:-1, :] = (u[:, 2:, :] - u[:, :-2, :]) / (2.0*hx)
    du_dy[:, :, 1:-1] = (u[:, :, 2:] - u[:, :, :-2]) / (2.0*hy)
    return du_dx, du_dy

def fd_lap(u, hx, hy):
    lap = torch.zeros_like(u)
    lap[:, 1:-1, 1:-1] = (
        (u[:, 2:, 1:-1] + u[:, :-2, 1:-1] - 2.0*u[:, 1:-1, 1:-1]) / (hx*hx) +
        (u[:, 1:-1, 2:] + u[:, 1:-1, :-2] - 2.0*u[:, 1:-1, 1:-1]) / (hy*hy)
    )
    return lap

# %%
import math
from timeit import default_timer
import torch
import torch.nn.functional as F
from spline_models import interpolate_states
import matplotlib.pyplot as plt

# =====================
# Helpers
# =====================

def make_boundary_mask(Sx, Sy, thickness=1, device='cuda'):
    bm = torch.zeros(1, Sx, Sy, 1, device=device)
    t = int(thickness)
    bm[:, :t, :, :]  = 1;  bm[:, -t:, :, :] = 1
    bm[:, :, :t, :]  = 1;  bm[:, :, -t:, :] = 1
    return bm  # (1,Sx,Sy,1)


def lp_on_mask(myloss, x, y, mask_bool):
    # x,y: (B,Sx,Sy,C); mask_bool: (Sx*Sy,) booleano
    B, Sx, Sy, C = x.shape
    X = x.reshape(B, Sx*Sy, C)[:, mask_bool, :].reshape(B, -1)
    Y = y.reshape(B, Sx*Sy, C)[:, mask_bool, :].reshape(B, -1)
    return myloss(X, Y)


def fd_grad(u, hx, hy):
    # u: (B,Sx,Sy) → derivate centrali interne, 0 ai bordi
    du_dx = torch.zeros_like(u); du_dy = torch.zeros_like(u)
    du_dx[:, 1:-1, :] = (u[:, 2:, :] - u[:, :-2, :]) / (2.0*hx)
    du_dy[:, :, 1:-1] = (u[:, :, 2:] - u[:, :, :-2]) / (2.0*hy)
    return du_dx, du_dy


def fd_lap(u, hx, hy):
    lap = torch.zeros_like(u)
    lap[:, 1:-1, 1:-1] = (
        (u[:, 2:, 1:-1] + u[:, :-2, 1:-1] - 2.0*u[:, 1:-1, 1:-1]) / (hx*hx) +
        (u[:, 1:-1, 2:] + u[:, 1:-1, :-2] - 2.0*u[:, 1:-1, 1:-1]) / (hy*hy)
    )
    return lap


def rms_masked(x, mask):
    # x: (B,Sx,Sy), mask: (B,Sx,Sy) float in {0,1}
    n = mask.sum().clamp_min(1.0)
    return torch.sqrt((x.pow(2) * mask).sum() / n + 1e-12)


def tf_ratio_for_epoch(ep_in_phase: int, phase_epochs: int, start=1.0, end=0.0):
    if phase_epochs <= 1:
        return end
    t = ep_in_phase / float(phase_epochs - 1)
    return end + (start - end) * (1.0 - t)


# =====================
# Iperparametri globali
# =====================

# Fisica
nu = 1e-2
# Consistenza temporale (imposta al dt reale del dataset)
dt = 0.1



# Pesi per fase (modifica liberamente)
PHASES = [
    {
        'name': 'P1_border_only',
        'epochs':200,
        'lambda_bd': 1.0,
        'lambda_res': 0.0,
        'record': False

     },
    {
        'name': 'P2_res_warm',
        'epochs': 200,
        'lambda_bd': 1.0,
        'lambda_res': 0.5,
        'record': True
    }
]


# =====================
# Training — curriculum a 4 fasi
# =====================



bm_bool = None
interior_mask = None

for iph, phase in enumerate(PHASES, 1):
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=scheduler_gamma)

    lambda_bd  = phase['lambda_bd']
    lambda_res = phase['lambda_res']

    print(f"\n===== Phase {iph}/{len(PHASES)}: {phase['name']}  (epochs={phase['epochs']}) =====")
    print(f"lambdas → bd:{lambda_bd}  res:{lambda_res}")

    boundary_loss, full_loss, res_loss = [], [], []

    for ep in range(phase['epochs']):
        model.train()
        t0 = default_timer()

        total_step_sum = 0.0
        sup_step_sum   = 0.0
        res_step_sum   = 0.0
        full_seq_sum   = 0.0

        

        for xx, yy in train_loader:
            xx = xx.to(device, dtype=torch.float32)
            yy = yy.to(device, dtype=torch.float32)

            if bm_bool is None:
                Sx, Sy = xx.shape[1], xx.shape[2]
                bm = make_boundary_mask(Sx, Sy, thickness=1, device=xx.device)
                bm_bool = (bm[0, ..., 0] > 0).reshape(-1)     # (Sx*Sy,)
                interior_mask = (1.0 - bm[0, ..., 0]).to(xx.dtype)  # (Sx,Sy)

            B = xx.size(0)
            preds = []
            loss_total = 0.0

            for t in range(T):
                y = yy[..., 3*t:3*(t+1)]  # (B,Sx,Sy,3) → (u_{t+1},v_{t+1},p_{t+1})

                # Forward
                if predict_delta:
                    base  = xx[..., -3:]
                    im    = base + model(xx)
                else:
                    im    = model(xx)
                    base  = xx[..., -3:]

                # Decode
                psi, v, grad_v, lap_v, p, grad_p = interpolate_states(
                    im, offset=torch.tensor([0.0, 0.0], device=device), orders_v=orders_v
                )
                pred = torch.cat([v, p], dim=-1)   # (B,Sx,Sy,3)
                preds.append(pred)

                # =========================
                # 1) SUPERVISIONE
                #    - u,v SOLO bordo
                #    - p FULL domain
                # =========================
                sup_uv_bd = lp_on_mask(myloss, pred[...,:2], y[...,:2], bm_bool)

                sup_p_full = myloss(pred[..., 2:3], y[..., 2:3])

                sup_term = sup_uv_bd + sup_p_full

                # =========================
                # 2) RESIDUO Navier–Stokes (quantità di moto)
                #    valutato SOLO su interior
                # =========================
                u_next = v[..., 0];  v_next = v[..., 1]
                u_prev = base[..., 0]; v_prev = base[..., 1]
                p_prev = base[..., 2]

                Sxg, Syg = u_next.shape[1], u_next.shape[2]
                hx = 1.0 / (Sxg - 1); hy = 1.0 / (Syg - 1)

                # derivate (n: dal decoder; p: FD su base)
                du_dx_n = grad_v[..., 0]; du_dy_n = grad_v[..., 1]
                dv_dx_n = grad_v[..., 2]; dv_dy_n = grad_v[..., 3]
                lap_u_n = lap_v[..., 0];  lap_v_n = lap_v[..., 1]
                dp_dx_n = grad_p[..., 0]; dp_dy_n = grad_p[..., 1]

                du_dx_p, du_dy_p = fd_grad(u_prev, hx, hy)
                dv_dx_p, dv_dy_p = fd_grad(v_prev, hx, hy)
                dp_dx_p, dp_dy_p = fd_grad(p_prev, hx, hy)
                lap_u_p = fd_lap(u_prev, hx, hy)
                lap_v_p = fd_lap(v_prev, hx, hy)

                # medie (CN-like)
                u_bar = 0.5*(u_next + u_prev)
                v_bar = 0.5*(v_next + v_prev)
                du_dx_b = 0.5*(du_dx_n + du_dx_p);  du_dy_b = 0.5*(du_dy_n + du_dy_p)
                dv_dx_b = 0.5*(dv_dx_n + dv_dx_p);  dv_dy_b = 0.5*(dv_dy_n + dv_dy_p)
                dp_dx_b = 0.5*(dp_dx_n + dp_dx_p);  dp_dy_b = 0.5*(dp_dy_n + dp_dy_p)
                lap_u_b = 0.5*(lap_u_n + lap_u_p);  lap_v_b = 0.5*(lap_v_n + lap_v_p)

                # d/dt
                ut = (u_next - u_prev) / dt
                vt = (v_next - v_prev) / dt

                # convettivi e residui
                conv_u = u_bar*du_dx_b + v_bar*du_dy_b
                conv_v = u_bar*dv_dx_b + v_bar*dv_dy_b
                res_u  = ut + conv_u + dp_dx_b - nu*lap_u_b
                res_v  = vt + conv_v + dp_dy_b - nu*lap_v_b

                # MSE su interior (wgt = 1 su interior, 0 su bordo)
                wgt = interior_mask.unsqueeze(0).expand(B, -1, -1)
                num = wgt.sum().clamp_min(1.0)
                res_term = ((res_u.pow(2)*wgt).sum() + (res_v.pow(2)*wgt).sum()) / num

                # =========================
                # 3) LOSS TOTALE (questa fase)
                # =========================
                loss_step = lambda_bd * sup_term + lambda_res * res_term
                loss_total = loss_total + loss_step

                # log parziali
                sup_step_sum += sup_uv_bd.item()
                res_step_sum += res_term.item()

                # Teacher Forcing (qui full TF)
                xy   = xx[..., :2]
                hist = xx[..., 2:]
                hist = torch.cat([hist[..., 3:], y], dim=-1)
                xx   = torch.cat([xy, hist], dim=-1)

            # metriche full-seq
            pred_seq = torch.cat(preds, dim=-1)
            full_seq_sum += myloss(pred_seq.reshape(B, -1), yy.reshape(B, -1)).item()

            optimizer.zero_grad(set_to_none=True)
            loss_total.backward()
            if 'grad_clip' in globals() and grad_clip and grad_clip > 0.0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            optimizer.step()

            total_step_sum += loss_total.item()

        scheduler.step()
        elapsed = default_timer() - t0
        denom_steps = T * len(train_loader)

        # medie epoca
        train_step_mean  = total_step_sum / denom_steps
        sup_step_mean    = sup_step_sum   / denom_steps
        res_step_mean    = res_step_sum   / denom_steps
        full_seq_mean    = full_seq_sum   / len(train_loader)

        print(
            f"[Phase {iph}:{phase['name']}] Ep {ep+1:3d}/{phase['epochs']} │ Time: {elapsed:6.2f}s │ "
            f"Total: {train_step_mean:8.4e} │ Full L2: {full_seq_mean:8.4e} │ "
            f"Boundary: {sup_step_mean:8.4e} │ Res: {res_step_mean:8.4e}"
        )

        boundary_loss.append(sup_step_mean)
        full_loss.append(full_seq_mean)
        if phase['record']:
            res_loss.append(res_step_mean)
    idx = list(range(1, phase['epochs']+1))
    data = {
        'loss_boundary':   boundary_loss,
        'loss_full': full_loss,
    }
    if phase['record']:
        data['loss_res'] = res_loss
    df = pd.DataFrame(data, index=idx)
    df.index.name = 'epoch_in_phase'
    csv_path = os.path.join(path_loss_dir, f"loss_{phase['name']}.csv")
    df.to_csv(csv_path)
    print(f"→ Saved loss history for phase '{phase['name']}' in {csv_path}")
print("Training finished.")
# Out:
# loaded buffers
#
# ===== Phase 1/2: P1_border_only  (epochs=200) =====
# lambdas → bd:1.0  res:0.0
# [Phase 1:P1_border_only] Ep   1/200 │ Time:   0.65s │ Total: 3.4272e+00 │ Full L2: 1.3182e+00 │ Sup@bd+pfull: 1.4635e+00 │ Res: 1.4288e+02
# [Phase 1:P1_border_only] Ep   2/200 │ Time:   0.24s │ Total: 2.7388e+00 │ Full L2: 1.2083e+00 │ Sup@bd+pfull: 1.0011e+00 │ Res: 1.2979e+02
# [Phase 1:P1_border_only] Ep   3/200 │ Time:   0.24s │ Total: 2.0551e+00 │ Full L2: 1.0795e+00 │ Sup@bd+pfull: 9.0006e-01 │ Res: 1.0887e+02
# [Phase 1:P1_border_only] Ep   4/200 │ Time:   0.23s │ Total: 1.2436e+00 │ Full L2: 9.5833e-01 │ Sup@bd+pfull: 4.0747e-01 │ Res: 9.1498e+01
# [Phase 1:P1_border_only] Ep   5/200 │ Time:   0.23s │ Total: 8.9609e-01 │ Full L2: 9.3230e-01 │ Sup@bd+pfull: 4.0688e-01 │ Res: 8.7781e+01
# [Phase 1:P1_border_only] Ep   6/200 │ Time:   0.24s │ Total: 8.4092e-01 │ Full L2: 9.1434e-01 │ Sup@bd+pfull: 2.7750e-01 │ Res: 8.6262e+01
# [Phase 1:P1_border_only] Ep   7/200 │ Time:   0.24s │ Total: 7.1107e-01 │ Full L2: 8.8457e-01 │ Sup@bd+pfull: 2.0423e-01 │ Res: 8.0401e+01
# [Phase 1:P1_border_only] Ep   8/200 │ Time:   0.23s │ Total: 5.4735e-01 │ Full L2: 8.5483e-01 │ Sup@bd+pfull: 1.8384e-01 │ Res: 7.4940e+01
# [Phase 1:P1_border_only] Ep   9/200 │ Time:   0.24s │ Total: 4.9627e-01 │ Full L2: 8.3733e-01 │ Sup@bd+pfull: 1.4631e-01 │ Res: 7.2685e+01
# [Phase 1:P1_border_only] Ep  10/200 │ Time:   0.24s │ Total: 4.7855e-01 │ Full L2: 8.2409e-01 │ Sup@bd+pfull: 1.4136e-01 │ Res: 7.0833e+01
# [Phase 1:P1_border_only] Ep  11/200 │ Time:   0.24s │ Total: 3.6708e-01 │ Full L2: 8.0965e-01 │ Sup@bd+pfull: 1.1688e-01 │ Res: 6.8295e+01
# [Phase 1:P1_border_only] Ep  12/200 │ Time:   0.24s │ Total: 3.4853e-01 │ Full L2: 8.0213e-01 │ Sup@bd+pfull: 1.1005e-01 │ Res: 6.7636e+01
# [Phase 1:P1_border_only] Ep  13/200 │ Time:   0.24s │ Total: 3.4334e-01 │ Full L2: 7.8215e-01 │ Sup@bd+pfull: 1.0027e-01 │ Res: 6.4410e+01
# [Phase 1:P1_border_only] Ep  14/200 │ Time:   0.25s │ Total: 2.8214e-01 │ Full L2: 7.6556e-01 │ Sup@bd+pfull: 8.9772e-02 │ Res: 6.1646e+01
# [Phase 1:P1_border_only] Ep  15/200 │ Time:   0.24s │ Total: 2.8367e-01 │ Full L2: 7.5972e-01 │ Sup@bd+pfull: 9.5773e-02 │ Res: 6.1123e+01
# [Phase 1:P1_border_only] Ep  16/200 │ Time:   0.23s │ Total: 2.6497e-01 │ Full L2: 7.4978e-01 │ Sup@bd+pfull: 8.7551e-02 │ Res: 5.9176e+01
# [Phase 1:P1_border_only] Ep  17/200 │ Time:   0.23s │ Total: 2.3773e-01 │ Full L2: 7.4148e-01 │ Sup@bd+pfull: 7.5243e-02 │ Res: 5.7927e+01
# [Phase 1:P1_border_only] Ep  18/200 │ Time:   0.24s │ Total: 2.6723e-01 │ Full L2: 7.4137e-01 │ Sup@bd+pfull: 9.5737e-02 │ Res: 5.8237e+01
# [Phase 1:P1_border_only] Ep  19/200 │ Time:   0.23s │ Total: 2.3891e-01 │ Full L2: 7.3111e-01 │ Sup@bd+pfull: 7.9005e-02 │ Res: 5.6629e+01
# [Phase 1:P1_border_only] Ep  20/200 │ Time:   0.24s │ Total: 2.3783e-01 │ Full L2: 7.1447e-01 │ Sup@bd+pfull: 1.0402e-01 │ Res: 5.3420e+01
# [Phase 1:P1_border_only] Ep  21/200 │ Time:   0.24s │ Total: 2.3958e-01 │ Full L2: 7.0828e-01 │ Sup@bd+pfull: 9.9430e-02 │ Res: 5.2403e+01
# [Phase 1:P1_border_only] Ep  22/200 │ Time:   0.24s │ Total: 1.8912e-01 │ Full L2: 7.0814e-01 │ Sup@bd+pfull: 6.5032e-02 │ Res: 5.2651e+01
# [Phase 1:P1_border_only] Ep  23/200 │ Time:   0.23s │ Total: 1.8197e-01 │ Full L2: 7.0798e-01 │ Sup@bd+pfull: 6.9584e-02 │ Res: 5.2859e+01
# [Phase 1:P1_border_only] Ep  24/200 │ Time:   0.24s │ Total: 1.9831e-01 │ Full L2: 7.0440e-01 │ Sup@bd+pfull: 8.2998e-02 │ Res: 5.2220e+01
# [Phase 1:P1_border_only] Ep  25/200 │ Time:   0.23s │ Total: 1.8672e-01 │ Full L2: 6.9905e-01 │ Sup@bd+pfull: 6.7988e-02 │ Res: 5.1188e+01
# [Phase 1:P1_border_only] Ep  26/200 │ Time:   0.23s │ Total: 1.6145e-01 │ Full L2: 6.9567e-01 │ Sup@bd+pfull: 5.5740e-02 │ Res: 5.0428e+01
# [Phase 1:P1_border_only] Ep  27/200 │ Time:   0.24s │ Total: 1.6209e-01 │ Full L2: 6.9594e-01 │ Sup@bd+pfull: 6.0841e-02 │ Res: 5.0344e+01
# [Phase 1:P1_border_only] Ep  28/200 │ Time:   0.23s │ Total: 1.4894e-01 │ Full L2: 6.9576e-01 │ Sup@bd+pfull: 4.8988e-02 │ Res: 5.0360e+01
# [Phase 1:P1_border_only] Ep  29/200 │ Time:   0.27s │ Total: 1.3950e-01 │ Full L2: 6.9284e-01 │ Sup@bd+pfull: 5.0939e-02 │ Res: 4.9981e+01
# [Phase 1:P1_border_only] Ep  30/200 │ Time:   0.26s │ Total: 1.3806e-01 │ Full L2: 6.8742e-01 │ Sup@bd+pfull: 4.4504e-02 │ Res: 4.9048e+01
# [Phase 1:P1_border_only] Ep  31/200 │ Time:   0.23s │ Total: 1.2557e-01 │ Full L2: 6.8304e-01 │ Sup@bd+pfull: 4.0237e-02 │ Res: 4.8232e+01
# [Phase 1:P1_border_only] Ep  32/200 │ Time:   0.24s │ Total: 1.1345e-01 │ Full L2: 6.8248e-01 │ Sup@bd+pfull: 4.0065e-02 │ Res: 4.8083e+01
# [Phase 1:P1_border_only] Ep  33/200 │ Time:   0.25s │ Total: 1.1219e-01 │ Full L2: 6.8307e-01 │ Sup@bd+pfull: 3.3188e-02 │ Res: 4.8117e+01
# [Phase 1:P1_border_only] Ep  34/200 │ Time:   0.24s │ Total: 1.0429e-01 │ Full L2: 6.8053e-01 │ Sup@bd+pfull: 3.5811e-02 │ Res: 4.7660e+01
# [Phase 1:P1_border_only] Ep  35/200 │ Time:   0.24s │ Total: 1.0596e-01 │ Full L2: 6.7795e-01 │ Sup@bd+pfull: 2.8030e-02 │ Res: 4.7151e+01
# [Phase 1:P1_border_only] Ep  36/200 │ Time:   0.24s │ Total: 1.0765e-01 │ Full L2: 6.7903e-01 │ Sup@bd+pfull: 3.6310e-02 │ Res: 4.7125e+01
# [Phase 1:P1_border_only] Ep  37/200 │ Time:   0.24s │ Total: 9.6171e-02 │ Full L2: 6.7741e-01 │ Sup@bd+pfull: 2.9008e-02 │ Res: 4.6862e+01
# [Phase 1:P1_border_only] Ep  38/200 │ Time:   0.25s │ Total: 9.4493e-02 │ Full L2: 6.7424e-01 │ Sup@bd+pfull: 3.0593e-02 │ Res: 4.6405e+01
# [Phase 1:P1_border_only] Ep  39/200 │ Time:   0.23s │ Total: 9.0333e-02 │ Full L2: 6.7396e-01 │ Sup@bd+pfull: 3.0845e-02 │ Res: 4.6202e+01
# [Phase 1:P1_border_only] Ep  40/200 │ Time:   0.24s │ Total: 9.5739e-02 │ Full L2: 6.7357e-01 │ Sup@bd+pfull: 3.3715e-02 │ Res: 4.6008e+01
# [Phase 1:P1_border_only] Ep  41/200 │ Time:   0.24s │ Total: 7.5186e-02 │ Full L2: 6.7232e-01 │ Sup@bd+pfull: 2.6593e-02 │ Res: 4.5827e+01
# [Phase 1:P1_border_only] Ep  42/200 │ Time:   0.24s │ Total: 6.7546e-02 │ Full L2: 6.7364e-01 │ Sup@bd+pfull: 2.3639e-02 │ Res: 4.5956e+01
# [Phase 1:P1_border_only] Ep  43/200 │ Time:   0.24s │ Total: 5.9699e-02 │ Full L2: 6.7467e-01 │ Sup@bd+pfull: 2.1370e-02 │ Res: 4.6020e+01
# [Phase 1:P1_border_only] Ep  44/200 │ Time:   0.24s │ Total: 6.1963e-02 │ Full L2: 6.7229e-01 │ Sup@bd+pfull: 2.2594e-02 │ Res: 4.5653e+01
# [Phase 1:P1_border_only] Ep  45/200 │ Time:   0.24s │ Total: 7.0356e-02 │ Full L2: 6.7207e-01 │ Sup@bd+pfull: 2.7635e-02 │ Res: 4.5603e+01
# [Phase 1:P1_border_only] Ep  46/200 │ Time:   0.23s │ Total: 5.7998e-02 │ Full L2: 6.7504e-01 │ Sup@bd+pfull: 1.9845e-02 │ Res: 4.5996e+01
# [Phase 1:P1_border_only] Ep  47/200 │ Time:   0.23s │ Total: 6.1911e-02 │ Full L2: 6.7580e-01 │ Sup@bd+pfull: 2.4540e-02 │ Res: 4.6033e+01
# [Phase 1:P1_border_only] Ep  48/200 │ Time:   0.23s │ Total: 5.6639e-02 │ Full L2: 6.7258e-01 │ Sup@bd+pfull: 1.8473e-02 │ Res: 4.5521e+01
# [Phase 1:P1_border_only] Ep  49/200 │ Time:   0.24s │ Total: 5.8839e-02 │ Full L2: 6.7115e-01 │ Sup@bd+pfull: 2.3093e-02 │ Res: 4.5304e+01
# [Phase 1:P1_border_only] Ep  50/200 │ Time:   0.23s │ Total: 5.3232e-02 │ Full L2: 6.7396e-01 │ Sup@bd+pfull: 1.6522e-02 │ Res: 4.5696e+01
# [Phase 1:P1_border_only] Ep  51/200 │ Time:   0.24s │ Total: 5.9572e-02 │ Full L2: 6.7620e-01 │ Sup@bd+pfull: 2.3253e-02 │ Res: 4.5984e+01
# [Phase 1:P1_border_only] Ep  52/200 │ Time:   0.24s │ Total: 5.2909e-02 │ Full L2: 6.7403e-01 │ Sup@bd+pfull: 1.7825e-02 │ Res: 4.5656e+01
# [Phase 1:P1_border_only] Ep  53/200 │ Time:   0.24s │ Total: 5.4415e-02 │ Full L2: 6.7070e-01 │ Sup@bd+pfull: 1.8503e-02 │ Res: 4.5166e+01
# [Phase 1:P1_border_only] Ep  54/200 │ Time:   0.24s │ Total: 5.2761e-02 │ Full L2: 6.6989e-01 │ Sup@bd+pfull: 2.0227e-02 │ Res: 4.5019e+01
# [Phase 1:P1_border_only] Ep  55/200 │ Time:   0.25s │ Total: 4.8965e-02 │ Full L2: 6.7166e-01 │ Sup@bd+pfull: 1.6597e-02 │ Res: 4.5231e+01
# [Phase 1:P1_border_only] Ep  56/200 │ Time:   0.24s │ Total: 4.8419e-02 │ Full L2: 6.7412e-01 │ Sup@bd+pfull: 1.8577e-02 │ Res: 4.5560e+01
# [Phase 1:P1_border_only] Ep  57/200 │ Time:   0.24s │ Total: 4.6850e-02 │ Full L2: 6.7379e-01 │ Sup@bd+pfull: 1.8360e-02 │ Res: 4.5519e+01
# [Phase 1:P1_border_only] Ep  58/200 │ Time:   0.25s │ Total: 4.8745e-02 │ Full L2: 6.7008e-01 │ Sup@bd+pfull: 1.7275e-02 │ Res: 4.4987e+01
# [Phase 1:P1_border_only] Ep  59/200 │ Time:   0.24s │ Total: 4.8277e-02 │ Full L2: 6.6834e-01 │ Sup@bd+pfull: 1.9388e-02 │ Res: 4.4703e+01
# [Phase 1:P1_border_only] Ep  60/200 │ Time:   0.24s │ Total: 4.8323e-02 │ Full L2: 6.7025e-01 │ Sup@bd+pfull: 1.5634e-02 │ Res: 4.4936e+01
# [Phase 1:P1_border_only] Ep  61/200 │ Time:   0.24s │ Total: 5.1256e-02 │ Full L2: 6.7195e-01 │ Sup@bd+pfull: 1.8593e-02 │ Res: 4.5178e+01
# [Phase 1:P1_border_only] Ep  62/200 │ Time:   0.24s │ Total: 3.8941e-02 │ Full L2: 6.7140e-01 │ Sup@bd+pfull: 1.5663e-02 │ Res: 4.5108e+01
# [Phase 1:P1_border_only] Ep  63/200 │ Time:   0.23s │ Total: 4.2439e-02 │ Full L2: 6.6814e-01 │ Sup@bd+pfull: 1.4968e-02 │ Res: 4.4639e+01
# [Phase 1:P1_border_only] Ep  64/200 │ Time:   0.23s │ Total: 5.9127e-02 │ Full L2: 6.6620e-01 │ Sup@bd+pfull: 2.2998e-02 │ Res: 4.4346e+01
# [Phase 1:P1_border_only] Ep  65/200 │ Time:   0.24s │ Total: 5.5149e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 2.3049e-02 │ Res: 4.4300e+01
# [Phase 1:P1_border_only] Ep  66/200 │ Time:   0.25s │ Total: 3.9938e-02 │ Full L2: 6.6815e-01 │ Sup@bd+pfull: 1.4219e-02 │ Res: 4.4603e+01
# [Phase 1:P1_border_only] Ep  67/200 │ Time:   0.26s │ Total: 4.6206e-02 │ Full L2: 6.7101e-01 │ Sup@bd+pfull: 1.7531e-02 │ Res: 4.5005e+01
# [Phase 1:P1_border_only] Ep  68/200 │ Time:   0.24s │ Total: 4.9368e-02 │ Full L2: 6.7215e-01 │ Sup@bd+pfull: 2.2693e-02 │ Res: 4.5165e+01
# [Phase 1:P1_border_only] Ep  69/200 │ Time:   0.24s │ Total: 4.2314e-02 │ Full L2: 6.7036e-01 │ Sup@bd+pfull: 1.7719e-02 │ Res: 4.4903e+01
# [Phase 1:P1_border_only] Ep  70/200 │ Time:   0.24s │ Total: 4.0643e-02 │ Full L2: 6.6729e-01 │ Sup@bd+pfull: 1.4525e-02 │ Res: 4.4452e+01
# [Phase 1:P1_border_only] Ep  71/200 │ Time:   0.24s │ Total: 4.0245e-02 │ Full L2: 6.6565e-01 │ Sup@bd+pfull: 1.7990e-02 │ Res: 4.4201e+01
# [Phase 1:P1_border_only] Ep  72/200 │ Time:   0.24s │ Total: 3.8982e-02 │ Full L2: 6.6691e-01 │ Sup@bd+pfull: 1.6651e-02 │ Res: 4.4373e+01
# [Phase 1:P1_border_only] Ep  73/200 │ Time:   0.23s │ Total: 3.5316e-02 │ Full L2: 6.6889e-01 │ Sup@bd+pfull: 1.3526e-02 │ Res: 4.4661e+01
# [Phase 1:P1_border_only] Ep  74/200 │ Time:   0.24s │ Total: 3.7032e-02 │ Full L2: 6.6933e-01 │ Sup@bd+pfull: 1.6149e-02 │ Res: 4.4716e+01
# [Phase 1:P1_border_only] Ep  75/200 │ Time:   0.25s │ Total: 3.4317e-02 │ Full L2: 6.6813e-01 │ Sup@bd+pfull: 1.5476e-02 │ Res: 4.4524e+01
# [Phase 1:P1_border_only] Ep  76/200 │ Time:   0.24s │ Total: 3.1303e-02 │ Full L2: 6.6685e-01 │ Sup@bd+pfull: 1.1594e-02 │ Res: 4.4326e+01
# [Phase 1:P1_border_only] Ep  77/200 │ Time:   0.24s │ Total: 3.2735e-02 │ Full L2: 6.6674e-01 │ Sup@bd+pfull: 1.5340e-02 │ Res: 4.4320e+01
# [Phase 1:P1_border_only] Ep  78/200 │ Time:   0.24s │ Total: 3.0730e-02 │ Full L2: 6.6719e-01 │ Sup@bd+pfull: 1.2069e-02 │ Res: 4.4380e+01
# [Phase 1:P1_border_only] Ep  79/200 │ Time:   0.25s │ Total: 3.0610e-02 │ Full L2: 6.6788e-01 │ Sup@bd+pfull: 1.3569e-02 │ Res: 4.4452e+01
# [Phase 1:P1_border_only] Ep  80/200 │ Time:   0.25s │ Total: 3.1667e-02 │ Full L2: 6.6783e-01 │ Sup@bd+pfull: 1.2498e-02 │ Res: 4.4435e+01
# [Phase 1:P1_border_only] Ep  81/200 │ Time:   0.24s │ Total: 2.6865e-02 │ Full L2: 6.6683e-01 │ Sup@bd+pfull: 1.0150e-02 │ Res: 4.4299e+01
# [Phase 1:P1_border_only] Ep  82/200 │ Time:   0.23s │ Total: 2.5138e-02 │ Full L2: 6.6643e-01 │ Sup@bd+pfull: 9.9136e-03 │ Res: 4.4240e+01
# [Phase 1:P1_border_only] Ep  83/200 │ Time:   0.24s │ Total: 2.3663e-02 │ Full L2: 6.6667e-01 │ Sup@bd+pfull: 8.7852e-03 │ Res: 4.4263e+01
# [Phase 1:P1_border_only] Ep  84/200 │ Time:   0.23s │ Total: 2.5464e-02 │ Full L2: 6.6707e-01 │ Sup@bd+pfull: 1.0024e-02 │ Res: 4.4312e+01
# [Phase 1:P1_border_only] Ep  85/200 │ Time:   0.25s │ Total: 2.4195e-02 │ Full L2: 6.6708e-01 │ Sup@bd+pfull: 8.5578e-03 │ Res: 4.4314e+01
# [Phase 1:P1_border_only] Ep  86/200 │ Time:   0.24s │ Total: 2.4325e-02 │ Full L2: 6.6639e-01 │ Sup@bd+pfull: 9.5012e-03 │ Res: 4.4219e+01
# [Phase 1:P1_border_only] Ep  87/200 │ Time:   0.24s │ Total: 2.6720e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 1.0865e-02 │ Res: 4.4157e+01
# [Phase 1:P1_border_only] Ep  88/200 │ Time:   0.24s │ Total: 2.3191e-02 │ Full L2: 6.6617e-01 │ Sup@bd+pfull: 8.1826e-03 │ Res: 4.4178e+01
# [Phase 1:P1_border_only] Ep  89/200 │ Time:   0.25s │ Total: 2.4607e-02 │ Full L2: 6.6676e-01 │ Sup@bd+pfull: 9.3858e-03 │ Res: 4.4253e+01
# [Phase 1:P1_border_only] Ep  90/200 │ Time:   0.24s │ Total: 2.3310e-02 │ Full L2: 6.6689e-01 │ Sup@bd+pfull: 9.4786e-03 │ Res: 4.4268e+01
# [Phase 1:P1_border_only] Ep  91/200 │ Time:   0.24s │ Total: 2.3903e-02 │ Full L2: 6.6636e-01 │ Sup@bd+pfull: 8.0218e-03 │ Res: 4.4194e+01
# [Phase 1:P1_border_only] Ep  92/200 │ Time:   0.23s │ Total: 2.4939e-02 │ Full L2: 6.6595e-01 │ Sup@bd+pfull: 9.5918e-03 │ Res: 4.4134e+01
# [Phase 1:P1_border_only] Ep  93/200 │ Time:   0.24s │ Total: 2.2717e-02 │ Full L2: 6.6595e-01 │ Sup@bd+pfull: 8.2655e-03 │ Res: 4.4129e+01
# [Phase 1:P1_border_only] Ep  94/200 │ Time:   0.23s │ Total: 2.3552e-02 │ Full L2: 6.6624e-01 │ Sup@bd+pfull: 8.0824e-03 │ Res: 4.4163e+01
# [Phase 1:P1_border_only] Ep  95/200 │ Time:   0.23s │ Total: 2.2147e-02 │ Full L2: 6.6647e-01 │ Sup@bd+pfull: 8.0435e-03 │ Res: 4.4194e+01
# [Phase 1:P1_border_only] Ep  96/200 │ Time:   0.24s │ Total: 2.2297e-02 │ Full L2: 6.6644e-01 │ Sup@bd+pfull: 7.8012e-03 │ Res: 4.4189e+01
# [Phase 1:P1_border_only] Ep  97/200 │ Time:   0.25s │ Total: 2.1366e-02 │ Full L2: 6.6617e-01 │ Sup@bd+pfull: 7.4671e-03 │ Res: 4.4145e+01
# [Phase 1:P1_border_only] Ep  98/200 │ Time:   0.23s │ Total: 2.2214e-02 │ Full L2: 6.6595e-01 │ Sup@bd+pfull: 7.4242e-03 │ Res: 4.4105e+01
# [Phase 1:P1_border_only] Ep  99/200 │ Time:   0.25s │ Total: 2.3224e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 7.7408e-03 │ Res: 4.4103e+01
# [Phase 1:P1_border_only] Ep 100/200 │ Time:   0.24s │ Total: 2.0524e-02 │ Full L2: 6.6608e-01 │ Sup@bd+pfull: 6.6886e-03 │ Res: 4.4123e+01
# [Phase 1:P1_border_only] Ep 101/200 │ Time:   0.25s │ Total: 2.1525e-02 │ Full L2: 6.6614e-01 │ Sup@bd+pfull: 7.3827e-03 │ Res: 4.4128e+01
# [Phase 1:P1_border_only] Ep 102/200 │ Time:   0.24s │ Total: 2.0364e-02 │ Full L2: 6.6612e-01 │ Sup@bd+pfull: 6.7631e-03 │ Res: 4.4122e+01
# [Phase 1:P1_border_only] Ep 103/200 │ Time:   0.24s │ Total: 1.8530e-02 │ Full L2: 6.6609e-01 │ Sup@bd+pfull: 6.4712e-03 │ Res: 4.4112e+01
# [Phase 1:P1_border_only] Ep 104/200 │ Time:   0.23s │ Total: 2.0312e-02 │ Full L2: 6.6605e-01 │ Sup@bd+pfull: 6.4620e-03 │ Res: 4.4105e+01
# [Phase 1:P1_border_only] Ep 105/200 │ Time:   0.24s │ Total: 2.1224e-02 │ Full L2: 6.6598e-01 │ Sup@bd+pfull: 6.7525e-03 │ Res: 4.4094e+01
# [Phase 1:P1_border_only] Ep 106/200 │ Time:   0.24s │ Total: 1.9263e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 6.4932e-03 │ Res: 4.4082e+01
# [Phase 1:P1_border_only] Ep 107/200 │ Time:   0.24s │ Total: 1.8888e-02 │ Full L2: 6.6594e-01 │ Sup@bd+pfull: 6.2905e-03 │ Res: 4.4084e+01
# [Phase 1:P1_border_only] Ep 108/200 │ Time:   0.24s │ Total: 2.0048e-02 │ Full L2: 6.6609e-01 │ Sup@bd+pfull: 6.5875e-03 │ Res: 4.4105e+01
# [Phase 1:P1_border_only] Ep 109/200 │ Time:   0.25s │ Total: 1.8592e-02 │ Full L2: 6.6619e-01 │ Sup@bd+pfull: 6.2406e-03 │ Res: 4.4119e+01
# [Phase 1:P1_border_only] Ep 110/200 │ Time:   0.24s │ Total: 1.8817e-02 │ Full L2: 6.6606e-01 │ Sup@bd+pfull: 6.3387e-03 │ Res: 4.4097e+01
# [Phase 1:P1_border_only] Ep 111/200 │ Time:   0.26s │ Total: 1.9534e-02 │ Full L2: 6.6585e-01 │ Sup@bd+pfull: 6.3601e-03 │ Res: 4.4064e+01
# [Phase 1:P1_border_only] Ep 112/200 │ Time:   0.24s │ Total: 1.8190e-02 │ Full L2: 6.6576e-01 │ Sup@bd+pfull: 6.1653e-03 │ Res: 4.4048e+01
# [Phase 1:P1_border_only] Ep 113/200 │ Time:   0.24s │ Total: 1.7953e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 6.0669e-03 │ Res: 4.4076e+01
# [Phase 1:P1_border_only] Ep 114/200 │ Time:   0.27s │ Total: 1.8288e-02 │ Full L2: 6.6619e-01 │ Sup@bd+pfull: 6.0523e-03 │ Res: 4.4108e+01
# [Phase 1:P1_border_only] Ep 115/200 │ Time:   0.24s │ Total: 1.7558e-02 │ Full L2: 6.6615e-01 │ Sup@bd+pfull: 6.1698e-03 │ Res: 4.4102e+01
# [Phase 1:P1_border_only] Ep 116/200 │ Time:   0.23s │ Total: 1.7997e-02 │ Full L2: 6.6571e-01 │ Sup@bd+pfull: 5.8604e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 117/200 │ Time:   0.24s │ Total: 1.8730e-02 │ Full L2: 6.6551e-01 │ Sup@bd+pfull: 6.7149e-03 │ Res: 4.4005e+01
# [Phase 1:P1_border_only] Ep 118/200 │ Time:   0.25s │ Total: 1.7798e-02 │ Full L2: 6.6575e-01 │ Sup@bd+pfull: 5.8672e-03 │ Res: 4.4038e+01
# [Phase 1:P1_border_only] Ep 119/200 │ Time:   0.24s │ Total: 1.7089e-02 │ Full L2: 6.6614e-01 │ Sup@bd+pfull: 5.7027e-03 │ Res: 4.4093e+01
# [Phase 1:P1_border_only] Ep 120/200 │ Time:   0.24s │ Total: 1.8186e-02 │ Full L2: 6.6625e-01 │ Sup@bd+pfull: 6.0136e-03 │ Res: 4.4106e+01
# [Phase 1:P1_border_only] Ep 121/200 │ Time:   0.23s │ Total: 1.7761e-02 │ Full L2: 6.6610e-01 │ Sup@bd+pfull: 5.7649e-03 │ Res: 4.4083e+01
# [Phase 1:P1_border_only] Ep 122/200 │ Time:   0.25s │ Total: 1.6459e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 5.4586e-03 │ Res: 4.4062e+01
# [Phase 1:P1_border_only] Ep 123/200 │ Time:   0.23s │ Total: 1.6929e-02 │ Full L2: 6.6579e-01 │ Sup@bd+pfull: 5.3838e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 124/200 │ Time:   0.25s │ Total: 1.8401e-02 │ Full L2: 6.6567e-01 │ Sup@bd+pfull: 5.9781e-03 │ Res: 4.4019e+01
# [Phase 1:P1_border_only] Ep 125/200 │ Time:   0.24s │ Total: 1.8325e-02 │ Full L2: 6.6565e-01 │ Sup@bd+pfull: 6.2150e-03 │ Res: 4.4015e+01
# [Phase 1:P1_border_only] Ep 126/200 │ Time:   0.25s │ Total: 1.7231e-02 │ Full L2: 6.6572e-01 │ Sup@bd+pfull: 5.7685e-03 │ Res: 4.4025e+01
# [Phase 1:P1_border_only] Ep 127/200 │ Time:   0.26s │ Total: 1.6422e-02 │ Full L2: 6.6592e-01 │ Sup@bd+pfull: 5.2486e-03 │ Res: 4.4051e+01
# [Phase 1:P1_border_only] Ep 128/200 │ Time:   0.23s │ Total: 1.6789e-02 │ Full L2: 6.6609e-01 │ Sup@bd+pfull: 5.6757e-03 │ Res: 4.4075e+01
# [Phase 1:P1_border_only] Ep 129/200 │ Time:   0.24s │ Total: 1.7177e-02 │ Full L2: 6.6615e-01 │ Sup@bd+pfull: 5.7590e-03 │ Res: 4.4082e+01
# [Phase 1:P1_border_only] Ep 130/200 │ Time:   0.24s │ Total: 1.6760e-02 │ Full L2: 6.6605e-01 │ Sup@bd+pfull: 5.3955e-03 │ Res: 4.4067e+01
# [Phase 1:P1_border_only] Ep 131/200 │ Time:   0.23s │ Total: 1.6031e-02 │ Full L2: 6.6588e-01 │ Sup@bd+pfull: 5.3254e-03 │ Res: 4.4042e+01
# [Phase 1:P1_border_only] Ep 132/200 │ Time:   0.24s │ Total: 1.6137e-02 │ Full L2: 6.6573e-01 │ Sup@bd+pfull: 5.1964e-03 │ Res: 4.4020e+01
# [Phase 1:P1_border_only] Ep 133/200 │ Time:   0.25s │ Total: 1.6759e-02 │ Full L2: 6.6571e-01 │ Sup@bd+pfull: 5.3833e-03 │ Res: 4.4015e+01
# [Phase 1:P1_border_only] Ep 134/200 │ Time:   0.23s │ Total: 1.6517e-02 │ Full L2: 6.6580e-01 │ Sup@bd+pfull: 5.4304e-03 │ Res: 4.4026e+01
# [Phase 1:P1_border_only] Ep 135/200 │ Time:   0.24s │ Total: 1.5761e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 4.9997e-03 │ Res: 4.4051e+01
# [Phase 1:P1_border_only] Ep 136/200 │ Time:   0.24s │ Total: 1.5931e-02 │ Full L2: 6.6605e-01 │ Sup@bd+pfull: 5.1253e-03 │ Res: 4.4063e+01
# [Phase 1:P1_border_only] Ep 137/200 │ Time:   0.23s │ Total: 1.6211e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 5.2242e-03 │ Res: 4.4057e+01
# [Phase 1:P1_border_only] Ep 138/200 │ Time:   0.24s │ Total: 1.5710e-02 │ Full L2: 6.6586e-01 │ Sup@bd+pfull: 5.0106e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 139/200 │ Time:   0.24s │ Total: 1.5461e-02 │ Full L2: 6.6576e-01 │ Sup@bd+pfull: 5.0064e-03 │ Res: 4.4017e+01
# [Phase 1:P1_border_only] Ep 140/200 │ Time:   0.23s │ Total: 1.5553e-02 │ Full L2: 6.6581e-01 │ Sup@bd+pfull: 4.9289e-03 │ Res: 4.4024e+01
# [Phase 1:P1_border_only] Ep 141/200 │ Time:   0.24s │ Total: 1.5455e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 4.9909e-03 │ Res: 4.4038e+01
# [Phase 1:P1_border_only] Ep 142/200 │ Time:   0.23s │ Total: 1.5091e-02 │ Full L2: 6.6592e-01 │ Sup@bd+pfull: 4.8178e-03 │ Res: 4.4039e+01
# [Phase 1:P1_border_only] Ep 143/200 │ Time:   0.24s │ Total: 1.4965e-02 │ Full L2: 6.6588e-01 │ Sup@bd+pfull: 4.7324e-03 │ Res: 4.4032e+01
# [Phase 1:P1_border_only] Ep 144/200 │ Time:   0.23s │ Total: 1.5159e-02 │ Full L2: 6.6587e-01 │ Sup@bd+pfull: 4.8587e-03 │ Res: 4.4029e+01
# [Phase 1:P1_border_only] Ep 145/200 │ Time:   0.24s │ Total: 1.5022e-02 │ Full L2: 6.6589e-01 │ Sup@bd+pfull: 4.7620e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 146/200 │ Time:   0.23s │ Total: 1.4839e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 4.6880e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 147/200 │ Time:   0.23s │ Total: 1.4886e-02 │ Full L2: 6.6589e-01 │ Sup@bd+pfull: 4.7564e-03 │ Res: 4.4032e+01
# [Phase 1:P1_border_only] Ep 148/200 │ Time:   0.23s │ Total: 1.4831e-02 │ Full L2: 6.6585e-01 │ Sup@bd+pfull: 4.6859e-03 │ Res: 4.4025e+01
# [Phase 1:P1_border_only] Ep 149/200 │ Time:   0.24s │ Total: 1.4650e-02 │ Full L2: 6.6586e-01 │ Sup@bd+pfull: 4.6170e-03 │ Res: 4.4025e+01
# [Phase 1:P1_border_only] Ep 150/200 │ Time:   0.24s │ Total: 1.4612e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 4.6189e-03 │ Res: 4.4032e+01
# [Phase 1:P1_border_only] Ep 151/200 │ Time:   0.24s │ Total: 1.4586e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 4.5774e-03 │ Res: 4.4039e+01
# [Phase 1:P1_border_only] Ep 152/200 │ Time:   0.23s │ Total: 1.4415e-02 │ Full L2: 6.6593e-01 │ Sup@bd+pfull: 4.4999e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 153/200 │ Time:   0.23s │ Total: 1.4278e-02 │ Full L2: 6.6586e-01 │ Sup@bd+pfull: 4.4316e-03 │ Res: 4.4025e+01
# [Phase 1:P1_border_only] Ep 154/200 │ Time:   0.23s │ Total: 1.4266e-02 │ Full L2: 6.6589e-01 │ Sup@bd+pfull: 4.4316e-03 │ Res: 4.4027e+01
# [Phase 1:P1_border_only] Ep 155/200 │ Time:   0.24s │ Total: 1.4139e-02 │ Full L2: 6.6593e-01 │ Sup@bd+pfull: 4.3494e-03 │ Res: 4.4033e+01
# [Phase 1:P1_border_only] Ep 156/200 │ Time:   0.24s │ Total: 1.4069e-02 │ Full L2: 6.6590e-01 │ Sup@bd+pfull: 4.3448e-03 │ Res: 4.4029e+01
# [Phase 1:P1_border_only] Ep 157/200 │ Time:   0.24s │ Total: 1.4040e-02 │ Full L2: 6.6589e-01 │ Sup@bd+pfull: 4.3170e-03 │ Res: 4.4026e+01
# [Phase 1:P1_border_only] Ep 158/200 │ Time:   0.25s │ Total: 1.3853e-02 │ Full L2: 6.6592e-01 │ Sup@bd+pfull: 4.2086e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 159/200 │ Time:   0.23s │ Total: 1.3794e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 4.2093e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 160/200 │ Time:   0.23s │ Total: 1.3687e-02 │ Full L2: 6.6593e-01 │ Sup@bd+pfull: 4.1311e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 161/200 │ Time:   0.24s │ Total: 1.3595e-02 │ Full L2: 6.6588e-01 │ Sup@bd+pfull: 4.1036e-03 │ Res: 4.4023e+01
# [Phase 1:P1_border_only] Ep 162/200 │ Time:   0.24s │ Total: 1.3520e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 4.0692e-03 │ Res: 4.4026e+01
# [Phase 1:P1_border_only] Ep 163/200 │ Time:   0.24s │ Total: 1.3437e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 4.0299e-03 │ Res: 4.4034e+01
# [Phase 1:P1_border_only] Ep 164/200 │ Time:   0.25s │ Total: 1.3408e-02 │ Full L2: 6.6599e-01 │ Sup@bd+pfull: 4.0189e-03 │ Res: 4.4038e+01
# [Phase 1:P1_border_only] Ep 165/200 │ Time:   0.24s │ Total: 1.3360e-02 │ Full L2: 6.6595e-01 │ Sup@bd+pfull: 3.9947e-03 │ Res: 4.4033e+01
# [Phase 1:P1_border_only] Ep 166/200 │ Time:   0.23s │ Total: 1.3287e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 3.9630e-03 │ Res: 4.4026e+01
# [Phase 1:P1_border_only] Ep 167/200 │ Time:   0.24s │ Total: 1.3244e-02 │ Full L2: 6.6591e-01 │ Sup@bd+pfull: 3.9435e-03 │ Res: 4.4026e+01
# [Phase 1:P1_border_only] Ep 168/200 │ Time:   0.26s │ Total: 1.3183e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 3.9115e-03 │ Res: 4.4034e+01
# [Phase 1:P1_border_only] Ep 169/200 │ Time:   0.24s │ Total: 1.3123e-02 │ Full L2: 6.6598e-01 │ Sup@bd+pfull: 3.8924e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 170/200 │ Time:   0.24s │ Total: 1.3059e-02 │ Full L2: 6.6594e-01 │ Sup@bd+pfull: 3.8530e-03 │ Res: 4.4030e+01
# [Phase 1:P1_border_only] Ep 171/200 │ Time:   0.23s │ Total: 1.3016e-02 │ Full L2: 6.6592e-01 │ Sup@bd+pfull: 3.8452e-03 │ Res: 4.4027e+01
# [Phase 1:P1_border_only] Ep 172/200 │ Time:   0.23s │ Total: 1.2933e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 3.7971e-03 │ Res: 4.4032e+01
# [Phase 1:P1_border_only] Ep 173/200 │ Time:   0.24s │ Total: 1.2876e-02 │ Full L2: 6.6598e-01 │ Sup@bd+pfull: 3.7770e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 174/200 │ Time:   0.23s │ Total: 1.2811e-02 │ Full L2: 6.6596e-01 │ Sup@bd+pfull: 3.7447e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 175/200 │ Time:   0.24s │ Total: 1.2745e-02 │ Full L2: 6.6595e-01 │ Sup@bd+pfull: 3.7134e-03 │ Res: 4.4029e+01
# [Phase 1:P1_border_only] Ep 176/200 │ Time:   0.23s │ Total: 1.2679e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 3.6879e-03 │ Res: 4.4033e+01
# [Phase 1:P1_border_only] Ep 177/200 │ Time:   0.23s │ Total: 1.2615e-02 │ Full L2: 6.6599e-01 │ Sup@bd+pfull: 3.6559e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 178/200 │ Time:   0.24s │ Total: 1.2546e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 3.6292e-03 │ Res: 4.4031e+01
# [Phase 1:P1_border_only] Ep 179/200 │ Time:   0.24s │ Total: 1.2479e-02 │ Full L2: 6.6597e-01 │ Sup@bd+pfull: 3.5948e-03 │ Res: 4.4032e+01
# [Phase 1:P1_border_only] Ep 180/200 │ Time:   0.25s │ Total: 1.2418e-02 │ Full L2: 6.6601e-01 │ Sup@bd+pfull: 3.5771e-03 │ Res: 4.4037e+01
# [Phase 1:P1_border_only] Ep 181/200 │ Time:   0.23s │ Total: 1.2335e-02 │ Full L2: 6.6600e-01 │ Sup@bd+pfull: 3.5311e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 182/200 │ Time:   0.24s │ Total: 1.2293e-02 │ Full L2: 6.6599e-01 │ Sup@bd+pfull: 3.5146e-03 │ Res: 4.4034e+01
# [Phase 1:P1_border_only] Ep 183/200 │ Time:   0.24s │ Total: 1.2262e-02 │ Full L2: 6.6600e-01 │ Sup@bd+pfull: 3.4999e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 184/200 │ Time:   0.24s │ Total: 1.2227e-02 │ Full L2: 6.6601e-01 │ Sup@bd+pfull: 3.4879e-03 │ Res: 4.4037e+01
# [Phase 1:P1_border_only] Ep 185/200 │ Time:   0.24s │ Total: 1.2175e-02 │ Full L2: 6.6600e-01 │ Sup@bd+pfull: 3.4617e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 186/200 │ Time:   0.24s │ Total: 1.2137e-02 │ Full L2: 6.6599e-01 │ Sup@bd+pfull: 3.4465e-03 │ Res: 4.4034e+01
# [Phase 1:P1_border_only] Ep 187/200 │ Time:   0.24s │ Total: 1.2089e-02 │ Full L2: 6.6600e-01 │ Sup@bd+pfull: 3.4251e-03 │ Res: 4.4035e+01
# [Phase 1:P1_border_only] Ep 188/200 │ Time:   0.24s │ Total: 1.2043e-02 │ Full L2: 6.6601e-01 │ Sup@bd+pfull: 3.4035e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 189/200 │ Time:   0.23s │ Total: 1.1999e-02 │ Full L2: 6.6601e-01 │ Sup@bd+pfull: 3.3841e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 190/200 │ Time:   0.23s │ Total: 1.1950e-02 │ Full L2: 6.6601e-01 │ Sup@bd+pfull: 3.3607e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 191/200 │ Time:   0.23s │ Total: 1.1903e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.3422e-03 │ Res: 4.4037e+01
# [Phase 1:P1_border_only] Ep 192/200 │ Time:   0.24s │ Total: 1.1852e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.3181e-03 │ Res: 4.4037e+01
# [Phase 1:P1_border_only] Ep 193/200 │ Time:   0.23s │ Total: 1.1805e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.2982e-03 │ Res: 4.4037e+01
# [Phase 1:P1_border_only] Ep 194/200 │ Time:   0.24s │ Total: 1.1754e-02 │ Full L2: 6.6603e-01 │ Sup@bd+pfull: 3.2742e-03 │ Res: 4.4039e+01
# [Phase 1:P1_border_only] Ep 195/200 │ Time:   0.25s │ Total: 1.1706e-02 │ Full L2: 6.6603e-01 │ Sup@bd+pfull: 3.2533e-03 │ Res: 4.4039e+01
# [Phase 1:P1_border_only] Ep 196/200 │ Time:   0.23s │ Total: 1.1660e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.2341e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 197/200 │ Time:   0.23s │ Total: 1.1616e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.2151e-03 │ Res: 4.4036e+01
# [Phase 1:P1_border_only] Ep 198/200 │ Time:   0.25s │ Total: 1.1563e-02 │ Full L2: 6.6604e-01 │ Sup@bd+pfull: 3.1931e-03 │ Res: 4.4040e+01
# [Phase 1:P1_border_only] Ep 199/200 │ Time:   0.24s │ Total: 1.1519e-02 │ Full L2: 6.6604e-01 │ Sup@bd+pfull: 3.1722e-03 │ Res: 4.4040e+01
# [Phase 1:P1_border_only] Ep 200/200 │ Time:   0.24s │ Total: 1.1471e-02 │ Full L2: 6.6602e-01 │ Sup@bd+pfull: 3.1544e-03 │ Res: 4.4037e+01
# → Saved loss history for phase 'P1_border_only' in loss/Spline_Multi_Stage_Adam_ep100_m24_w64_T10/loss_P1_border_only.csv
#
# ===== Phase 2/2: P2_res_warm  (epochs=200) =====
# lambdas → bd:1.0  res:0.5
# [Phase 2:P2_res_warm] Ep   1/200 │ Time:   0.24s │ Total: 2.2030e+01 │ Full L2: 6.6603e-01 │ Sup@bd+pfull: 3.1309e-03 │ Res: 4.4038e+01
# [Phase 2:P2_res_warm] Ep   2/200 │ Time:   0.23s │ Total: 6.6535e+00 │ Full L2: 3.1899e-01 │ Sup@bd+pfull: 2.2263e-01 │ Res: 1.2182e+01
# [Phase 2:P2_res_warm] Ep   3/200 │ Time:   0.24s │ Total: 4.3032e+00 │ Full L2: 2.5748e-01 │ Sup@bd+pfull: 1.4014e-01 │ Res: 7.7560e+00
# [Phase 2:P2_res_warm] Ep   4/200 │ Time:   0.23s │ Total: 2.2992e+00 │ Full L2: 2.0454e-01 │ Sup@bd+pfull: 1.3426e-01 │ Res: 3.9003e+00
# [Phase 2:P2_res_warm] Ep   5/200 │ Time:   0.23s │ Total: 1.8021e+00 │ Full L2: 1.8759e-01 │ Sup@bd+pfull: 1.4339e-01 │ Res: 2.8452e+00
# [Phase 2:P2_res_warm] Ep   6/200 │ Time:   0.23s │ Total: 1.8369e+00 │ Full L2: 1.8583e-01 │ Sup@bd+pfull: 1.3217e-01 │ Res: 3.0776e+00
# [Phase 2:P2_res_warm] Ep   7/200 │ Time:   0.23s │ Total: 1.0159e+00 │ Full L2: 1.3709e-01 │ Sup@bd+pfull: 8.7344e-02 │ Res: 1.4701e+00
# [Phase 2:P2_res_warm] Ep   8/200 │ Time:   0.23s │ Total: 9.2396e-01 │ Full L2: 1.1652e-01 │ Sup@bd+pfull: 8.6442e-02 │ Res: 1.3542e+00
# [Phase 2:P2_res_warm] Ep   9/200 │ Time:   0.24s │ Total: 8.4226e-01 │ Full L2: 1.2905e-01 │ Sup@bd+pfull: 8.3773e-02 │ Res: 1.1872e+00
# [Phase 2:P2_res_warm] Ep  10/200 │ Time:   0.23s │ Total: 6.8040e-01 │ Full L2: 1.1926e-01 │ Sup@bd+pfull: 7.5749e-02 │ Res: 9.3561e-01
# [Phase 2:P2_res_warm] Ep  11/200 │ Time:   0.23s │ Total: 6.2430e-01 │ Full L2: 1.1279e-01 │ Sup@bd+pfull: 7.3689e-02 │ Res: 8.1873e-01
# [Phase 2:P2_res_warm] Ep  12/200 │ Time:   0.23s │ Total: 5.1118e-01 │ Full L2: 9.2603e-02 │ Sup@bd+pfull: 8.4087e-02 │ Res: 6.1520e-01
# [Phase 2:P2_res_warm] Ep  13/200 │ Time:   0.25s │ Total: 4.5832e-01 │ Full L2: 9.4281e-02 │ Sup@bd+pfull: 6.9668e-02 │ Res: 5.4375e-01
# [Phase 2:P2_res_warm] Ep  14/200 │ Time:   0.23s │ Total: 4.0047e-01 │ Full L2: 9.0197e-02 │ Sup@bd+pfull: 6.5195e-02 │ Res: 4.2953e-01
# [Phase 2:P2_res_warm] Ep  15/200 │ Time:   0.24s │ Total: 3.3252e-01 │ Full L2: 9.6138e-02 │ Sup@bd+pfull: 6.5530e-02 │ Res: 3.0275e-01
# [Phase 2:P2_res_warm] Ep  16/200 │ Time:   0.24s │ Total: 3.8447e-01 │ Full L2: 7.7071e-02 │ Sup@bd+pfull: 6.4463e-02 │ Res: 4.0144e-01
# [Phase 2:P2_res_warm] Ep  17/200 │ Time:   0.24s │ Total: 3.0947e-01 │ Full L2: 8.9110e-02 │ Sup@bd+pfull: 5.4368e-02 │ Res: 2.9590e-01
# [Phase 2:P2_res_warm] Ep  18/200 │ Time:   0.23s │ Total: 2.5865e-01 │ Full L2: 7.7268e-02 │ Sup@bd+pfull: 5.5377e-02 │ Res: 1.9055e-01
# [Phase 2:P2_res_warm] Ep  19/200 │ Time:   0.23s │ Total: 2.6259e-01 │ Full L2: 7.3992e-02 │ Sup@bd+pfull: 5.2231e-02 │ Res: 2.3766e-01
# [Phase 2:P2_res_warm] Ep  20/200 │ Time:   0.25s │ Total: 2.5676e-01 │ Full L2: 8.4045e-02 │ Sup@bd+pfull: 5.3098e-02 │ Res: 2.3258e-01
# [Phase 2:P2_res_warm] Ep  21/200 │ Time:   0.24s │ Total: 2.0479e-01 │ Full L2: 6.7977e-02 │ Sup@bd+pfull: 5.6975e-02 │ Res: 1.5770e-01
# [Phase 2:P2_res_warm] Ep  22/200 │ Time:   0.23s │ Total: 1.6317e-01 │ Full L2: 6.7337e-02 │ Sup@bd+pfull: 3.8620e-02 │ Res: 1.3968e-01
# [Phase 2:P2_res_warm] Ep  23/200 │ Time:   0.26s │ Total: 1.2120e-01 │ Full L2: 6.9295e-02 │ Sup@bd+pfull: 2.6875e-02 │ Res: 8.9933e-02
# [Phase 2:P2_res_warm] Ep  24/200 │ Time:   0.25s │ Total: 1.4543e-01 │ Full L2: 6.8757e-02 │ Sup@bd+pfull: 3.3627e-02 │ Res: 1.1112e-01
# [Phase 2:P2_res_warm] Ep  25/200 │ Time:   0.23s │ Total: 1.3361e-01 │ Full L2: 6.3255e-02 │ Sup@bd+pfull: 3.5698e-02 │ Res: 9.5813e-02
# [Phase 2:P2_res_warm] Ep  26/200 │ Time:   0.25s │ Total: 1.3040e-01 │ Full L2: 6.4865e-02 │ Sup@bd+pfull: 3.2843e-02 │ Res: 9.2079e-02
# [Phase 2:P2_res_warm] Ep  27/200 │ Time:   0.26s │ Total: 1.1055e-01 │ Full L2: 6.3367e-02 │ Sup@bd+pfull: 2.9461e-02 │ Res: 7.0242e-02
# [Phase 2:P2_res_warm] Ep  28/200 │ Time:   0.23s │ Total: 1.4007e-01 │ Full L2: 6.7294e-02 │ Sup@bd+pfull: 3.1011e-02 │ Res: 7.8146e-02
# [Phase 2:P2_res_warm] Ep  29/200 │ Time:   0.24s │ Total: 1.0845e-01 │ Full L2: 6.0872e-02 │ Sup@bd+pfull: 2.7540e-02 │ Res: 5.3180e-02
# [Phase 2:P2_res_warm] Ep  30/200 │ Time:   0.24s │ Total: 1.4422e-01 │ Full L2: 6.0211e-02 │ Sup@bd+pfull: 3.0165e-02 │ Res: 7.8575e-02
# [Phase 2:P2_res_warm] Ep  31/200 │ Time:   0.23s │ Total: 1.3986e-01 │ Full L2: 6.3010e-02 │ Sup@bd+pfull: 2.6137e-02 │ Res: 7.2990e-02
# [Phase 2:P2_res_warm] Ep  32/200 │ Time:   0.24s │ Total: 1.1497e-01 │ Full L2: 6.5192e-02 │ Sup@bd+pfull: 2.4797e-02 │ Res: 6.0356e-02
# [Phase 2:P2_res_warm] Ep  33/200 │ Time:   0.24s │ Total: 1.2165e-01 │ Full L2: 6.3512e-02 │ Sup@bd+pfull: 2.3497e-02 │ Res: 6.8061e-02
# [Phase 2:P2_res_warm] Ep  34/200 │ Time:   0.24s │ Total: 1.0973e-01 │ Full L2: 5.9354e-02 │ Sup@bd+pfull: 2.4122e-02 │ Res: 4.9079e-02
# [Phase 2:P2_res_warm] Ep  35/200 │ Time:   0.24s │ Total: 1.0057e-01 │ Full L2: 5.8426e-02 │ Sup@bd+pfull: 2.2244e-02 │ Res: 5.3712e-02
# [Phase 2:P2_res_warm] Ep  36/200 │ Time:   0.24s │ Total: 1.0297e-01 │ Full L2: 5.6950e-02 │ Sup@bd+pfull: 2.2384e-02 │ Res: 5.5175e-02
# [Phase 2:P2_res_warm] Ep  37/200 │ Time:   0.25s │ Total: 8.7851e-02 │ Full L2: 5.7663e-02 │ Sup@bd+pfull: 2.2551e-02 │ Res: 3.4559e-02
# [Phase 2:P2_res_warm] Ep  38/200 │ Time:   0.23s │ Total: 1.0295e-01 │ Full L2: 6.1776e-02 │ Sup@bd+pfull: 2.6278e-02 │ Res: 5.7578e-02
# [Phase 2:P2_res_warm] Ep  39/200 │ Time:   0.23s │ Total: 7.1197e-02 │ Full L2: 5.5184e-02 │ Sup@bd+pfull: 2.1380e-02 │ Res: 2.4476e-02
# [Phase 2:P2_res_warm] Ep  40/200 │ Time:   0.24s │ Total: 1.0792e-01 │ Full L2: 5.8768e-02 │ Sup@bd+pfull: 2.6209e-02 │ Res: 4.8502e-02
# [Phase 2:P2_res_warm] Ep  41/200 │ Time:   0.24s │ Total: 1.1172e-01 │ Full L2: 6.0075e-02 │ Sup@bd+pfull: 2.7515e-02 │ Res: 4.7092e-02
# [Phase 2:P2_res_warm] Ep  42/200 │ Time:   0.24s │ Total: 7.4118e-02 │ Full L2: 5.6473e-02 │ Sup@bd+pfull: 1.9942e-02 │ Res: 2.5555e-02
# [Phase 2:P2_res_warm] Ep  43/200 │ Time:   0.24s │ Total: 6.5817e-02 │ Full L2: 5.4640e-02 │ Sup@bd+pfull: 1.8569e-02 │ Res: 2.6917e-02
# [Phase 2:P2_res_warm] Ep  44/200 │ Time:   0.25s │ Total: 8.5214e-02 │ Full L2: 5.6643e-02 │ Sup@bd+pfull: 2.0197e-02 │ Res: 3.8790e-02
# [Phase 2:P2_res_warm] Ep  45/200 │ Time:   0.24s │ Total: 6.9931e-02 │ Full L2: 5.6998e-02 │ Sup@bd+pfull: 1.8557e-02 │ Res: 2.7049e-02
# [Phase 2:P2_res_warm] Ep  46/200 │ Time:   0.23s │ Total: 5.8325e-02 │ Full L2: 5.6339e-02 │ Sup@bd+pfull: 1.6835e-02 │ Res: 2.1223e-02
# [Phase 2:P2_res_warm] Ep  47/200 │ Time:   0.24s │ Total: 7.1301e-02 │ Full L2: 5.6339e-02 │ Sup@bd+pfull: 1.8916e-02 │ Res: 3.0393e-02
# [Phase 2:P2_res_warm] Ep  48/200 │ Time:   0.23s │ Total: 5.6996e-02 │ Full L2: 5.4839e-02 │ Sup@bd+pfull: 1.6303e-02 │ Res: 2.4672e-02
# [Phase 2:P2_res_warm] Ep  49/200 │ Time:   0.24s │ Total: 5.4612e-02 │ Full L2: 5.3745e-02 │ Sup@bd+pfull: 1.3380e-02 │ Res: 2.1084e-02
# [Phase 2:P2_res_warm] Ep  50/200 │ Time:   0.24s │ Total: 5.5393e-02 │ Full L2: 5.3103e-02 │ Sup@bd+pfull: 1.5685e-02 │ Res: 1.9956e-02
# [Phase 2:P2_res_warm] Ep  51/200 │ Time:   0.24s │ Total: 5.0255e-02 │ Full L2: 5.4128e-02 │ Sup@bd+pfull: 1.3686e-02 │ Res: 2.0680e-02
# [Phase 2:P2_res_warm] Ep  52/200 │ Time:   0.24s │ Total: 5.2776e-02 │ Full L2: 5.5828e-02 │ Sup@bd+pfull: 1.2884e-02 │ Res: 1.8253e-02
# [Phase 2:P2_res_warm] Ep  53/200 │ Time:   0.23s │ Total: 4.1641e-02 │ Full L2: 5.5848e-02 │ Sup@bd+pfull: 1.2056e-02 │ Res: 1.4621e-02
# [Phase 2:P2_res_warm] Ep  54/200 │ Time:   0.24s │ Total: 5.3263e-02 │ Full L2: 5.2882e-02 │ Sup@bd+pfull: 1.3016e-02 │ Res: 1.5776e-02
# [Phase 2:P2_res_warm] Ep  55/200 │ Time:   0.25s │ Total: 5.5799e-02 │ Full L2: 5.1115e-02 │ Sup@bd+pfull: 1.2433e-02 │ Res: 1.5545e-02
# [Phase 2:P2_res_warm] Ep  56/200 │ Time:   0.24s │ Total: 4.7635e-02 │ Full L2: 5.2572e-02 │ Sup@bd+pfull: 1.2876e-02 │ Res: 1.1777e-02
# [Phase 2:P2_res_warm] Ep  57/200 │ Time:   0.25s │ Total: 5.0389e-02 │ Full L2: 5.4644e-02 │ Sup@bd+pfull: 1.5323e-02 │ Res: 1.4576e-02
# [Phase 2:P2_res_warm] Ep  58/200 │ Time:   0.25s │ Total: 5.1008e-02 │ Full L2: 5.5596e-02 │ Sup@bd+pfull: 1.1670e-02 │ Res: 1.2239e-02
# [Phase 2:P2_res_warm] Ep  59/200 │ Time:   0.24s │ Total: 4.4589e-02 │ Full L2: 5.5458e-02 │ Sup@bd+pfull: 1.2216e-02 │ Res: 1.3514e-02
# [Phase 2:P2_res_warm] Ep  60/200 │ Time:   0.24s │ Total: 4.5992e-02 │ Full L2: 5.3231e-02 │ Sup@bd+pfull: 9.9020e-03 │ Res: 1.2264e-02
# [Phase 2:P2_res_warm] Ep  61/200 │ Time:   0.24s │ Total: 4.8168e-02 │ Full L2: 5.0336e-02 │ Sup@bd+pfull: 1.1356e-02 │ Res: 1.3497e-02
# [Phase 2:P2_res_warm] Ep  62/200 │ Time:   0.23s │ Total: 3.7138e-02 │ Full L2: 4.9985e-02 │ Sup@bd+pfull: 1.0177e-02 │ Res: 1.2950e-02
# [Phase 2:P2_res_warm] Ep  63/200 │ Time:   0.24s │ Total: 3.5560e-02 │ Full L2: 5.2116e-02 │ Sup@bd+pfull: 7.5172e-03 │ Res: 9.0534e-03
# [Phase 2:P2_res_warm] Ep  64/200 │ Time:   0.23s │ Total: 4.4746e-02 │ Full L2: 5.5010e-02 │ Sup@bd+pfull: 9.8979e-03 │ Res: 1.0558e-02
# [Phase 2:P2_res_warm] Ep  65/200 │ Time:   0.24s │ Total: 4.2359e-02 │ Full L2: 5.6528e-02 │ Sup@bd+pfull: 9.5771e-03 │ Res: 1.2954e-02
# [Phase 2:P2_res_warm] Ep  66/200 │ Time:   0.24s │ Total: 3.5986e-02 │ Full L2: 5.4988e-02 │ Sup@bd+pfull: 8.9934e-03 │ Res: 1.0585e-02
# [Phase 2:P2_res_warm] Ep  67/200 │ Time:   0.23s │ Total: 3.4672e-02 │ Full L2: 5.2116e-02 │ Sup@bd+pfull: 8.4162e-03 │ Res: 8.9858e-03
# [Phase 2:P2_res_warm] Ep  68/200 │ Time:   0.24s │ Total: 3.6895e-02 │ Full L2: 4.9774e-02 │ Sup@bd+pfull: 7.7776e-03 │ Res: 1.0929e-02
# [Phase 2:P2_res_warm] Ep  69/200 │ Time:   0.24s │ Total: 3.7122e-02 │ Full L2: 4.9737e-02 │ Sup@bd+pfull: 9.1450e-03 │ Res: 1.1693e-02
# [Phase 2:P2_res_warm] Ep  70/200 │ Time:   0.24s │ Total: 2.9752e-02 │ Full L2: 5.1481e-02 │ Sup@bd+pfull: 7.5792e-03 │ Res: 8.8667e-03
# [Phase 2:P2_res_warm] Ep  71/200 │ Time:   0.24s │ Total: 3.2148e-02 │ Full L2: 5.3672e-02 │ Sup@bd+pfull: 7.6253e-03 │ Res: 8.8986e-03
# [Phase 2:P2_res_warm] Ep  72/200 │ Time:   0.23s │ Total: 3.1313e-02 │ Full L2: 5.4576e-02 │ Sup@bd+pfull: 8.4569e-03 │ Res: 9.7494e-03
# [Phase 2:P2_res_warm] Ep  73/200 │ Time:   0.23s │ Total: 3.0446e-02 │ Full L2: 5.3646e-02 │ Sup@bd+pfull: 7.3714e-03 │ Res: 8.6472e-03
# [Phase 2:P2_res_warm] Ep  74/200 │ Time:   0.24s │ Total: 2.9848e-02 │ Full L2: 5.1940e-02 │ Sup@bd+pfull: 7.8107e-03 │ Res: 8.3980e-03
# [Phase 2:P2_res_warm] Ep  75/200 │ Time:   0.24s │ Total: 2.9379e-02 │ Full L2: 5.0973e-02 │ Sup@bd+pfull: 6.6705e-03 │ Res: 8.4548e-03
# [Phase 2:P2_res_warm] Ep  76/200 │ Time:   0.24s │ Total: 2.8430e-02 │ Full L2: 5.1630e-02 │ Sup@bd+pfull: 8.1633e-03 │ Res: 8.8417e-03
# [Phase 2:P2_res_warm] Ep  77/200 │ Time:   0.24s │ Total: 2.9791e-02 │ Full L2: 5.2043e-02 │ Sup@bd+pfull: 5.9374e-03 │ Res: 7.8599e-03
# [Phase 2:P2_res_warm] Ep  78/200 │ Time:   0.24s │ Total: 2.8852e-02 │ Full L2: 5.1959e-02 │ Sup@bd+pfull: 8.0286e-03 │ Res: 8.3007e-03
# [Phase 2:P2_res_warm] Ep  79/200 │ Time:   0.24s │ Total: 3.0133e-02 │ Full L2: 5.2410e-02 │ Sup@bd+pfull: 6.6212e-03 │ Res: 8.1212e-03
# [Phase 2:P2_res_warm] Ep  80/200 │ Time:   0.25s │ Total: 2.9766e-02 │ Full L2: 5.3282e-02 │ Sup@bd+pfull: 7.5656e-03 │ Res: 8.3267e-03
# [Phase 2:P2_res_warm] Ep  81/200 │ Time:   0.24s │ Total: 2.7652e-02 │ Full L2: 5.2814e-02 │ Sup@bd+pfull: 6.6760e-03 │ Res: 7.7461e-03
# [Phase 2:P2_res_warm] Ep  82/200 │ Time:   0.24s │ Total: 2.5436e-02 │ Full L2: 5.2161e-02 │ Sup@bd+pfull: 6.0652e-03 │ Res: 7.6181e-03
# [Phase 2:P2_res_warm] Ep  83/200 │ Time:   0.24s │ Total: 2.2013e-02 │ Full L2: 5.1597e-02 │ Sup@bd+pfull: 5.3504e-03 │ Res: 7.2591e-03
# [Phase 2:P2_res_warm] Ep  84/200 │ Time:   0.23s │ Total: 2.3536e-02 │ Full L2: 5.1722e-02 │ Sup@bd+pfull: 5.5176e-03 │ Res: 7.3920e-03
# [Phase 2:P2_res_warm] Ep  85/200 │ Time:   0.25s │ Total: 2.3075e-02 │ Full L2: 5.1969e-02 │ Sup@bd+pfull: 6.0645e-03 │ Res: 7.5340e-03
# [Phase 2:P2_res_warm] Ep  86/200 │ Time:   0.24s │ Total: 2.1588e-02 │ Full L2: 5.1854e-02 │ Sup@bd+pfull: 5.0754e-03 │ Res: 6.9408e-03
# [Phase 2:P2_res_warm] Ep  87/200 │ Time:   0.25s │ Total: 2.1414e-02 │ Full L2: 5.1579e-02 │ Sup@bd+pfull: 5.1569e-03 │ Res: 7.1228e-03
# [Phase 2:P2_res_warm] Ep  88/200 │ Time:   0.23s │ Total: 2.1435e-02 │ Full L2: 5.1821e-02 │ Sup@bd+pfull: 5.4486e-03 │ Res: 7.2469e-03
# [Phase 2:P2_res_warm] Ep  89/200 │ Time:   0.25s │ Total: 2.0216e-02 │ Full L2: 5.2151e-02 │ Sup@bd+pfull: 4.9054e-03 │ Res: 6.7952e-03
# [Phase 2:P2_res_warm] Ep  90/200 │ Time:   0.24s │ Total: 2.0354e-02 │ Full L2: 5.1802e-02 │ Sup@bd+pfull: 4.9344e-03 │ Res: 6.8574e-03
# [Phase 2:P2_res_warm] Ep  91/200 │ Time:   0.24s │ Total: 1.9463e-02 │ Full L2: 5.1518e-02 │ Sup@bd+pfull: 4.9744e-03 │ Res: 6.7926e-03
# [Phase 2:P2_res_warm] Ep  92/200 │ Time:   0.23s │ Total: 1.9532e-02 │ Full L2: 5.1895e-02 │ Sup@bd+pfull: 4.5710e-03 │ Res: 6.7366e-03
# [Phase 2:P2_res_warm] Ep  93/200 │ Time:   0.24s │ Total: 1.8794e-02 │ Full L2: 5.2179e-02 │ Sup@bd+pfull: 4.7475e-03 │ Res: 6.7247e-03
# [Phase 2:P2_res_warm] Ep  94/200 │ Time:   0.25s │ Total: 1.8826e-02 │ Full L2: 5.1635e-02 │ Sup@bd+pfull: 4.3732e-03 │ Res: 6.6250e-03
# [Phase 2:P2_res_warm] Ep  95/200 │ Time:   0.23s │ Total: 1.8545e-02 │ Full L2: 5.1296e-02 │ Sup@bd+pfull: 4.8838e-03 │ Res: 6.6460e-03
# [Phase 2:P2_res_warm] Ep  96/200 │ Time:   0.23s │ Total: 1.8080e-02 │ Full L2: 5.1826e-02 │ Sup@bd+pfull: 4.2433e-03 │ Res: 6.5536e-03
# [Phase 2:P2_res_warm] Ep  97/200 │ Time:   0.23s │ Total: 1.7838e-02 │ Full L2: 5.2166e-02 │ Sup@bd+pfull: 4.4806e-03 │ Res: 6.5623e-03
# [Phase 2:P2_res_warm] Ep  98/200 │ Time:   0.23s │ Total: 1.7983e-02 │ Full L2: 5.1718e-02 │ Sup@bd+pfull: 4.3745e-03 │ Res: 6.4850e-03
# [Phase 2:P2_res_warm] Ep  99/200 │ Time:   0.24s │ Total: 1.7917e-02 │ Full L2: 5.1759e-02 │ Sup@bd+pfull: 4.4050e-03 │ Res: 6.4920e-03
# [Phase 2:P2_res_warm] Ep 100/200 │ Time:   0.24s │ Total: 1.6799e-02 │ Full L2: 5.1448e-02 │ Sup@bd+pfull: 3.7136e-03 │ Res: 6.3585e-03
# [Phase 2:P2_res_warm] Ep 101/200 │ Time:   0.24s │ Total: 1.6847e-02 │ Full L2: 5.1432e-02 │ Sup@bd+pfull: 4.0118e-03 │ Res: 6.3914e-03
# [Phase 2:P2_res_warm] Ep 102/200 │ Time:   0.25s │ Total: 1.5700e-02 │ Full L2: 5.1417e-02 │ Sup@bd+pfull: 3.3766e-03 │ Res: 6.2557e-03
# [Phase 2:P2_res_warm] Ep 103/200 │ Time:   0.26s │ Total: 1.7090e-02 │ Full L2: 5.1777e-02 │ Sup@bd+pfull: 4.3086e-03 │ Res: 6.3874e-03
# [Phase 2:P2_res_warm] Ep 104/200 │ Time:   0.25s │ Total: 1.7660e-02 │ Full L2: 5.1910e-02 │ Sup@bd+pfull: 5.0328e-03 │ Res: 6.5073e-03
# [Phase 2:P2_res_warm] Ep 105/200 │ Time:   0.25s │ Total: 1.5847e-02 │ Full L2: 5.1731e-02 │ Sup@bd+pfull: 3.4789e-03 │ Res: 6.1766e-03
# [Phase 2:P2_res_warm] Ep 106/200 │ Time:   0.24s │ Total: 1.6526e-02 │ Full L2: 5.1683e-02 │ Sup@bd+pfull: 4.1104e-03 │ Res: 6.3974e-03
# [Phase 2:P2_res_warm] Ep 107/200 │ Time:   0.24s │ Total: 1.6437e-02 │ Full L2: 5.1696e-02 │ Sup@bd+pfull: 4.2262e-03 │ Res: 6.3729e-03
# [Phase 2:P2_res_warm] Ep 108/200 │ Time:   0.23s │ Total: 1.5597e-02 │ Full L2: 5.1567e-02 │ Sup@bd+pfull: 3.4122e-03 │ Res: 6.0942e-03
# [Phase 2:P2_res_warm] Ep 109/200 │ Time:   0.23s │ Total: 1.5612e-02 │ Full L2: 5.1403e-02 │ Sup@bd+pfull: 3.7298e-03 │ Res: 6.1477e-03
# [Phase 2:P2_res_warm] Ep 110/200 │ Time:   0.23s │ Total: 1.5656e-02 │ Full L2: 5.1373e-02 │ Sup@bd+pfull: 3.6257e-03 │ Res: 6.1362e-03
# [Phase 2:P2_res_warm] Ep 111/200 │ Time:   0.24s │ Total: 1.4923e-02 │ Full L2: 5.1518e-02 │ Sup@bd+pfull: 3.1821e-03 │ Res: 6.0085e-03
# [Phase 2:P2_res_warm] Ep 112/200 │ Time:   0.24s │ Total: 1.5711e-02 │ Full L2: 5.1647e-02 │ Sup@bd+pfull: 3.6653e-03 │ Res: 6.0279e-03
# [Phase 2:P2_res_warm] Ep 113/200 │ Time:   0.25s │ Total: 1.6282e-02 │ Full L2: 5.1625e-02 │ Sup@bd+pfull: 4.0608e-03 │ Res: 6.0911e-03
# [Phase 2:P2_res_warm] Ep 114/200 │ Time:   0.25s │ Total: 1.4842e-02 │ Full L2: 5.1442e-02 │ Sup@bd+pfull: 3.2685e-03 │ Res: 5.9135e-03
# [Phase 2:P2_res_warm] Ep 115/200 │ Time:   0.25s │ Total: 1.5099e-02 │ Full L2: 5.1393e-02 │ Sup@bd+pfull: 3.4526e-03 │ Res: 5.9485e-03
# [Phase 2:P2_res_warm] Ep 116/200 │ Time:   0.24s │ Total: 1.4957e-02 │ Full L2: 5.1518e-02 │ Sup@bd+pfull: 3.3845e-03 │ Res: 5.9465e-03
# [Phase 2:P2_res_warm] Ep 117/200 │ Time:   0.25s │ Total: 1.4651e-02 │ Full L2: 5.1778e-02 │ Sup@bd+pfull: 3.3075e-03 │ Res: 5.8387e-03
# [Phase 2:P2_res_warm] Ep 118/200 │ Time:   0.23s │ Total: 1.4735e-02 │ Full L2: 5.1745e-02 │ Sup@bd+pfull: 3.2621e-03 │ Res: 5.8353e-03
# [Phase 2:P2_res_warm] Ep 119/200 │ Time:   0.23s │ Total: 1.4633e-02 │ Full L2: 5.1184e-02 │ Sup@bd+pfull: 3.2959e-03 │ Res: 5.8090e-03
# [Phase 2:P2_res_warm] Ep 120/200 │ Time:   0.24s │ Total: 1.4912e-02 │ Full L2: 5.0919e-02 │ Sup@bd+pfull: 3.4025e-03 │ Res: 5.8407e-03
# [Phase 2:P2_res_warm] Ep 121/200 │ Time:   0.25s │ Total: 1.4482e-02 │ Full L2: 5.1246e-02 │ Sup@bd+pfull: 3.1839e-03 │ Res: 5.7421e-03
# [Phase 2:P2_res_warm] Ep 122/200 │ Time:   0.24s │ Total: 1.4256e-02 │ Full L2: 5.1426e-02 │ Sup@bd+pfull: 3.1697e-03 │ Res: 5.7172e-03
# [Phase 2:P2_res_warm] Ep 123/200 │ Time:   0.25s │ Total: 1.3526e-02 │ Full L2: 5.1536e-02 │ Sup@bd+pfull: 2.6068e-03 │ Res: 5.6686e-03
# [Phase 2:P2_res_warm] Ep 124/200 │ Time:   0.24s │ Total: 1.3744e-02 │ Full L2: 5.1538e-02 │ Sup@bd+pfull: 2.7952e-03 │ Res: 5.6742e-03
# [Phase 2:P2_res_warm] Ep 125/200 │ Time:   0.24s │ Total: 1.4044e-02 │ Full L2: 5.1486e-02 │ Sup@bd+pfull: 3.0722e-03 │ Res: 5.6881e-03
# [Phase 2:P2_res_warm] Ep 126/200 │ Time:   0.23s │ Total: 1.3446e-02 │ Full L2: 5.1416e-02 │ Sup@bd+pfull: 2.5874e-03 │ Res: 5.6340e-03
# [Phase 2:P2_res_warm] Ep 127/200 │ Time:   0.24s │ Total: 1.3409e-02 │ Full L2: 5.1403e-02 │ Sup@bd+pfull: 2.6395e-03 │ Res: 5.6172e-03
# [Phase 2:P2_res_warm] Ep 128/200 │ Time:   0.24s │ Total: 1.3452e-02 │ Full L2: 5.1451e-02 │ Sup@bd+pfull: 2.6098e-03 │ Res: 5.6122e-03
# [Phase 2:P2_res_warm] Ep 129/200 │ Time:   0.24s │ Total: 1.3216e-02 │ Full L2: 5.1474e-02 │ Sup@bd+pfull: 2.5007e-03 │ Res: 5.6002e-03
# [Phase 2:P2_res_warm] Ep 130/200 │ Time:   0.23s │ Total: 1.3183e-02 │ Full L2: 5.1408e-02 │ Sup@bd+pfull: 2.4386e-03 │ Res: 5.5712e-03
# [Phase 2:P2_res_warm] Ep 131/200 │ Time:   0.23s │ Total: 1.3195e-02 │ Full L2: 5.1338e-02 │ Sup@bd+pfull: 2.4633e-03 │ Res: 5.5777e-03
# [Phase 2:P2_res_warm] Ep 132/200 │ Time:   0.24s │ Total: 1.2974e-02 │ Full L2: 5.1324e-02 │ Sup@bd+pfull: 2.3772e-03 │ Res: 5.5544e-03
# [Phase 2:P2_res_warm] Ep 133/200 │ Time:   0.23s │ Total: 1.2919e-02 │ Full L2: 5.1378e-02 │ Sup@bd+pfull: 2.3181e-03 │ Res: 5.5290e-03
# [Phase 2:P2_res_warm] Ep 134/200 │ Time:   0.24s │ Total: 1.2840e-02 │ Full L2: 5.1426e-02 │ Sup@bd+pfull: 2.3494e-03 │ Res: 5.5228e-03
# [Phase 2:P2_res_warm] Ep 135/200 │ Time:   0.26s │ Total: 1.2700e-02 │ Full L2: 5.1358e-02 │ Sup@bd+pfull: 2.2239e-03 │ Res: 5.4941e-03
# [Phase 2:P2_res_warm] Ep 136/200 │ Time:   0.23s │ Total: 1.2665e-02 │ Full L2: 5.1281e-02 │ Sup@bd+pfull: 2.2636e-03 │ Res: 5.4870e-03
# [Phase 2:P2_res_warm] Ep 137/200 │ Time:   0.23s │ Total: 1.2508e-02 │ Full L2: 5.1343e-02 │ Sup@bd+pfull: 2.1820e-03 │ Res: 5.4603e-03
# [Phase 2:P2_res_warm] Ep 138/200 │ Time:   0.23s │ Total: 1.2508e-02 │ Full L2: 5.1376e-02 │ Sup@bd+pfull: 2.1943e-03 │ Res: 5.4423e-03
# [Phase 2:P2_res_warm] Ep 139/200 │ Time:   0.25s │ Total: 1.2377e-02 │ Full L2: 5.1412e-02 │ Sup@bd+pfull: 2.1612e-03 │ Res: 5.4231e-03
# [Phase 2:P2_res_warm] Ep 140/200 │ Time:   0.23s │ Total: 1.2356e-02 │ Full L2: 5.1376e-02 │ Sup@bd+pfull: 2.1289e-03 │ Res: 5.3984e-03
# [Phase 2:P2_res_warm] Ep 141/200 │ Time:   0.23s │ Total: 1.2402e-02 │ Full L2: 5.1294e-02 │ Sup@bd+pfull: 2.1970e-03 │ Res: 5.3868e-03
# [Phase 2:P2_res_warm] Ep 142/200 │ Time:   0.23s │ Total: 1.2121e-02 │ Full L2: 5.1284e-02 │ Sup@bd+pfull: 2.0795e-03 │ Res: 5.3665e-03
# [Phase 2:P2_res_warm] Ep 143/200 │ Time:   0.23s │ Total: 1.2058e-02 │ Full L2: 5.1335e-02 │ Sup@bd+pfull: 2.0289e-03 │ Res: 5.3533e-03
# [Phase 2:P2_res_warm] Ep 144/200 │ Time:   0.24s │ Total: 1.2217e-02 │ Full L2: 5.1376e-02 │ Sup@bd+pfull: 2.1374e-03 │ Res: 5.3509e-03
# [Phase 2:P2_res_warm] Ep 145/200 │ Time:   0.24s │ Total: 1.2041e-02 │ Full L2: 5.1369e-02 │ Sup@bd+pfull: 2.0650e-03 │ Res: 5.3307e-03
# [Phase 2:P2_res_warm] Ep 146/200 │ Time:   0.24s │ Total: 1.1870e-02 │ Full L2: 5.1320e-02 │ Sup@bd+pfull: 1.9712e-03 │ Res: 5.3132e-03
# [Phase 2:P2_res_warm] Ep 147/200 │ Time:   0.24s │ Total: 1.1927e-02 │ Full L2: 5.1268e-02 │ Sup@bd+pfull: 2.0173e-03 │ Res: 5.3011e-03
# [Phase 2:P2_res_warm] Ep 148/200 │ Time:   0.26s │ Total: 1.1817e-02 │ Full L2: 5.1251e-02 │ Sup@bd+pfull: 1.9806e-03 │ Res: 5.2840e-03
# [Phase 2:P2_res_warm] Ep 149/200 │ Time:   0.24s │ Total: 1.1752e-02 │ Full L2: 5.1332e-02 │ Sup@bd+pfull: 1.9483e-03 │ Res: 5.2663e-03
# [Phase 2:P2_res_warm] Ep 150/200 │ Time:   0.24s │ Total: 1.1790e-02 │ Full L2: 5.1401e-02 │ Sup@bd+pfull: 1.9817e-03 │ Res: 5.2519e-03
# [Phase 2:P2_res_warm] Ep 151/200 │ Time:   0.24s │ Total: 1.1585e-02 │ Full L2: 5.1342e-02 │ Sup@bd+pfull: 1.8916e-03 │ Res: 5.2299e-03
# [Phase 2:P2_res_warm] Ep 152/200 │ Time:   0.25s │ Total: 1.1614e-02 │ Full L2: 5.1231e-02 │ Sup@bd+pfull: 1.9308e-03 │ Res: 5.2170e-03
# [Phase 2:P2_res_warm] Ep 153/200 │ Time:   0.24s │ Total: 1.1533e-02 │ Full L2: 5.1252e-02 │ Sup@bd+pfull: 1.8766e-03 │ Res: 5.1940e-03
# [Phase 2:P2_res_warm] Ep 154/200 │ Time:   0.23s │ Total: 1.1414e-02 │ Full L2: 5.1333e-02 │ Sup@bd+pfull: 1.8579e-03 │ Res: 5.1729e-03
# [Phase 2:P2_res_warm] Ep 155/200 │ Time:   0.24s │ Total: 1.1411e-02 │ Full L2: 5.1297e-02 │ Sup@bd+pfull: 1.8517e-03 │ Res: 5.1565e-03
# [Phase 2:P2_res_warm] Ep 156/200 │ Time:   0.23s │ Total: 1.1273e-02 │ Full L2: 5.1267e-02 │ Sup@bd+pfull: 1.7790e-03 │ Res: 5.1371e-03
# [Phase 2:P2_res_warm] Ep 157/200 │ Time:   0.24s │ Total: 1.1273e-02 │ Full L2: 5.1274e-02 │ Sup@bd+pfull: 1.8217e-03 │ Res: 5.1208e-03
# [Phase 2:P2_res_warm] Ep 158/200 │ Time:   0.23s │ Total: 1.1240e-02 │ Full L2: 5.1249e-02 │ Sup@bd+pfull: 1.7818e-03 │ Res: 5.1011e-03
# [Phase 2:P2_res_warm] Ep 159/200 │ Time:   0.24s │ Total: 1.1067e-02 │ Full L2: 5.1265e-02 │ Sup@bd+pfull: 1.7289e-03 │ Res: 5.0777e-03
# [Phase 2:P2_res_warm] Ep 160/200 │ Time:   0.24s │ Total: 1.1142e-02 │ Full L2: 5.1319e-02 │ Sup@bd+pfull: 1.8020e-03 │ Res: 5.0644e-03
# [Phase 2:P2_res_warm] Ep 161/200 │ Time:   0.23s │ Total: 1.1134e-02 │ Full L2: 5.1292e-02 │ Sup@bd+pfull: 1.7736e-03 │ Res: 5.0468e-03
# [Phase 2:P2_res_warm] Ep 162/200 │ Time:   0.25s │ Total: 1.0964e-02 │ Full L2: 5.1257e-02 │ Sup@bd+pfull: 1.6833e-03 │ Res: 5.0340e-03
# [Phase 2:P2_res_warm] Ep 163/200 │ Time:   0.24s │ Total: 1.0890e-02 │ Full L2: 5.1230e-02 │ Sup@bd+pfull: 1.6849e-03 │ Res: 5.0257e-03
# [Phase 2:P2_res_warm] Ep 164/200 │ Time:   0.24s │ Total: 1.0953e-02 │ Full L2: 5.1240e-02 │ Sup@bd+pfull: 1.6987e-03 │ Res: 5.0181e-03
# [Phase 2:P2_res_warm] Ep 165/200 │ Time:   0.24s │ Total: 1.0962e-02 │ Full L2: 5.1260e-02 │ Sup@bd+pfull: 1.6955e-03 │ Res: 5.0095e-03
# [Phase 2:P2_res_warm] Ep 166/200 │ Time:   0.24s │ Total: 1.0846e-02 │ Full L2: 5.1268e-02 │ Sup@bd+pfull: 1.6600e-03 │ Res: 4.9995e-03
# [Phase 2:P2_res_warm] Ep 167/200 │ Time:   0.24s │ Total: 1.0762e-02 │ Full L2: 5.1262e-02 │ Sup@bd+pfull: 1.6275e-03 │ Res: 4.9910e-03
# [Phase 2:P2_res_warm] Ep 168/200 │ Time:   0.24s │ Total: 1.0776e-02 │ Full L2: 5.1264e-02 │ Sup@bd+pfull: 1.6336e-03 │ Res: 4.9818e-03
# [Phase 2:P2_res_warm] Ep 169/200 │ Time:   0.24s │ Total: 1.0743e-02 │ Full L2: 5.1254e-02 │ Sup@bd+pfull: 1.6197e-03 │ Res: 4.9715e-03
# [Phase 2:P2_res_warm] Ep 170/200 │ Time:   0.23s │ Total: 1.0667e-02 │ Full L2: 5.1221e-02 │ Sup@bd+pfull: 1.6043e-03 │ Res: 4.9625e-03
# [Phase 2:P2_res_warm] Ep 171/200 │ Time:   0.24s │ Total: 1.0662e-02 │ Full L2: 5.1221e-02 │ Sup@bd+pfull: 1.6053e-03 │ Res: 4.9516e-03
# [Phase 2:P2_res_warm] Ep 172/200 │ Time:   0.23s │ Total: 1.0649e-02 │ Full L2: 5.1253e-02 │ Sup@bd+pfull: 1.6012e-03 │ Res: 4.9399e-03
# [Phase 2:P2_res_warm] Ep 173/200 │ Time:   0.25s │ Total: 1.0578e-02 │ Full L2: 5.1280e-02 │ Sup@bd+pfull: 1.5837e-03 │ Res: 4.9297e-03
# [Phase 2:P2_res_warm] Ep 174/200 │ Time:   0.23s │ Total: 1.0540e-02 │ Full L2: 5.1268e-02 │ Sup@bd+pfull: 1.5669e-03 │ Res: 4.9187e-03
# [Phase 2:P2_res_warm] Ep 175/200 │ Time:   0.24s │ Total: 1.0527e-02 │ Full L2: 5.1224e-02 │ Sup@bd+pfull: 1.5647e-03 │ Res: 4.9082e-03
# [Phase 2:P2_res_warm] Ep 176/200 │ Time:   0.24s │ Total: 1.0493e-02 │ Full L2: 5.1199e-02 │ Sup@bd+pfull: 1.5569e-03 │ Res: 4.8981e-03
# [Phase 2:P2_res_warm] Ep 177/200 │ Time:   0.24s │ Total: 1.0430e-02 │ Full L2: 5.1211e-02 │ Sup@bd+pfull: 1.5381e-03 │ Res: 4.8866e-03
# [Phase 2:P2_res_warm] Ep 178/200 │ Time:   0.23s │ Total: 1.0393e-02 │ Full L2: 5.1235e-02 │ Sup@bd+pfull: 1.5149e-03 │ Res: 4.8744e-03
# [Phase 2:P2_res_warm] Ep 179/200 │ Time:   0.24s │ Total: 1.0380e-02 │ Full L2: 5.1247e-02 │ Sup@bd+pfull: 1.5324e-03 │ Res: 4.8623e-03
# [Phase 2:P2_res_warm] Ep 180/200 │ Time:   0.24s │ Total: 1.0318e-02 │ Full L2: 5.1241e-02 │ Sup@bd+pfull: 1.4967e-03 │ Res: 4.8515e-03
# [Phase 2:P2_res_warm] Ep 181/200 │ Time:   0.23s │ Total: 1.0340e-02 │ Full L2: 5.1206e-02 │ Sup@bd+pfull: 1.5353e-03 │ Res: 4.8430e-03
# [Phase 2:P2_res_warm] Ep 182/200 │ Time:   0.23s │ Total: 1.0334e-02 │ Full L2: 5.1195e-02 │ Sup@bd+pfull: 1.5356e-03 │ Res: 4.8377e-03
# [Phase 2:P2_res_warm] Ep 183/200 │ Time:   0.25s │ Total: 1.0263e-02 │ Full L2: 5.1195e-02 │ Sup@bd+pfull: 1.4879e-03 │ Res: 4.8306e-03
# [Phase 2:P2_res_warm] Ep 184/200 │ Time:   0.23s │ Total: 1.0246e-02 │ Full L2: 5.1211e-02 │ Sup@bd+pfull: 1.4874e-03 │ Res: 4.8243e-03
# [Phase 2:P2_res_warm] Ep 185/200 │ Time:   0.25s │ Total: 1.0277e-02 │ Full L2: 5.1224e-02 │ Sup@bd+pfull: 1.5173e-03 │ Res: 4.8194e-03
# [Phase 2:P2_res_warm] Ep 186/200 │ Time:   0.23s │ Total: 1.0244e-02 │ Full L2: 5.1232e-02 │ Sup@bd+pfull: 1.4937e-03 │ Res: 4.8138e-03
# [Phase 2:P2_res_warm] Ep 187/200 │ Time:   0.24s │ Total: 1.0192e-02 │ Full L2: 5.1233e-02 │ Sup@bd+pfull: 1.4629e-03 │ Res: 4.8087e-03
# [Phase 2:P2_res_warm] Ep 188/200 │ Time:   0.23s │ Total: 1.0190e-02 │ Full L2: 5.1216e-02 │ Sup@bd+pfull: 1.4707e-03 │ Res: 4.8044e-03
# [Phase 2:P2_res_warm] Ep 189/200 │ Time:   0.23s │ Total: 1.0184e-02 │ Full L2: 5.1203e-02 │ Sup@bd+pfull: 1.4653e-03 │ Res: 4.7993e-03
# [Phase 2:P2_res_warm] Ep 190/200 │ Time:   0.24s │ Total: 1.0148e-02 │ Full L2: 5.1195e-02 │ Sup@bd+pfull: 1.4464e-03 │ Res: 4.7939e-03
# [Phase 2:P2_res_warm] Ep 191/200 │ Time:   0.24s │ Total: 1.0136e-02 │ Full L2: 5.1199e-02 │ Sup@bd+pfull: 1.4533e-03 │ Res: 4.7891e-03
# [Phase 2:P2_res_warm] Ep 192/200 │ Time:   0.23s │ Total: 1.0133e-02 │ Full L2: 5.1207e-02 │ Sup@bd+pfull: 1.4479e-03 │ Res: 4.7838e-03
# [Phase 2:P2_res_warm] Ep 193/200 │ Time:   0.24s │ Total: 1.0098e-02 │ Full L2: 5.1214e-02 │ Sup@bd+pfull: 1.4278e-03 │ Res: 4.7784e-03
# [Phase 2:P2_res_warm] Ep 194/200 │ Time:   0.24s │ Total: 1.0079e-02 │ Full L2: 5.1210e-02 │ Sup@bd+pfull: 1.4333e-03 │ Res: 4.7740e-03
# [Phase 2:P2_res_warm] Ep 195/200 │ Time:   0.24s │ Total: 1.0076e-02 │ Full L2: 5.1207e-02 │ Sup@bd+pfull: 1.4281e-03 │ Res: 4.7684e-03
# [Phase 2:P2_res_warm] Ep 196/200 │ Time:   0.24s │ Total: 1.0045e-02 │ Full L2: 5.1202e-02 │ Sup@bd+pfull: 1.4134e-03 │ Res: 4.7623e-03
# [Phase 2:P2_res_warm] Ep 197/200 │ Time:   0.24s │ Total: 1.0026e-02 │ Full L2: 5.1202e-02 │ Sup@bd+pfull: 1.4160e-03 │ Res: 4.7571e-03
# [Phase 2:P2_res_warm] Ep 198/200 │ Time:   0.24s │ Total: 1.0017e-02 │ Full L2: 5.1207e-02 │ Sup@bd+pfull: 1.4076e-03 │ Res: 4.7517e-03
# [Phase 2:P2_res_warm] Ep 199/200 │ Time:   0.24s │ Total: 9.9891e-03 │ Full L2: 5.1208e-02 │ Sup@bd+pfull: 1.4021e-03 │ Res: 4.7471e-03
# [Phase 2:P2_res_warm] Ep 200/200 │ Time:   0.24s │ Total: 9.9714e-03 │ Full L2: 5.1206e-02 │ Sup@bd+pfull: 1.3964e-03 │ Res: 4.7411e-03
# → Saved loss history for phase 'P2_res_warm' in loss/Spline_Multi_Stage_Adam_ep100_m24_w64_T10/loss_P2_res_warm.csv
# Training finished.

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# -----------------------------------------
# genera predizioni autoregressive dal modello
# -----------------------------------------
def predict_sequence(model, xx, yy, T, step=1, C=3):
    model.eval()
    preds = []
    with torch.no_grad():
        for t in range(0, T, step):
            y = yy[..., 3*t:3*(t+1)] 
           # ---- predizione ----
            if predict_delta:
                # base = ultimo stato nella finestra (u_t, v_t, p_t)
                base = xx[..., -C:]                                # (B,Sx,Sy,3)
                delta = model(xx)                                  # (B,Sx,Sy,3)
                im = base + delta                                  # pred stato t+1
            else:
                im = model(xx)                                     # pred stato t+1 diretto
            
            ψ, v, grad_v, lap_v, p, grad_p = interpolate_states(im, offset=torch.tensor([0.0, 0.0], device=device),
                orders_v=orders_v)
            
            pred = torch.cat([v,p], dim=-1)
            preds.append(pred)
            
            # aggiorna input con autoregressione
            xy   = xx[..., :2]
            hist = xx[..., 2:]
            hist = torch.cat([hist[..., C:], y], dim=-1)
            xx   = torch.cat([xy, hist], dim=-1)
    pred_seq = torch.cat(preds, dim=-1)  # (B, Sx, Sy, 3*T)
    return pred_seq


# -----------------------------------------
# funzione per animare u,v,p
# -----------------------------------------
def animate_prediction(xx, yy, model, T, step=1, interval=200,
                       save_prefix="anim",  # solo basename del file (niente path)
                       cmap_field="jet", cmap_err="magma",
                       add_colorbars=True, times=None,
                       out_dir=".", save_last_png=True, filename_base=None):
    """
    out_dir: cartella dove salvare i file (es. path_image)
    save_last_png: se True salva anche l'ultimo frame come PNG
    filename_base: basename per i file; se None usa save_prefix
    """
    import os
    if filename_base is None:
        filename_base = save_prefix
    os.makedirs(out_dir, exist_ok=True)

    C = 3
    pred_seq = predict_sequence(model, xx.clone(), yy.clone(), T, step, C)  # (B,Sx,Sy,3*Tpred)
    B, Sx, Sy, _ = pred_seq.shape
    Tpred = pred_seq.shape[-1] // C

    # estrai pred e gt (B,Sx,Sy,T)
    u_pred = pred_seq[..., 0::C]; v_pred = pred_seq[..., 1::C]; p_pred = pred_seq[..., 2::C]
    u_true = yy      [..., 0::C]; v_true = yy      [..., 1::C]; p_true = yy      [..., 2::C]

    # to numpy (Sx,Sy,T)
    u_pred = u_pred.squeeze(0).detach().cpu().numpy()
    v_pred = v_pred.squeeze(0).detach().cpu().numpy()
    p_pred = p_pred.squeeze(0).detach().cpu().numpy()
    u_true = u_true.squeeze(0).detach().cpu().numpy()
    v_true = v_true.squeeze(0).detach().cpu().numpy()
    p_true = p_true.squeeze(0).detach().cpu().numpy()

    # errori (Sx,Sy,T)
    eu = np.abs(u_pred - u_true)
    ev = np.abs(v_pred - v_true)
    ep = np.abs(p_pred - p_true)

    # range colori stabile (dai GT)
    vmin_u, vmax_u = float(u_true.min()), float(u_true.max())
    vmin_v, vmax_v = float(v_true.min()), float(v_true.max())
    vmin_p, vmax_p = float(p_true.min()), float(p_true.max())

    # range errore robusto (99° percentile)
    emax_u = max(1e-12, float(np.percentile(eu, 99)))
    emax_v = max(1e-12, float(np.percentile(ev, 99)))
    emax_p = max(1e-12, float(np.percentile(ep, 99)))

    # figura animazione 3x3
    fig, axes = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
    titles_top = ['u pred', 'v pred', 'p pred']
    titles_mid = ['u GT',   'v GT',   'p GT'  ]
    titles_bot = ['|u err|','|v err|','|p err|']

    for i in range(3):
        axes[0,i].set_title(titles_top[i])
        axes[1,i].set_title(titles_mid[i])
        axes[2,i].set_title(titles_bot[i])
        for r in range(3):
            axes[r,i].set_xticks([]); axes[r,i].set_yticks([])

    k0 = 0
    im00 = axes[0,0].imshow(u_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im01 = axes[0,1].imshow(v_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im02 = axes[0,2].imshow(p_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im10 = axes[1,0].imshow(u_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im11 = axes[1,1].imshow(v_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im12 = axes[1,2].imshow(p_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im20 = axes[2,0].imshow(eu[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_u, animated=True)
    im21 = axes[2,1].imshow(ev[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_v, animated=True)
    im22 = axes[2,2].imshow(ep[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_p, animated=True)

    ims = [im00, im01, im02, im10, im11, im12, im20, im21, im22]
    cbs = []
    if add_colorbars:
        for ax, im in zip(axes[0], ims[0:3]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[1], ims[3:6]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[2], ims[6:9]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))

    # testo tempo/frame
    if times is not None and len(times) >= Tpred:
        time_text = fig.text(0.01, 0.98, f"t = {float(times[0]):.3f}", fontsize=12)
    else:
        time_text = fig.text(0.01, 0.98, f"frame 0 / {Tpred-1}", fontsize=12)

    def update(frame):
        im00.set_array(u_pred[...,frame].T); im01.set_array(v_pred[...,frame].T); im02.set_array(p_pred[...,frame].T)
        im10.set_array(u_true[...,frame].T); im11.set_array(v_true[...,frame].T); im12.set_array(p_true[...,frame].T)
        im20.set_array(eu[...,frame].T);     im21.set_array(ev[...,frame].T);     im22.set_array(ep[...,frame].T)
        if times is not None and len(times) >= Tpred:
            time_text.set_text(f"t = {float(times[frame]):.3f}")
        else:
            time_text.set_text(f"frame {frame} / {Tpred-1}")
        return ims + [time_text]

    ani = animation.FuncAnimation(fig, update, frames=Tpred, interval=interval, blit=False)

    # ---- salva GIF ----
    gif_path = os.path.join(out_dir, f"{filename_base}.gif")
    ani.save(gif_path, writer='pillow', fps=max(1, int(1000/interval)))

    # ---- salva PNG dell'ultimo frame (stessa griglia 3x3) ----
    png_path = None
    if save_last_png:
        frame = Tpred-1
        fig_last, axes_last = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
        titles_top = ['u pred', 'v pred', 'p pred']
        titles_mid = ['u GT',   'v GT',   'p GT'  ]
        titles_bot = ['|u err|','|v err|','|p err|']
        for i in range(3):
            axes_last[0,i].set_title(titles_top[i])
            axes_last[1,i].set_title(titles_mid[i])
            axes_last[2,i].set_title(titles_bot[i])
            for r in range(3):
                axes_last[r,i].set_xticks([]); axes_last[r,i].set_yticks([])

        axes_last[0,0].imshow(u_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[0,1].imshow(v_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[0,2].imshow(p_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[1,0].imshow(u_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[1,1].imshow(v_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[1,2].imshow(p_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[2,0].imshow(eu[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_u)
        axes_last[2,1].imshow(ev[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_v)
        axes_last[2,2].imshow(ep[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_p)

        if add_colorbars:
            for ax in axes_last[0]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[1]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[2]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)

        png_path = os.path.join(out_dir, f"{filename_base}_last.png")
        fig_last.savefig(png_path, dpi=160, bbox_inches="tight")
        plt.close(fig_last)

    plt.close(fig)
    return ani, gif_path, png_path



# batch di esempio
xx, yy = next(iter(train_loader))
xx = xx.to(device, dtype=torch.float32)
yy = yy.to(device, dtype=torch.float32)

# salva GIF + ultimo frame PNG nella cartella immagini dell'esperimento
ani, gif_path, png_path = animate_prediction(
    xx, yy, model,
    T=T, step=1, interval=200,
    save_prefix="supervised_fno",
    out_dir=path_image,          # <--- usa la cartella 'image/<path>'
    save_last_png=True,
)

print("GIF salvata in:", gif_path)
print("PNG ultimo frame in:", png_path)
# Out:
# GIF salvata in: image/Spline_Multi_Stage_Adam_ep100_m24_w64_T10/supervised_fno.gif
# PNG ultimo frame in: image/Spline_Multi_Stage_Adam_ep100_m24_w64_T10/supervised_fno_last.png
