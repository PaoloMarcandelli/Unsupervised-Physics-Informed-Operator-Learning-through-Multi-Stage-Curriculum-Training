# %%
import numpy as np
import scipy.io
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sub = 1
offset = 0
T_in = 1
T = 10

# --- carica ---  #
data   = scipy.io.loadmat('cylinder_wake.mat')
X_star = data['X_star']           # (N,2)
U_star = data['U_star']           # (N,2,T)
P_star = data['p_star']           # (N,T)
t_star = data['t'].squeeze()      # (T,)

# --- griglia regolare (completa) ---
dec =12
x_unique = np.unique(np.round(X_star[:,0], dec))   # 100 valori
y_unique = np.unique(np.round(X_star[:,1], dec))   # 50 valori
Sx_full, Sy_full = len(x_unique), len(y_unique)
time = t_star.shape[0]

# mapping (x,y) -> (i,j) sulla griglia COMPLETA
x_to_i = {x:i for i,x in enumerate(x_unique)}
y_to_j = {y:j for j,y in enumerate(y_unique)}
ij = np.empty((X_star.shape[0],2), dtype=int)
for k,(x,y) in enumerate(np.round(X_star, dec)):
    ij[k] = (x_to_i[x], y_to_j[y])

# --- riempi griglie complete ---
U_grid = np.empty((Sx_full, Sy_full, time, 2), dtype=U_star.dtype)  # ...,(u,v)
P_grid = np.empty((Sx_full, Sy_full, time),     dtype=P_star.dtype)

for k in range(X_star.shape[0]):
    i,j = ij[k]
    U_grid[i,j,:,0] = U_star[k,0,:]   # u
    U_grid[i,j,:,1] = U_star[k,1,:]   # v
    P_grid[i,j,:]   = P_star[k,:]

# ====== QUI scegli metà dominio in x (50 colonne) ======
half = Sx_full // 2

# Metà SINISTRA:    ix = slice(0, half)
# Metà DESTRA:      ix = slice(half, Sx_full)
# Metà CENTRATA:    c = Sx_full//2; w = half; ix = slice(c - w//2, c + w//2)
ix = slice(0, half)

# Integra anche l'eventuale subsampling
iy = slice(0, Sy_full)               # tieni tutte le 50 in y
ix = slice(ix.start, ix.stop, sub)   # es. sub=1 → tutte; sub=2 → una ogni 2
iy = slice(iy.start, iy.stop, sub)

# --- in torch, con B=1: u,v,p hanno shape (1, Sx', Sy', T) ---
u = torch.from_numpy(U_grid[ix, iy, :, 0]).unsqueeze(0).contiguous()   # (1, 50, 50, T) se sub=1
v = torch.from_numpy(U_grid[ix, iy, :, 1]).unsqueeze(0).contiguous()
p = torch.from_numpy(P_grid[ix, iy, :]).unsqueeze(0).contiguous()

# --- coord grid coerenti (usando meshgrid) ---
x_half = x_unique[ix]
y_half = y_unique[iy]
Xv, Yv = np.meshgrid(x_half, y_half, indexing='ij')  # (Sx',Sy')
X = torch.from_numpy(Xv)[None, ..., None]  # (1,Sx',Sy',1)
Y = torch.from_numpy(Yv)[None, ..., None]  # (1,Sx',Sy',1)

# --- split in/stimolo e target ---
u_in = u[..., offset:offset+T_in]                         # (1,Sx',Sy',T_in)
v_in = v[..., offset:offset+T_in]
p_in = p[..., offset:offset+T_in]

u_t = u[..., offset+T_in:offset+T_in+T]                   # (1,Sx',Sy',T)
v_t = v[..., offset+T_in:offset+T_in+T]
p_t = p[..., offset+T_in:offset+T_in+T]

# pack finale (B=1): concateni (x,y) ai canali temporali
train_in = torch.cat([X.to(device), Y.to(device), 
                      u_in.to(device), v_in.to(device), p_in.to(device)], dim=-1)  # (1,Sx',Sy', 2+3*T_in)

target = torch.stack([u_t, v_t, p_t], dim=-1)  # (1,Sx',Sy', T, 3)
train_t = target.reshape(target.shape[0], target.shape[1], target.shape[2], -1).contiguous().to(device)

print("Shapes ->", "train_in:", tuple(train_in.shape), "train_t:", tuple(train_t.shape),
      "| sub =", sub, "| half-x =", (ix.start, ix.stop, ix.step))

train_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(train_in, train_t),
    batch_size=1, shuffle=False
)
# Out:
# Shapes -> train_in: (1, 50, 50, 5) train_t: (1, 50, 50, 30) | sub = 1 | half-x = (0, 50, 1)

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
from utilities3 import *

import operator
from functools import reduce
from functools import partial
import os

from timeit import default_timer
import scipy.io
import pandas as pd
from get_params import get_params

import math


torch.manual_seed(0)
np.random.seed(0)

################################################################
# fourier layer
################################################################

def compl_mul2d_rfft(a, b):
    # a: (batch, in_ch, m1, m2, 2)
    # b: (in_ch, out_ch, m1, m2, 2)
    op = partial(torch.einsum, "bctq,dctq->bdtq")
    real = op(a[...,0], b[...,0]) - op(a[...,1], b[...,1])
    imag = op(a[...,1], b[...,0]) + op(a[...,0], b[...,1])
    return torch.stack([real, imag], dim=-1)


class SpectralConv2d_fast(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1
        self.modes2 = modes2
        self.scale = (1/(in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, modes1, modes2, 2))

    def forward(self, x):
        batchsize, _, nx, ny = *x.shape, 
        # Compute Fourier coefficients (real input -> rfft2)
        x_ft_complex = torch.fft.rfft2(x, norm='ortho')
        # Convert to real-imag tensor
        x_ft = torch.stack([x_ft_complex.real, x_ft_complex.imag], dim=-1)
        # Allocate output in Fourier space
        out_ft = torch.zeros(batchsize, self.out_channels, nx, ny//2+1, 2, device=x.device)
        # Multiply modes
        out_ft[:, :, :self.modes1, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            compl_mul2d_rfft(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)
        # Convert back to complex
        out_ft_complex = torch.complex(out_ft[...,0], out_ft[...,1])
        # Return to physical space
        x = torch.fft.irfft2(out_ft_complex, s=(nx, ny), norm='ortho')
        return x

class SimpleBlock2d(nn.Module):
    def __init__(self, modes1, modes2, width):
        super(SimpleBlock2d, self).__init__()

        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.fc0 = nn.Linear(5, self.width)

        self.conv0 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)
        self.bn0 = torch.nn.BatchNorm2d(self.width)
        self.bn1 = torch.nn.BatchNorm2d(self.width)
        self.bn2 = torch.nn.BatchNorm2d(self.width)
        self.bn3 = torch.nn.BatchNorm2d(self.width)


        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 3)

    def forward(self, x):
        batchsize = x.shape[0]
        size_x, size_y = x.shape[1], x.shape[2]

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)

        x1 = self.conv0(x)
        x2 = self.w0(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn0(x1 + x2)
        x = F.relu(x)
        x1 = self.conv1(x)
        x2 = self.w1(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn1(x1 + x2)
        x = F.relu(x)
        x1 = self.conv2(x)
        x2 = self.w2(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn2(x1 + x2)
        x = F.relu(x)
        x1 = self.conv3(x)
        x2 = self.w3(x.view(batchsize, self.width, -1)).view(batchsize, self.width, size_x, size_y)
        x = self.bn3(x1 + x2)


        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

class Net2d(nn.Module):
    def __init__(self, modes, width):
        super(Net2d, self).__init__()

        self.conv1 = SimpleBlock2d(modes, modes, width)


    def forward(self, x):
        x = self.conv1(x)
        return x


    def count_params(self):
        c = 0
        for p in self.parameters():
            c += reduce(operator.mul, list(p.size()))

        return c

import torch
import math

# ------------------------------------------------------------
# 1) Fourier continuation (even-reflection) 2D
#    Estende con riflessione pari (C^0 e con pendenze ~0 agli estremi).
#    È robusta per derivazione spettrale su domini non periodici.
# ------------------------------------------------------------
def fc_pad2d_even(x, m: int, dimx: int=-2, dimy: int=-1):
    """
    x: (..., Sx, Sy)
    m: spessore continuation per lato
    return: x_ext (..., Sx+2m, Sy+2m)
    """
    assert m > 0
    # pad lungo x (righe)
    x_left  = torch.flip(x[..., 1:m+1, :], dims=(dimx,))   # riflessione interna (evita duplicare bordo)
    x_right = torch.flip(x[..., -m-1:-1, :], dims=(dimx,))
    x_px = torch.cat([x_left, x, x_right], dim=dimx)
    # pad lungo y (colonne)
    y_top    = torch.flip(x_px[..., :, 1:m+1], dims=(dimy,))
    y_bottom = torch.flip(x_px[..., :, -m-1:-1], dims=(dimy,))
    x_ext = torch.cat([y_top, x_px, y_bottom], dim=dimy)
    return x_ext

def center_crop2d(x_ext, m: int, dimx: int=-2, dimy: int=-1):
    """
    x_ext: (..., Sx+2m, Sy+2m)
    return: (..., Sx, Sy)
    """
    slx = [slice(None)] * x_ext.ndim
    sly = [slice(None)] * x_ext.ndim
    Sx_ext = x_ext.shape[dimx]
    Sy_ext = x_ext.shape[dimy]
    Sx = Sx_ext - 2*m
    Sy = Sy_ext - 2*m
    slx[dimx] = slice(m, m+Sx)
    sly[dimy] = slice(m, m+Sy)
    return x_ext[tuple(slx)][tuple(sly)]

# ------------------------------------------------------------
# 2) Wavenumbers e operatori spettrali su griglia estesa
# ------------------------------------------------------------
def _build_kxy(Sx, Sy, device):
    """
    Ritorna kx, ky (float) di shape (Sx, Sy) per FFT periodica su griglia Sx,Sy.
    """
    kx = torch.fft.fftfreq(Sx, d=1.0, device=device)  # [0,1/Sx,...,-1/Sx]
    ky = torch.fft.fftfreq(Sy, d=1.0, device=device)
    kx = kx.view(Sx, 1).expand(Sx, Sy)
    ky = ky.view(1, Sy).expand(Sx, Sy)
    # fattori 2π
    kx = (2.0*math.pi) * kx
    ky = (2.0*math.pi) * ky
    return kx, ky

def _dealias_23(mask_shape, device):
    """
    Maschera 2/3 classica per antialiasing (sfera rettangolare).
    """
    Sx, Sy = mask_shape
    cx = Sx//2
    cy = Sy//2
    kx = torch.fft.fftfreq(Sx, d=1.0, device=device).abs()
    ky = torch.fft.fftfreq(Sy, d=1.0, device=device).abs()
    # cutoff = 1/3 in frequenza normale (⇒ 2/3 dei modes tenuti)
    cutoff_x = (1.0/3.0)
    cutoff_y = (1.0/3.0)
    mx = (kx <= cutoff_x).view(Sx, 1).expand(Sx, Sy)
    my = (ky <= cutoff_y).view(1, Sy).expand(Sx, Sy)
    return (mx & my)

def _spectral_derivatives_on_extended(f_ext, dealias=True):
    """
    f_ext: (B, SxE, SyE) campo scalare su griglia ESTESA (già periodica per costruzione)
    Ritorna: fx_ext, fy_ext, lap_ext (stesse shape)
    """
    B, SxE, SyE = f_ext.shape
    device = f_ext.device

    kx, ky = _build_kxy(SxE, SyE, device)               # (SxE, SyE)
    k2 = kx**2 + ky**2
    k2[0,0] = 1.0  # evita div/0 quando serve

    F = torch.fft.fftn(f_ext, dim=(-2, -1))             # (B, SxE, SyE)
    if dealias:
        mask = _dealias_23((SxE, SyE), device)          # bool
        F = F * mask                                   # broadcasting su B

    Fx = (1j * kx) * F
    Fy = (1j * ky) * F
    Flap = -(k2) * F

    fx_ext  = torch.fft.ifftn(Fx,   dim=(-2, -1)).real
    fy_ext  = torch.fft.ifftn(Fy,   dim=(-2, -1)).real
    lap_ext = torch.fft.ifftn(Flap, dim=(-2, -1)).real
    return fx_ext, fy_ext, lap_ext

# ------------------------------------------------------------
# 3) Operatori differenziali per (u,v,p) con FC automatica
# ------------------------------------------------------------
def spectral_ops_vp_fc(u, v, p, m: int=12, dealias: bool=True):
    """
    Calcola operatori differenziali per Navier-Stokes in forma (u,v,p)
    usando Fourier continuation (even-reflection) e derivate spettrali.

    Input:
      u,v,p: (B, Sx, Sy)  tensors
      m: spessore banda FC (celle per lato)
      dealias: applica o meno maschera 2/3 in Fourier

    Output: dict con
      ux, uy, vx, vy,         # derivate prime
      lap_u, lap_v,           # Laplaciani
      div_u,                  # divergenza
      px, py,                 # gradiente pressione
      convx, convy,           # (u·∇)u componenti
      interior_mask           # (1,Sx,Sy) True nell'interno (esclude banda FC)
    """
    assert u.shape == v.shape == p.shape
    B, Sx, Sy = u.shape
    device = u.device

    # 3.1 FC padding per ciascun canale
    u_ext = fc_pad2d_even(u, m)   # (B, Sx+2m, Sy+2m)
    v_ext = fc_pad2d_even(v, m)
    p_ext = fc_pad2d_even(p, m)

    # 3.2 Derivate spettrali su esteso
    ux_ext, uy_ext, lap_u_ext = _spectral_derivatives_on_extended(u_ext, dealias=dealias)
    vx_ext, vy_ext, lap_v_ext = _spectral_derivatives_on_extended(v_ext, dealias=dealias)
    px_ext, py_ext, _         = _spectral_derivatives_on_extended(p_ext, dealias=dealias)

    # 3.3 Crop centrale (tornare alla griglia originale)
    ux   = center_crop2d(ux_ext,   m)
    uy   = center_crop2d(uy_ext,   m)
    vx   = center_crop2d(vx_ext,   m)
    vy   = center_crop2d(vy_ext,   m)
    lap_u= center_crop2d(lap_u_ext,m)
    lap_v= center_crop2d(lap_v_ext,m)
    px   = center_crop2d(px_ext,   m)
    py   = center_crop2d(py_ext,   m)

    # 3.4 Divergenza e convettivo (sulla griglia originale)
    div_u = ux + vy
    convx = u * ux + v * uy
    convy = u * vx + v * vy

    # 3.5 Maschera interno (True solo lontano dai bordi fisici)
    interior_mask = torch.zeros(1, Sx, Sy, dtype=torch.bool, device=device)
    interior_mask[:, m:Sx-m, m:Sy-m] = True

    return {
        'ux': ux, 'uy': uy, 'vx': vx, 'vy': vy,
        'lap_u': lap_u, 'lap_v': lap_v,
        'div_u': div_u,
        'px': px, 'py': py,
        'convx': convx, 'convy': convy,
        'interior_mask': interior_mask
    }

# %%
################################################################
# training and evaluation
################################################################
# Parametri\ 

ntrain      = 1

modes       = 24
width       = 64


batch_size  = 1
epochs      = 250

learning_rate   = 2e-3
scheduler_step  = 20
scheduler_gamma = 0.5


step        = 1

rf          = 8
orders_v    = [2,2]
n_samples   = 4
model = Net2d(modes, width).cuda()
# model = torch.load('model/ns_fourier_V100_N1000_ep100_m8_w10')

print(model.count_params())
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=scheduler_gamma)


myloss = LpLoss(size_average=False)

test_full = []

path = f'FNO_Sup_ep{epochs}_m{modes}_w{width}_T{T}'

path_model     = os.path.join('model',  path)
path_image     = os.path.join('image',  path)
path_loss_dir  = os.path.join('loss',   path)
os.makedirs(path_image, exist_ok=True)
os.makedirs(path_loss_dir, exist_ok=True)
os.makedirs(os.path.dirname(path_model), exist_ok=True)
# ============================
# Training loop robusto a T lunghi
# ============================

import numpy as np
import torch

# ---- impostazioni autoregressione / stabilità ----
predict_delta   = False     # True: modello predice Δ; False: predice stato assoluto
use_detach      = True     # stacca il gradiente quando reinserisci la predizione in finestra
time_weighting  = True     # pesa di più gli step temporali lontani
noise_std       = 0.0      # es. 0.01 se lavori con canali normalizzati (std~1). 0.0 = off
grad_clip       = 1.0      # clipping del gradiente (None o 0.0 per disattivare)

# ---- scheduled sampling con "pavimento" ----
tf_max = 1.0
tf_min = 0.10                   # non scendere mai sotto il 10% di teacher forcing
warm   = int(0.6 * 200)      # epoche su cui far decrescere p GT -> tf_min

def get_tf_ratio(ep):
    # Cosine decay da 1.0 a tf_min durante il warmup
    x = min(1.0, ep / max(1, warm))
    # 0 -> 1: cos decresce da 1 a -1
    return float(tf_min + 0.5*(tf_max - tf_min)*(1.0 + torch.cos(torch.tensor(np.pi*x)).item()))

def make_boundary_mask(Sx, Sy, thickness=1, device='cuda'):
    bm = torch.zeros(1, Sx, Sy, 1, device=device)
    t = int(thickness)
    bm[:, :t, :, :]  = 1;  bm[:, -t:, :, :] = 1
    bm[:, :, :t, :]  = 1;  bm[:, :, -t:, :] = 1
    return bm  # shape (1,Sx,Sy,1)

C = 3  # (u,v,p) per passo
# Out:
# 37774979

# %%
nu = 0.01
dt = 0.1

lambda_res = 1.0      # peso della residual loss (tuning a piacere)
beta_div   = 1.0      # peso del vincolo di incomprimibilità
m_fc       = 2       # spessore banda Fourier continuation

C = 3
# Pesi per fase (modifica liberamente)
PHASES = [
    {
        'name': 'P1_border_only',
        'epochs':epochs,
        'lambda_bd': 1.0,
        'record': False

    }
]

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=0.5)

for iph, phase in enumerate(PHASES, 1):


    lambda_bd  = phase['lambda_bd']

    print(f"\n===== Phase {iph}/{len(PHASES)}: {phase['name']}  (epochs={phase['epochs']}) =====")
    print(f"lambdas → bd:{lambda_bd}  res:{lambda_res}")

    boundary_loss, full_loss, res_loss = [], [], []

    # usa le epoche della fase
    for ep in range(phase['epochs']):
        model.train()
        t_start = default_timer()

        # accumulatori epoca
        train_l2_step = 0.0           # loss totale per step (tutte le componenti)
        train_l2_full = 0.0           # L2 full-sequence (monitoring)
        train_bd_step = 0.0           # supervisione bordo (u,v)
        train_p_step  = 0.0           # supervisione pressione full
        train_res_step = 0.0          # residual loss

        tf_ratio = get_tf_ratio(ep)

        for xx, yy in train_loader:
            xx = xx.to(device, dtype=torch.float32)  # (B,Sx,Sy, 2 + 3*T_in)
            yy = yy.to(device, dtype=torch.float32)  # (B,Sx,Sy, 3*T)

            B, Sx, Sy = xx.shape[0], xx.shape[1], xx.shape[2]
            bd_mask = make_boundary_mask(Sx, Sy, thickness=1, device=xx.device)  # (1,Sx,Sy,1)

            loss = 0.0
            preds = []

            # accumulatori per QUESTO batch (sommati sui T step)
            sum_bd_batch = 0.0
            sum_p_batch  = 0.0
            sum_res_batch = 0.0

            for t in range(T):
                # target (u_{t+1}, v_{t+1}, p_{t+1})
                y  = yy[..., C*t : C*(t+1)]                          # (B,Sx,Sy,3)

                # predizione
                if predict_delta:
                    base = xx[..., -C:]                              # (u_t,v_t,p_t)
                    delta = model(xx)                                # (Δu,Δv,Δp)
                    im = base + delta                                # (u_{t+1}, v_{t+1}, p_{t+1})
                else:
                    im = model(xx)

                preds.append(im)

                loss_p_t = myloss(im.reshape(B, -1), y.reshape(B, -1))

                # somma alla loss totale con i pesi di fase
                loss = loss  + lambda_bd * (loss_p_t)
                xy   = xx[..., :2]
                hist = xx[..., 2:]
                hist = torch.cat([hist[..., C:], y], dim=-1)   # sposta la finestra e aggiunge feed
                xx   = torch.cat([xy, hist], dim=-1)

                # ---- accumula per-step (batch) ----
                sum_p_batch   += loss_p_t.item()

            # ---- metriche full-sequence ----
            pred_seq = torch.cat(preds, dim=-1)                        # (B,Sx,Sy, 3*T)
            train_l2_full += myloss(pred_seq.reshape(B, -1), yy.reshape(B, -1)).item()

            # ---- accumula su epoca ----
            train_l2_step += loss.item()
            train_bd_step += sum_bd_batch
            train_p_step  += sum_p_batch
            train_res_step += sum_res_batch

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            if grad_clip and grad_clip > 0.0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            optimizer.step()

        scheduler.step()
        elapsed = default_timer() - t_start
        denom_steps = T * len(train_loader)

        print(f"[Phase {iph}:{phase['name']}] Ep {ep+1:3d}/{phase['epochs']} │ "
              f"Time: {elapsed:6.2f}s │ "
              f"Train step BD(u,v): {train_bd_step/denom_steps:8.4e} │ "
              f"Train step P(full): {train_p_step/denom_steps:8.4e} │ "
              f"Train step RES: {train_res_step/denom_steps:8.4e} │ "
              f"Train step TOTAL: {train_l2_step/denom_steps:8.4e} │ "
              f"Train full L2: {train_l2_full/len(train_loader):8.4e} │ ")

        # salva serie per plotting
        boundary_loss.append(train_bd_step/denom_steps)                     # solo (u,v) bordo
        full_loss.append(train_l2_full/len(train_loader))
        if phase['record']:
            res_loss.append(train_res_step/denom_steps)
    try:
        phase_losses
    except NameError:
        phase_losses = {}

    phase_losses[phase['name']] = {
        "boundary": boundary_loss,
        "full": full_loss,
        "res": res_loss if phase.get('record', False) else None
    }
    idx = list(range(1, phase['epochs']+1))
    data = {
        'loss_boundary':   boundary_loss,
        'loss_full': full_loss,
    }
    if phase['record']:
        data['loss_res'] = res_loss
    df = pd.DataFrame(data, index=idx)
    df.index.name = 'epoch_in_phase'
    csv_path = os.path.join(path_loss_dir, f"loss_{phase['name']}.csv")
    df.to_csv(csv_path)
    print(f"→ Saved loss history for phase '{phase['name']}' in {csv_path}")
# Out:
# ===== Phase 1/1: P1_border_only  (epochs=250) =====
# lambdas → bd:1.0  res:1.0
# [Phase 1:P1_border_only] Ep   1/250 │ Time:   0.54s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0763e+00 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0763e+00 │ Train full L2: 1.0763e+00 │
# [Phase 1:P1_border_only] Ep   2/250 │ Time:   0.17s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.5871e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.5871e-01 │ Train full L2: 9.5872e-01 │
# [Phase 1:P1_border_only] Ep   3/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.6633e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.6633e-01 │ Train full L2: 8.6634e-01 │
# [Phase 1:P1_border_only] Ep   4/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.9238e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.9238e-01 │ Train full L2: 7.9240e-01 │
# [Phase 1:P1_border_only] Ep   5/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.3037e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.3037e-01 │ Train full L2: 7.3040e-01 │
# [Phase 1:P1_border_only] Ep   6/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.7707e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.7707e-01 │ Train full L2: 6.7712e-01 │
# [Phase 1:P1_border_only] Ep   7/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.3029e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.3029e-01 │ Train full L2: 6.3036e-01 │
# [Phase 1:P1_border_only] Ep   8/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8726e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8726e-01 │ Train full L2: 5.8735e-01 │
# [Phase 1:P1_border_only] Ep   9/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.4676e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.4676e-01 │ Train full L2: 5.4688e-01 │
# [Phase 1:P1_border_only] Ep  10/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.0884e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.0884e-01 │ Train full L2: 5.0898e-01 │
# [Phase 1:P1_border_only] Ep  11/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.7315e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.7315e-01 │ Train full L2: 4.7329e-01 │
# [Phase 1:P1_border_only] Ep  12/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.3893e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.3893e-01 │ Train full L2: 4.3908e-01 │
# [Phase 1:P1_border_only] Ep  13/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.0598e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.0598e-01 │ Train full L2: 4.0615e-01 │
# [Phase 1:P1_border_only] Ep  14/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.7456e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.7456e-01 │ Train full L2: 3.7474e-01 │
# [Phase 1:P1_border_only] Ep  15/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.4438e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.4438e-01 │ Train full L2: 3.4458e-01 │
# [Phase 1:P1_border_only] Ep  16/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.1516e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.1516e-01 │ Train full L2: 3.1538e-01 │
# [Phase 1:P1_border_only] Ep  17/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.8705e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.8705e-01 │ Train full L2: 2.8730e-01 │
# [Phase 1:P1_border_only] Ep  18/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.6018e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.6018e-01 │ Train full L2: 2.6048e-01 │
# [Phase 1:P1_border_only] Ep  19/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.3432e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.3432e-01 │ Train full L2: 2.3467e-01 │
# [Phase 1:P1_border_only] Ep  20/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.0939e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.0939e-01 │ Train full L2: 2.0980e-01 │
# [Phase 1:P1_border_only] Ep  21/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.8541e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.8541e-01 │ Train full L2: 1.8591e-01 │
# [Phase 1:P1_border_only] Ep  22/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.7342e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.7342e-01 │ Train full L2: 1.7397e-01 │
# [Phase 1:P1_border_only] Ep  23/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.6108e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.6108e-01 │ Train full L2: 1.6170e-01 │
# [Phase 1:P1_border_only] Ep  24/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.4863e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.4863e-01 │ Train full L2: 1.4934e-01 │
# [Phase 1:P1_border_only] Ep  25/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.3634e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.3634e-01 │ Train full L2: 1.3716e-01 │
# [Phase 1:P1_border_only] Ep  26/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.2444e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.2444e-01 │ Train full L2: 1.2539e-01 │
# [Phase 1:P1_border_only] Ep  27/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1291e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1291e-01 │ Train full L2: 1.1403e-01 │
# [Phase 1:P1_border_only] Ep  28/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0172e-01 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0172e-01 │ Train full L2: 1.0304e-01 │
# [Phase 1:P1_border_only] Ep  29/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.0807e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.0807e-02 │ Train full L2: 9.2414e-02 │
# [Phase 1:P1_border_only] Ep  30/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.0318e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.0318e-02 │ Train full L2: 8.2278e-02 │
# [Phase 1:P1_border_only] Ep  31/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.0487e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.0487e-02 │ Train full L2: 7.2873e-02 │
# [Phase 1:P1_border_only] Ep  32/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1643e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1643e-02 │ Train full L2: 6.4483e-02 │
# [Phase 1:P1_border_only] Ep  33/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.4039e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.4039e-02 │ Train full L2: 5.7276e-02 │
# [Phase 1:P1_border_only] Ep  34/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.7949e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.7949e-02 │ Train full L2: 5.1389e-02 │
# [Phase 1:P1_border_only] Ep  35/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.3798e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.3798e-02 │ Train full L2: 4.6982e-02 │
# [Phase 1:P1_border_only] Ep  36/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.1897e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.1897e-02 │ Train full L2: 4.4247e-02 │
# [Phase 1:P1_border_only] Ep  37/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 4.0463e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 4.0463e-02 │ Train full L2: 4.2198e-02 │
# [Phase 1:P1_border_only] Ep  38/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.9710e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.9710e-02 │ Train full L2: 4.0942e-02 │
# [Phase 1:P1_border_only] Ep  39/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.8029e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.8029e-02 │ Train full L2: 3.8959e-02 │
# [Phase 1:P1_border_only] Ep  40/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.6192e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.6192e-02 │ Train full L2: 3.6975e-02 │
# [Phase 1:P1_border_only] Ep  41/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.3481e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.3481e-02 │ Train full L2: 3.4287e-02 │
# [Phase 1:P1_border_only] Ep  42/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 3.1744e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 3.1744e-02 │ Train full L2: 3.2606e-02 │
# [Phase 1:P1_border_only] Ep  43/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.9749e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.9749e-02 │ Train full L2: 3.0742e-02 │
# [Phase 1:P1_border_only] Ep  44/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.7608e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.7608e-02 │ Train full L2: 2.8861e-02 │
# [Phase 1:P1_border_only] Ep  45/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.5656e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.5656e-02 │ Train full L2: 2.7171e-02 │
# [Phase 1:P1_border_only] Ep  46/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.4012e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.4012e-02 │ Train full L2: 2.5592e-02 │
# [Phase 1:P1_border_only] Ep  47/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.2720e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.2720e-02 │ Train full L2: 2.4394e-02 │
# [Phase 1:P1_border_only] Ep  48/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.1828e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.1828e-02 │ Train full L2: 2.3582e-02 │
# [Phase 1:P1_border_only] Ep  49/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.0912e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.0912e-02 │ Train full L2: 2.2565e-02 │
# [Phase 1:P1_border_only] Ep  50/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 2.0128e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 2.0128e-02 │ Train full L2: 2.1594e-02 │
# [Phase 1:P1_border_only] Ep  51/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.9177e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.9177e-02 │ Train full L2: 2.0632e-02 │
# [Phase 1:P1_border_only] Ep  52/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.8389e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.8389e-02 │ Train full L2: 1.9793e-02 │
# [Phase 1:P1_border_only] Ep  53/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.7439e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.7439e-02 │ Train full L2: 1.8833e-02 │
# [Phase 1:P1_border_only] Ep  54/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.6927e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.6927e-02 │ Train full L2: 1.8245e-02 │
# [Phase 1:P1_border_only] Ep  55/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.6191e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.6191e-02 │ Train full L2: 1.7536e-02 │
# [Phase 1:P1_border_only] Ep  56/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.6053e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.6053e-02 │ Train full L2: 1.7283e-02 │
# [Phase 1:P1_border_only] Ep  57/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.5768e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.5768e-02 │ Train full L2: 1.6964e-02 │
# [Phase 1:P1_border_only] Ep  58/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.4944e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.4944e-02 │ Train full L2: 1.6219e-02 │
# [Phase 1:P1_border_only] Ep  59/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.4820e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.4820e-02 │ Train full L2: 1.5959e-02 │
# [Phase 1:P1_border_only] Ep  60/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.4228e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.4228e-02 │ Train full L2: 1.5366e-02 │
# [Phase 1:P1_border_only] Ep  61/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.3751e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.3751e-02 │ Train full L2: 1.4948e-02 │
# [Phase 1:P1_border_only] Ep  62/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.3451e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.3451e-02 │ Train full L2: 1.4680e-02 │
# [Phase 1:P1_border_only] Ep  63/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.2994e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.2994e-02 │ Train full L2: 1.4267e-02 │
# [Phase 1:P1_border_only] Ep  64/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.2708e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.2708e-02 │ Train full L2: 1.3980e-02 │
# [Phase 1:P1_border_only] Ep  65/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.2477e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.2477e-02 │ Train full L2: 1.3724e-02 │
# [Phase 1:P1_border_only] Ep  66/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.2122e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.2122e-02 │ Train full L2: 1.3413e-02 │
# [Phase 1:P1_border_only] Ep  67/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1842e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1842e-02 │ Train full L2: 1.3214e-02 │
# [Phase 1:P1_border_only] Ep  68/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1686e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1686e-02 │ Train full L2: 1.3085e-02 │
# [Phase 1:P1_border_only] Ep  69/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1429e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1429e-02 │ Train full L2: 1.2814e-02 │
# [Phase 1:P1_border_only] Ep  70/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1204e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1204e-02 │ Train full L2: 1.2574e-02 │
# [Phase 1:P1_border_only] Ep  71/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.1088e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.1088e-02 │ Train full L2: 1.2455e-02 │
# [Phase 1:P1_border_only] Ep  72/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0873e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0873e-02 │ Train full L2: 1.2257e-02 │
# [Phase 1:P1_border_only] Ep  73/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0659e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0659e-02 │ Train full L2: 1.2058e-02 │
# [Phase 1:P1_border_only] Ep  74/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0522e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0522e-02 │ Train full L2: 1.1919e-02 │
# [Phase 1:P1_border_only] Ep  75/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0283e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0283e-02 │ Train full L2: 1.1670e-02 │
# [Phase 1:P1_border_only] Ep  76/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 1.0115e-02 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 1.0115e-02 │ Train full L2: 1.1484e-02 │
# [Phase 1:P1_border_only] Ep  77/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.9406e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.9406e-03 │ Train full L2: 1.1311e-02 │
# [Phase 1:P1_border_only] Ep  78/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.7479e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.7479e-03 │ Train full L2: 1.1125e-02 │
# [Phase 1:P1_border_only] Ep  79/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.6359e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.6359e-03 │ Train full L2: 1.1016e-02 │
# [Phase 1:P1_border_only] Ep  80/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.4624e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.4624e-03 │ Train full L2: 1.0831e-02 │
# [Phase 1:P1_border_only] Ep  81/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.3427e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.3427e-03 │ Train full L2: 1.0674e-02 │
# [Phase 1:P1_border_only] Ep  82/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.2275e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.2275e-03 │ Train full L2: 1.0569e-02 │
# [Phase 1:P1_border_only] Ep  83/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.1099e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.1099e-03 │ Train full L2: 1.0478e-02 │
# [Phase 1:P1_border_only] Ep  84/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 9.0844e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 9.0844e-03 │ Train full L2: 1.0449e-02 │
# [Phase 1:P1_border_only] Ep  85/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.9696e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.9696e-03 │ Train full L2: 1.0348e-02 │
# [Phase 1:P1_border_only] Ep  86/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.8547e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.8547e-03 │ Train full L2: 1.0239e-02 │
# [Phase 1:P1_border_only] Ep  87/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.8010e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.8010e-03 │ Train full L2: 1.0177e-02 │
# [Phase 1:P1_border_only] Ep  88/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.7132e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.7132e-03 │ Train full L2: 1.0094e-02 │
# [Phase 1:P1_border_only] Ep  89/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.6156e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.6156e-03 │ Train full L2: 1.0007e-02 │
# [Phase 1:P1_border_only] Ep  90/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.5508e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.5508e-03 │ Train full L2: 9.9432e-03 │
# [Phase 1:P1_border_only] Ep  91/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.4581e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.4581e-03 │ Train full L2: 9.8575e-03 │
# [Phase 1:P1_border_only] Ep  92/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.3859e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.3859e-03 │ Train full L2: 9.7892e-03 │
# [Phase 1:P1_border_only] Ep  93/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.3009e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.3009e-03 │ Train full L2: 9.6984e-03 │
# [Phase 1:P1_border_only] Ep  94/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.2131e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.2131e-03 │ Train full L2: 9.6015e-03 │
# [Phase 1:P1_border_only] Ep  95/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.1383e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.1383e-03 │ Train full L2: 9.5314e-03 │
# [Phase 1:P1_border_only] Ep  96/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 8.0561e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 8.0561e-03 │ Train full L2: 9.4509e-03 │
# [Phase 1:P1_border_only] Ep  97/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.9719e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.9719e-03 │ Train full L2: 9.3731e-03 │
# [Phase 1:P1_border_only] Ep  98/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.8966e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.8966e-03 │ Train full L2: 9.2817e-03 │
# [Phase 1:P1_border_only] Ep  99/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.8028e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.8028e-03 │ Train full L2: 9.1738e-03 │
# [Phase 1:P1_border_only] Ep 100/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.7363e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.7363e-03 │ Train full L2: 9.1215e-03 │
# [Phase 1:P1_border_only] Ep 101/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.6440e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.6440e-03 │ Train full L2: 9.0239e-03 │
# [Phase 1:P1_border_only] Ep 102/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.5913e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.5913e-03 │ Train full L2: 8.9692e-03 │
# [Phase 1:P1_border_only] Ep 103/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.5504e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.5504e-03 │ Train full L2: 8.9173e-03 │
# [Phase 1:P1_border_only] Ep 104/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.5076e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.5076e-03 │ Train full L2: 8.8683e-03 │
# [Phase 1:P1_border_only] Ep 105/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.4550e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.4550e-03 │ Train full L2: 8.8239e-03 │
# [Phase 1:P1_border_only] Ep 106/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.4158e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.4158e-03 │ Train full L2: 8.7786e-03 │
# [Phase 1:P1_border_only] Ep 107/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.3687e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.3687e-03 │ Train full L2: 8.7301e-03 │
# [Phase 1:P1_border_only] Ep 108/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.3193e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.3193e-03 │ Train full L2: 8.6804e-03 │
# [Phase 1:P1_border_only] Ep 109/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.2727e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.2727e-03 │ Train full L2: 8.6228e-03 │
# [Phase 1:P1_border_only] Ep 110/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.2290e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.2290e-03 │ Train full L2: 8.5646e-03 │
# [Phase 1:P1_border_only] Ep 111/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.1826e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.1826e-03 │ Train full L2: 8.5177e-03 │
# [Phase 1:P1_border_only] Ep 112/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.1385e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.1385e-03 │ Train full L2: 8.4822e-03 │
# [Phase 1:P1_border_only] Ep 113/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.0949e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.0949e-03 │ Train full L2: 8.4383e-03 │
# [Phase 1:P1_border_only] Ep 114/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.0497e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.0497e-03 │ Train full L2: 8.3823e-03 │
# [Phase 1:P1_border_only] Ep 115/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 7.0064e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 7.0064e-03 │ Train full L2: 8.3254e-03 │
# [Phase 1:P1_border_only] Ep 116/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.9627e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.9627e-03 │ Train full L2: 8.2835e-03 │
# [Phase 1:P1_border_only] Ep 117/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.9199e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.9199e-03 │ Train full L2: 8.2418e-03 │
# [Phase 1:P1_border_only] Ep 118/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.8779e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.8779e-03 │ Train full L2: 8.1963e-03 │
# [Phase 1:P1_border_only] Ep 119/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.8315e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.8315e-03 │ Train full L2: 8.1403e-03 │
# [Phase 1:P1_border_only] Ep 120/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.7956e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.7956e-03 │ Train full L2: 8.1031e-03 │
# [Phase 1:P1_border_only] Ep 121/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.7531e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.7531e-03 │ Train full L2: 8.0542e-03 │
# [Phase 1:P1_border_only] Ep 122/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.7219e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.7219e-03 │ Train full L2: 8.0177e-03 │
# [Phase 1:P1_border_only] Ep 123/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.7011e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.7011e-03 │ Train full L2: 7.9911e-03 │
# [Phase 1:P1_border_only] Ep 124/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.6810e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.6810e-03 │ Train full L2: 7.9710e-03 │
# [Phase 1:P1_border_only] Ep 125/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.6530e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.6530e-03 │ Train full L2: 7.9455e-03 │
# [Phase 1:P1_border_only] Ep 126/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.6292e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.6292e-03 │ Train full L2: 7.9200e-03 │
# [Phase 1:P1_border_only] Ep 127/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.6045e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.6045e-03 │ Train full L2: 7.8892e-03 │
# [Phase 1:P1_border_only] Ep 128/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.5784e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.5784e-03 │ Train full L2: 7.8553e-03 │
# [Phase 1:P1_border_only] Ep 129/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.5538e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.5538e-03 │ Train full L2: 7.8254e-03 │
# [Phase 1:P1_border_only] Ep 130/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.5273e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.5273e-03 │ Train full L2: 7.8054e-03 │
# [Phase 1:P1_border_only] Ep 131/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.5020e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.5020e-03 │ Train full L2: 7.7798e-03 │
# [Phase 1:P1_border_only] Ep 132/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.4750e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.4750e-03 │ Train full L2: 7.7459e-03 │
# [Phase 1:P1_border_only] Ep 133/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.4486e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.4486e-03 │ Train full L2: 7.7113e-03 │
# [Phase 1:P1_border_only] Ep 134/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.4210e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.4210e-03 │ Train full L2: 7.6817e-03 │
# [Phase 1:P1_border_only] Ep 135/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.3918e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.3918e-03 │ Train full L2: 7.6476e-03 │
# [Phase 1:P1_border_only] Ep 136/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.3652e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.3652e-03 │ Train full L2: 7.6178e-03 │
# [Phase 1:P1_border_only] Ep 137/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.3347e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.3347e-03 │ Train full L2: 7.5872e-03 │
# [Phase 1:P1_border_only] Ep 138/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.3062e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.3062e-03 │ Train full L2: 7.5516e-03 │
# [Phase 1:P1_border_only] Ep 139/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.2763e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.2763e-03 │ Train full L2: 7.5121e-03 │
# [Phase 1:P1_border_only] Ep 140/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.2480e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.2480e-03 │ Train full L2: 7.4849e-03 │
# [Phase 1:P1_border_only] Ep 141/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.2176e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.2176e-03 │ Train full L2: 7.4501e-03 │
# [Phase 1:P1_border_only] Ep 142/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.2016e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.2016e-03 │ Train full L2: 7.4323e-03 │
# [Phase 1:P1_border_only] Ep 143/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1858e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1858e-03 │ Train full L2: 7.4160e-03 │
# [Phase 1:P1_border_only] Ep 144/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1705e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1705e-03 │ Train full L2: 7.3959e-03 │
# [Phase 1:P1_border_only] Ep 145/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1542e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1542e-03 │ Train full L2: 7.3740e-03 │
# [Phase 1:P1_border_only] Ep 146/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1393e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1393e-03 │ Train full L2: 7.3568e-03 │
# [Phase 1:P1_border_only] Ep 147/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1213e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1213e-03 │ Train full L2: 7.3381e-03 │
# [Phase 1:P1_border_only] Ep 148/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.1046e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.1046e-03 │ Train full L2: 7.3215e-03 │
# [Phase 1:P1_border_only] Ep 149/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0876e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0877e-03 │ Train full L2: 7.3006e-03 │
# [Phase 1:P1_border_only] Ep 150/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0708e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0708e-03 │ Train full L2: 7.2771e-03 │
# [Phase 1:P1_border_only] Ep 151/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0528e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0528e-03 │ Train full L2: 7.2559e-03 │
# [Phase 1:P1_border_only] Ep 152/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0371e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0371e-03 │ Train full L2: 7.2380e-03 │
# [Phase 1:P1_border_only] Ep 153/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0209e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0209e-03 │ Train full L2: 7.2200e-03 │
# [Phase 1:P1_border_only] Ep 154/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 6.0051e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 6.0051e-03 │ Train full L2: 7.1998e-03 │
# [Phase 1:P1_border_only] Ep 155/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9894e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9894e-03 │ Train full L2: 7.1830e-03 │
# [Phase 1:P1_border_only] Ep 156/250 │ Time:   0.21s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9728e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9728e-03 │ Train full L2: 7.1639e-03 │
# [Phase 1:P1_border_only] Ep 157/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9573e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9573e-03 │ Train full L2: 7.1424e-03 │
# [Phase 1:P1_border_only] Ep 158/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9405e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9405e-03 │ Train full L2: 7.1229e-03 │
# [Phase 1:P1_border_only] Ep 159/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9244e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9244e-03 │ Train full L2: 7.1057e-03 │
# [Phase 1:P1_border_only] Ep 160/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.9084e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.9084e-03 │ Train full L2: 7.0883e-03 │
# [Phase 1:P1_border_only] Ep 161/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8916e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8916e-03 │ Train full L2: 7.0688e-03 │
# [Phase 1:P1_border_only] Ep 162/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8834e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8834e-03 │ Train full L2: 7.0577e-03 │
# [Phase 1:P1_border_only] Ep 163/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8751e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8751e-03 │ Train full L2: 7.0491e-03 │
# [Phase 1:P1_border_only] Ep 164/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8677e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8677e-03 │ Train full L2: 7.0394e-03 │
# [Phase 1:P1_border_only] Ep 165/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8611e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8611e-03 │ Train full L2: 7.0304e-03 │
# [Phase 1:P1_border_only] Ep 166/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8523e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8523e-03 │ Train full L2: 7.0199e-03 │
# [Phase 1:P1_border_only] Ep 167/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8441e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8441e-03 │ Train full L2: 7.0115e-03 │
# [Phase 1:P1_border_only] Ep 168/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8368e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8368e-03 │ Train full L2: 7.0025e-03 │
# [Phase 1:P1_border_only] Ep 169/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8280e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8280e-03 │ Train full L2: 6.9930e-03 │
# [Phase 1:P1_border_only] Ep 170/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8203e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8203e-03 │ Train full L2: 6.9834e-03 │
# [Phase 1:P1_border_only] Ep 171/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8127e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8127e-03 │ Train full L2: 6.9740e-03 │
# [Phase 1:P1_border_only] Ep 172/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.8051e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.8051e-03 │ Train full L2: 6.9638e-03 │
# [Phase 1:P1_border_only] Ep 173/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7966e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7966e-03 │ Train full L2: 6.9542e-03 │
# [Phase 1:P1_border_only] Ep 174/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7885e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7885e-03 │ Train full L2: 6.9455e-03 │
# [Phase 1:P1_border_only] Ep 175/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7802e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7802e-03 │ Train full L2: 6.9363e-03 │
# [Phase 1:P1_border_only] Ep 176/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7713e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7713e-03 │ Train full L2: 6.9275e-03 │
# [Phase 1:P1_border_only] Ep 177/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7649e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7649e-03 │ Train full L2: 6.9178e-03 │
# [Phase 1:P1_border_only] Ep 178/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7560e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7560e-03 │ Train full L2: 6.9079e-03 │
# [Phase 1:P1_border_only] Ep 179/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7492e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7492e-03 │ Train full L2: 6.8979e-03 │
# [Phase 1:P1_border_only] Ep 180/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7401e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7401e-03 │ Train full L2: 6.8880e-03 │
# [Phase 1:P1_border_only] Ep 181/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7335e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7335e-03 │ Train full L2: 6.8791e-03 │
# [Phase 1:P1_border_only] Ep 182/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7298e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7298e-03 │ Train full L2: 6.8745e-03 │
# [Phase 1:P1_border_only] Ep 183/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7276e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7276e-03 │ Train full L2: 6.8721e-03 │
# [Phase 1:P1_border_only] Ep 184/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7229e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7229e-03 │ Train full L2: 6.8667e-03 │
# [Phase 1:P1_border_only] Ep 185/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7183e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7183e-03 │ Train full L2: 6.8616e-03 │
# [Phase 1:P1_border_only] Ep 186/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7161e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7161e-03 │ Train full L2: 6.8587e-03 │
# [Phase 1:P1_border_only] Ep 187/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7127e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7127e-03 │ Train full L2: 6.8546e-03 │
# [Phase 1:P1_border_only] Ep 188/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7088e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7088e-03 │ Train full L2: 6.8503e-03 │
# [Phase 1:P1_border_only] Ep 189/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7049e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7049e-03 │ Train full L2: 6.8464e-03 │
# [Phase 1:P1_border_only] Ep 190/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.7012e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.7012e-03 │ Train full L2: 6.8413e-03 │
# [Phase 1:P1_border_only] Ep 191/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6969e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6969e-03 │ Train full L2: 6.8373e-03 │
# [Phase 1:P1_border_only] Ep 192/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6940e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6940e-03 │ Train full L2: 6.8327e-03 │
# [Phase 1:P1_border_only] Ep 193/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6902e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6902e-03 │ Train full L2: 6.8277e-03 │
# [Phase 1:P1_border_only] Ep 194/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6853e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6853e-03 │ Train full L2: 6.8219e-03 │
# [Phase 1:P1_border_only] Ep 195/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6820e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6820e-03 │ Train full L2: 6.8179e-03 │
# [Phase 1:P1_border_only] Ep 196/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6788e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6788e-03 │ Train full L2: 6.8140e-03 │
# [Phase 1:P1_border_only] Ep 197/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6740e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6740e-03 │ Train full L2: 6.8098e-03 │
# [Phase 1:P1_border_only] Ep 198/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6701e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6701e-03 │ Train full L2: 6.8057e-03 │
# [Phase 1:P1_border_only] Ep 199/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6669e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6669e-03 │ Train full L2: 6.8016e-03 │
# [Phase 1:P1_border_only] Ep 200/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6631e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6631e-03 │ Train full L2: 6.7966e-03 │
# [Phase 1:P1_border_only] Ep 201/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6594e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6594e-03 │ Train full L2: 6.7924e-03 │
# [Phase 1:P1_border_only] Ep 202/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6574e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6574e-03 │ Train full L2: 6.7906e-03 │
# [Phase 1:P1_border_only] Ep 203/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6559e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6559e-03 │ Train full L2: 6.7880e-03 │
# [Phase 1:P1_border_only] Ep 204/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6543e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6543e-03 │ Train full L2: 6.7856e-03 │
# [Phase 1:P1_border_only] Ep 205/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6534e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6534e-03 │ Train full L2: 6.7847e-03 │
# [Phase 1:P1_border_only] Ep 206/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6512e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6512e-03 │ Train full L2: 6.7818e-03 │
# [Phase 1:P1_border_only] Ep 207/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6487e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6487e-03 │ Train full L2: 6.7789e-03 │
# [Phase 1:P1_border_only] Ep 208/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6476e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6476e-03 │ Train full L2: 6.7769e-03 │
# [Phase 1:P1_border_only] Ep 209/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6455e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6455e-03 │ Train full L2: 6.7747e-03 │
# [Phase 1:P1_border_only] Ep 210/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6433e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6433e-03 │ Train full L2: 6.7723e-03 │
# [Phase 1:P1_border_only] Ep 211/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6419e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6419e-03 │ Train full L2: 6.7711e-03 │
# [Phase 1:P1_border_only] Ep 212/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6401e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6401e-03 │ Train full L2: 6.7687e-03 │
# [Phase 1:P1_border_only] Ep 213/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6383e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6383e-03 │ Train full L2: 6.7658e-03 │
# [Phase 1:P1_border_only] Ep 214/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6371e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6371e-03 │ Train full L2: 6.7642e-03 │
# [Phase 1:P1_border_only] Ep 215/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6353e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6353e-03 │ Train full L2: 6.7618e-03 │
# [Phase 1:P1_border_only] Ep 216/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6328e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6328e-03 │ Train full L2: 6.7589e-03 │
# [Phase 1:P1_border_only] Ep 217/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6311e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6311e-03 │ Train full L2: 6.7569e-03 │
# [Phase 1:P1_border_only] Ep 218/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6297e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6297e-03 │ Train full L2: 6.7564e-03 │
# [Phase 1:P1_border_only] Ep 219/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6292e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6292e-03 │ Train full L2: 6.7549e-03 │
# [Phase 1:P1_border_only] Ep 220/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6279e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6279e-03 │ Train full L2: 6.7529e-03 │
# [Phase 1:P1_border_only] Ep 221/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6255e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6255e-03 │ Train full L2: 6.7501e-03 │
# [Phase 1:P1_border_only] Ep 222/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6250e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6250e-03 │ Train full L2: 6.7495e-03 │
# [Phase 1:P1_border_only] Ep 223/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6247e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6247e-03 │ Train full L2: 6.7486e-03 │
# [Phase 1:P1_border_only] Ep 224/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6236e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6236e-03 │ Train full L2: 6.7466e-03 │
# [Phase 1:P1_border_only] Ep 225/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6221e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6221e-03 │ Train full L2: 6.7458e-03 │
# [Phase 1:P1_border_only] Ep 226/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6210e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6210e-03 │ Train full L2: 6.7450e-03 │
# [Phase 1:P1_border_only] Ep 227/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6203e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6203e-03 │ Train full L2: 6.7444e-03 │
# [Phase 1:P1_border_only] Ep 228/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6199e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6199e-03 │ Train full L2: 6.7439e-03 │
# [Phase 1:P1_border_only] Ep 229/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6193e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6193e-03 │ Train full L2: 6.7431e-03 │
# [Phase 1:P1_border_only] Ep 230/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6182e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6182e-03 │ Train full L2: 6.7415e-03 │
# [Phase 1:P1_border_only] Ep 231/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6168e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6168e-03 │ Train full L2: 6.7402e-03 │
# [Phase 1:P1_border_only] Ep 232/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6159e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6159e-03 │ Train full L2: 6.7388e-03 │
# [Phase 1:P1_border_only] Ep 233/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6161e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6161e-03 │ Train full L2: 6.7379e-03 │
# [Phase 1:P1_border_only] Ep 234/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6144e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6144e-03 │ Train full L2: 6.7364e-03 │
# [Phase 1:P1_border_only] Ep 235/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6138e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6138e-03 │ Train full L2: 6.7354e-03 │
# [Phase 1:P1_border_only] Ep 236/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6119e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6119e-03 │ Train full L2: 6.7340e-03 │
# [Phase 1:P1_border_only] Ep 237/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6113e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6113e-03 │ Train full L2: 6.7331e-03 │
# [Phase 1:P1_border_only] Ep 238/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6107e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6107e-03 │ Train full L2: 6.7324e-03 │
# [Phase 1:P1_border_only] Ep 239/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6100e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6100e-03 │ Train full L2: 6.7322e-03 │
# [Phase 1:P1_border_only] Ep 240/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6089e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6089e-03 │ Train full L2: 6.7312e-03 │
# [Phase 1:P1_border_only] Ep 241/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6083e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6083e-03 │ Train full L2: 6.7303e-03 │
# [Phase 1:P1_border_only] Ep 242/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6082e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6082e-03 │ Train full L2: 6.7299e-03 │
# [Phase 1:P1_border_only] Ep 243/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6076e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6076e-03 │ Train full L2: 6.7292e-03 │
# [Phase 1:P1_border_only] Ep 244/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6073e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6073e-03 │ Train full L2: 6.7283e-03 │
# [Phase 1:P1_border_only] Ep 245/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6073e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6073e-03 │ Train full L2: 6.7283e-03 │
# [Phase 1:P1_border_only] Ep 246/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6068e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6068e-03 │ Train full L2: 6.7276e-03 │
# [Phase 1:P1_border_only] Ep 247/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6057e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6057e-03 │ Train full L2: 6.7267e-03 │
# [Phase 1:P1_border_only] Ep 248/250 │ Time:   0.20s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6051e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6051e-03 │ Train full L2: 6.7272e-03 │
# [Phase 1:P1_border_only] Ep 249/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6044e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6044e-03 │ Train full L2: 6.7262e-03 │
# [Phase 1:P1_border_only] Ep 250/250 │ Time:   0.19s │ Train step BD(u,v): 0.0000e+00 │ Train step P(full): 5.6040e-03 │ Train step RES: 0.0000e+00 │ Train step TOTAL: 5.6040e-03 │ Train full L2: 6.7248e-03 │
# → Saved loss history for phase 'P1_border_only' in loss/FNO_Sup_ep250_m24_w64_T10/loss_P1_border_only.csv

# %%
# --- Dopo l'ultima fase, fai i plot ---
for ph_name, logs in phase_losses.items():
    plt.figure(figsize=(8,5))
    epochs = range(1, len(logs["boundary"])+1)

    plt.plot(epochs, logs["boundary"], label="Loss_bd", color="tab:blue")
    plt.plot(epochs, logs["full"], label="Full L2 (train)", color="tab:orange")
    if logs["res"] is not None and len(logs["res"])>0:
        plt.plot(epochs, logs["res"], label="Residual (interior)", color="tab:red")

    plt.yscale("log")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Loss curves – {ph_name}")
    plt.legend()
    plt.grid(True, ls=":", alpha=0.5)
    plt.show()

# =============================
# Plot cumulativo di full_loss
# =============================

plt.figure(figsize=(9,5))
plt.yscale("log")

cum_x = 0
for ph_name, logs in phase_losses.items():
    y = logs["full"]
    x = range(cum_x+1, cum_x+len(y)+1)
    plt.plot(x, y, color="limegreen", linewidth=2.0, label=f"{ph_name}")  # verde chiaro fluo
    cum_x += len(y)

plt.xlabel("Epoch (cumulative across phases)")
plt.ylabel("Full L2 loss")
plt.title("Full L2 across all phases")
plt.legend()
plt.grid(True, ls=":", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# -----------------------------------------
# genera predizioni autoregressive dal modello
# -----------------------------------------
def predict_sequence(model, xx, yy, T, step=1, C=3):
    model.eval()
    preds = []
    with torch.no_grad():
        for t in range(0, T, step):
            y = yy[..., 3*t:3*(t+1)] 
           # ---- predizione ----
            if predict_delta:
                # base = ultimo stato nella finestra (u_t, v_t, p_t)
                base = xx[..., -C:]                                # (B,Sx,Sy,3)
                delta = model(xx)                                  # (B,Sx,Sy,3)
                im = base + delta                                  # pred stato t+1
            else:
                im = model(xx)                                     # pred stato t+1 diretto
            
            preds.append(im)
            
            # aggiorna input con autoregressione
            xy   = xx[..., :2]
            hist = xx[..., 2:]
            hist = torch.cat([hist[..., C:], y], dim=-1)
            xx   = torch.cat([xy, hist], dim=-1)
    pred_seq = torch.cat(preds, dim=-1)  # (B, Sx, Sy, 3*T)
    return pred_seq


# -----------------------------------------
# funzione per animare u,v,p
# -----------------------------------------
def animate_prediction(xx, yy, model, T, step=1, interval=200,
                       save_prefix="anim",  # solo basename del file (niente path)
                       cmap_field="jet", cmap_err="magma",
                       add_colorbars=True, times=None,
                       out_dir=".", save_last_png=True, filename_base=None):
    """
    out_dir: cartella dove salvare i file (es. path_image)
    save_last_png: se True salva anche l'ultimo frame come PNG
    filename_base: basename per i file; se None usa save_prefix
    """
    import os
    if filename_base is None:
        filename_base = save_prefix
    os.makedirs(out_dir, exist_ok=True)

    C = 3
    pred_seq = predict_sequence(model, xx.clone(), yy.clone(), T, step, C)  # (B,Sx,Sy,3*Tpred)
    B, Sx, Sy, _ = pred_seq.shape
    Tpred = pred_seq.shape[-1] // C

    # estrai pred e gt (B,Sx,Sy,T)
    u_pred = pred_seq[..., 0::C]; v_pred = pred_seq[..., 1::C]; p_pred = pred_seq[..., 2::C]
    u_true = yy      [..., 0::C]; v_true = yy      [..., 1::C]; p_true = yy      [..., 2::C]

    # to numpy (Sx,Sy,T)
    u_pred = u_pred.squeeze(0).detach().cpu().numpy()
    v_pred = v_pred.squeeze(0).detach().cpu().numpy()
    p_pred = p_pred.squeeze(0).detach().cpu().numpy()
    u_true = u_true.squeeze(0).detach().cpu().numpy()
    v_true = v_true.squeeze(0).detach().cpu().numpy()
    p_true = p_true.squeeze(0).detach().cpu().numpy()

    # errori (Sx,Sy,T)
    eu = np.abs(u_pred - u_true)
    ev = np.abs(v_pred - v_true)
    ep = np.abs(p_pred - p_true)

    # range colori stabile (dai GT)
    vmin_u, vmax_u = float(u_true.min()), float(u_true.max())
    vmin_v, vmax_v = float(v_true.min()), float(v_true.max())
    vmin_p, vmax_p = float(p_true.min()), float(p_true.max())

    # range errore robusto (99° percentile)
    emax_u = max(1e-12, float(np.percentile(eu, 99)))
    emax_v = max(1e-12, float(np.percentile(ev, 99)))
    emax_p = max(1e-12, float(np.percentile(ep, 99)))

    # figura animazione 3x3
    fig, axes = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
    titles_top = ['u pred', 'v pred', 'p pred']
    titles_mid = ['u GT',   'v GT',   'p GT'  ]
    titles_bot = ['|u err|','|v err|','|p err|']

    for i in range(3):
        axes[0,i].set_title(titles_top[i])
        axes[1,i].set_title(titles_mid[i])
        axes[2,i].set_title(titles_bot[i])
        for r in range(3):
            axes[r,i].set_xticks([]); axes[r,i].set_yticks([])

    k0 = 0
    im00 = axes[0,0].imshow(u_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im01 = axes[0,1].imshow(v_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im02 = axes[0,2].imshow(p_pred[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im10 = axes[1,0].imshow(u_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u, animated=True)
    im11 = axes[1,1].imshow(v_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v, animated=True)
    im12 = axes[1,2].imshow(p_true[...,k0].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p, animated=True)

    im20 = axes[2,0].imshow(eu[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_u, animated=True)
    im21 = axes[2,1].imshow(ev[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_v, animated=True)
    im22 = axes[2,2].imshow(ep[...,k0].T, origin='lower', cmap=cmap_err,   vmin=0.0, vmax=emax_p, animated=True)

    ims = [im00, im01, im02, im10, im11, im12, im20, im21, im22]
    cbs = []
    if add_colorbars:
        for ax, im in zip(axes[0], ims[0:3]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[1], ims[3:6]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))
        for ax, im in zip(axes[2], ims[6:9]): cbs.append(fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02))

    # testo tempo/frame
    if times is not None and len(times) >= Tpred:
        time_text = fig.text(0.01, 0.98, f"t = {float(times[0]):.3f}", fontsize=12)
    else:
        time_text = fig.text(0.01, 0.98, f"frame 0 / {Tpred-1}", fontsize=12)

    def update(frame):
        im00.set_array(u_pred[...,frame].T); im01.set_array(v_pred[...,frame].T); im02.set_array(p_pred[...,frame].T)
        im10.set_array(u_true[...,frame].T); im11.set_array(v_true[...,frame].T); im12.set_array(p_true[...,frame].T)
        im20.set_array(eu[...,frame].T);     im21.set_array(ev[...,frame].T);     im22.set_array(ep[...,frame].T)
        if times is not None and len(times) >= Tpred:
            time_text.set_text(f"t = {float(times[frame]):.3f}")
        else:
            time_text.set_text(f"frame {frame} / {Tpred-1}")
        return ims + [time_text]

    ani = animation.FuncAnimation(fig, update, frames=Tpred, interval=interval, blit=False)

    # ---- salva GIF ----
    gif_path = os.path.join(out_dir, f"{filename_base}.gif")
    ani.save(gif_path, writer='pillow', fps=max(1, int(1000/interval)))

    # ---- salva PNG dell'ultimo frame (stessa griglia 3x3) ----
    png_path = None
    if save_last_png:
        frame = Tpred-1
        fig_last, axes_last = plt.subplots(3, 3, figsize=(12, 10), constrained_layout=True)
        titles_top = ['u pred', 'v pred', 'p pred']
        titles_mid = ['u GT',   'v GT',   'p GT'  ]
        titles_bot = ['|u err|','|v err|','|p err|']
        for i in range(3):
            axes_last[0,i].set_title(titles_top[i])
            axes_last[1,i].set_title(titles_mid[i])
            axes_last[2,i].set_title(titles_bot[i])
            for r in range(3):
                axes_last[r,i].set_xticks([]); axes_last[r,i].set_yticks([])

        axes_last[0,0].imshow(u_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[0,1].imshow(v_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[0,2].imshow(p_pred[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[1,0].imshow(u_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_u, vmax=vmax_u)
        axes_last[1,1].imshow(v_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_v, vmax=vmax_v)
        axes_last[1,2].imshow(p_true[...,frame].T, origin='lower', cmap=cmap_field, vmin=vmin_p, vmax=vmax_p)

        axes_last[2,0].imshow(eu[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_u)
        axes_last[2,1].imshow(ev[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_v)
        axes_last[2,2].imshow(ep[...,frame].T, origin='lower', cmap=cmap_err, vmin=0.0, vmax=emax_p)

        if add_colorbars:
            for ax in axes_last[0]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[1]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)
            for ax in axes_last[2]: fig_last.colorbar(ax.images[0], ax=ax, fraction=0.046, pad=0.02)

        png_path = os.path.join(out_dir, f"{filename_base}_last.png")
        fig_last.savefig(png_path, dpi=160, bbox_inches="tight")
        plt.close(fig_last)

    plt.close(fig)
    return ani, gif_path, png_path



# batch di esempio
xx, yy = next(iter(train_loader))
xx = xx.to(device, dtype=torch.float32)
yy = yy.to(device, dtype=torch.float32)

# salva GIF + ultimo frame PNG nella cartella immagini dell'esperimento
ani, gif_path, png_path = animate_prediction(
    xx, yy, model,
    T=T, step=1, interval=200,
    save_prefix="supervised_fno",
    out_dir=path_image,          # <--- usa la cartella 'image/<path>'
    save_last_png=True,
)

print("GIF salvata in:", gif_path)
print("PNG ultimo frame in:", png_path)
# Out:
# GIF salvata in: image/FNO_Sup_ep250_m24_w64_T10/supervised_fno.gif
# PNG ultimo frame in: image/FNO_Sup_ep250_m24_w64_T10/supervised_fno_last.png
